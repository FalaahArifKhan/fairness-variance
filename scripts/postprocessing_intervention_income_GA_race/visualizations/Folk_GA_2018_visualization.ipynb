# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  c:\RAI\latest\fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_group_models_box_plot_per_test_set, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'eq_odds_postprocessing'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = "3cd57b4b-2226-4f9e-9ff9-398ebe58e111"
SENSITIVE_ATTRS = ['SEX', "RAC1P", "SEX&RAC1P"]
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (150, 33)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(5)
# Out:
#      Metric              Model_Name  \
# 0  Accuracy  RandomForestClassifier
# 1  Accuracy  RandomForestClassifier
# 2  Accuracy  RandomForestClassifier
# 3  Accuracy  RandomForestClassifier
# 4  Accuracy  RandomForestClassifier
#
#                                         Model_Params  \
# 0  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 1  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 2  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 3  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# 4  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
#
#                 Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0  Folktables_GA_2018_Income             200  OK 2023-11-19 21:29:05.224
# 1  Folktables_GA_2018_Income             200  OK 2023-11-19 21:47:04.676
# 2  Folktables_GA_2018_Income             200  OK 2023-11-20 07:09:31.511
# 3  Folktables_GA_2018_Income             200  OK 2023-11-20 07:10:16.850
# 4  Folktables_GA_2018_Income             200  OK 2023-11-20 07:11:50.130
#
#                            Session_Uuid Experiment_Iteration  \
# 0  3cd57b4b-2226-4f9e-9ff9-398ebe58e111           Exp_iter_1
# 1  3cd57b4b-2226-4f9e-9ff9-398ebe58e111           Exp_iter_1
# 2  3cd57b4b-2226-4f9e-9ff9-398ebe58e111           Exp_iter_4
# 3  3cd57b4b-2226-4f9e-9ff9-398ebe58e111           Exp_iter_3
# 4  3cd57b4b-2226-4f9e-9ff9-398ebe58e111           Exp_iter_5
#
#    Dataset_Split_Seed  ...  SEX&RAC1P_priv_correct SEX&RAC1P_priv_incorrect  \
# 0                 100  ...                     NaN                      NaN
# 1                 100  ...                     1.0                      0.0
# 2                 400  ...                     NaN                      NaN
# 3                 300  ...                     NaN                      NaN
# 4                 500  ...                     NaN                      NaN
#
#     SEX_dis  SEX_dis_correct  SEX_dis_incorrect  SEX_priv  SEX_priv_correct  \
# 0  0.823611              NaN                NaN  0.796154               NaN
# 1  0.826389              1.0                0.0  0.803846               1.0
# 2  0.830579              NaN                NaN  0.794574               NaN
# 3  0.817427              NaN                NaN  0.776062               NaN
# 4  0.811749              NaN                NaN  0.798935               NaN
#
#    SEX_priv_incorrect   overall  Test_Set_Index
# 0                 NaN  0.809333               0
# 1                 0.0  0.814667               0
# 2                 NaN  0.812000               0
# 3                 NaN  0.796000               0
# 4                 NaN  0.805333               0
#
# [5 rows x 33 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Accuracy') & (df.Experiment_Iteration == 'Exp_iter_1')].T
# Out:
#                                                                               0  \
# Metric                                                                 Accuracy
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# Dataset_Name                                          Folktables_GA_2018_Income
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-11-19 21:29:05.224000
# Session_Uuid                               3cd57b4b-2226-4f9e-9ff9-398ebe58e111
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                                         [1.0, 0.0]
# Intervention_Param                                                          1.0
# RAC1P_dis                                                              0.836066
# RAC1P_dis_correct                                                           NaN
# RAC1P_dis_incorrect                                                         NaN
# RAC1P_priv                                                             0.796443
# RAC1P_priv_correct                                                          NaN
# RAC1P_priv_incorrect                                                        NaN
# SEX&RAC1P_dis                                                          0.829457
# SEX&RAC1P_dis_correct                                                       NaN
# SEX&RAC1P_dis_incorrect                                                     NaN
# SEX&RAC1P_priv                                                         0.805153
# SEX&RAC1P_priv_correct                                                      NaN
# SEX&RAC1P_priv_incorrect                                                    NaN
# SEX_dis                                                                0.823611
# SEX_dis_correct                                                             NaN
# SEX_dis_incorrect                                                           NaN
# SEX_priv                                                               0.796154
# SEX_priv_correct                                                            NaN
# SEX_priv_incorrect                                                          NaN
# overall                                                                0.809333
# Test_Set_Index                                                                0
#
#                                                                               1
# Metric                                                                 Accuracy
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# Dataset_Name                                          Folktables_GA_2018_Income
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-11-19 21:47:04.676000
# Session_Uuid                               3cd57b4b-2226-4f9e-9ff9-398ebe58e111
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                                         [1.0, 0.0]
# Intervention_Param                                                          0.0
# RAC1P_dis                                                              0.831967
# RAC1P_dis_correct                                                           1.0
# RAC1P_dis_incorrect                                                         0.0
# RAC1P_priv                                                             0.806324
# RAC1P_priv_correct                                                          1.0
# RAC1P_priv_incorrect                                                        0.0
# SEX&RAC1P_dis                                                          0.825581
# SEX&RAC1P_dis_correct                                                       1.0
# SEX&RAC1P_dis_incorrect                                                     0.0
# SEX&RAC1P_priv                                                         0.812399
# SEX&RAC1P_priv_correct                                                      1.0
# SEX&RAC1P_priv_incorrect                                                    0.0
# SEX_dis                                                                0.826389
# SEX_dis_correct                                                             1.0
# SEX_dis_incorrect                                                           0.0
# SEX_priv                                                               0.803846
# SEX_priv_correct                                                            1.0
# SEX_priv_incorrect                                                          0.0
# overall                                                                0.814667
# Test_Set_Index                                                                0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
test_df = melted_all_subgroup_metrics_per_model_dct["RandomForestClassifier"]
test_df[(test_df['Metric'] == 'Label_Stability') & (test_df['Intervention_Param'] == 1) & (test_df["Subgroup"] == 'overall')][["Metric", "Experiment_Iteration", "Metric_Value"]]
# Out:
#               Metric Experiment_Iteration  Metric_Value
# 221  Label_Stability           Exp_iter_1      0.999160
# 221  Label_Stability           Exp_iter_4      0.999133
# 221  Label_Stability           Exp_iter_3      0.951387
# 221  Label_Stability           Exp_iter_5      0.999213
# 221  Label_Stability           Exp_iter_2      0.998580

# %%
test_df = melted_all_subgroup_metrics_per_model_dct["RandomForestClassifier"]
test_df[(test_df['Metric'] == 'Label_Stability') & (test_df['Intervention_Param'] == 0) & (test_df["Subgroup"] == 'overall')][["Metric", "Experiment_Iteration", "Metric_Value"]]
# Out:
#               Metric Experiment_Iteration  Metric_Value
# 331  Label_Stability           Exp_iter_1      0.898140
# 331  Label_Stability           Exp_iter_4      0.908553
# 331  Label_Stability           Exp_iter_3      0.904807
# 331  Label_Stability           Exp_iter_5      0.903787
# 331  Label_Stability           Exp_iter_2      0.898413

# %%
melted_all_subgroup_metrics_per_model_dct['RandomForestClassifier']["Intervention_Param"]= melted_all_subgroup_metrics_per_model_dct['RandomForestClassifier']["Intervention_Param"].astype(bool)

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           ylim=(0.8, 0.83),
                                           metric_names=['Accuracy'],
                                           )

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           #ylim=(0.40, 0.525),
                                           metric_names=['F1'],
                                           )

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           #ylim=(0.925, 1.005),
                                           metric_names=['Label_Stability'])

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           #ylim=(0.925, 1.005),
                                           metric_names=['Jitter'])

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group='RAC1P',
                                           metric_names=['Equalized_Odds_FPR'])

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group='RAC1P',
                                           metric_names=['Equalized_Odds_FNR'])

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group='RAC1P',
                                           metric_names=['Label_Stability_Ratio'])
