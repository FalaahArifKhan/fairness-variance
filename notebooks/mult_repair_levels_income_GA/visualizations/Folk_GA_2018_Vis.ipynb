# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = 'da196782-b063-488c-9ad7-bc52ccf8e6ed'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (108, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3                Accuracy                   201  RandomForestClassifier
# 4                Accuracy                   201  RandomForestClassifier
# 5                Accuracy                   201  RandomForestClassifier
# 6   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 7   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 8   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 9   Aleatoric_Uncertainty                   201  RandomForestClassifier
# 10  Aleatoric_Uncertainty                   201  RandomForestClassifier
# 11  Aleatoric_Uncertainty                   201  RandomForestClassifier
# 12                     F1                   101  RandomForestClassifier
# 13                     F1                   101  RandomForestClassifier
# 14                     F1                   101  RandomForestClassifier
# 15                     F1                   201  RandomForestClassifier
# 16                     F1                   201  RandomForestClassifier
# 17                     F1                   201  RandomForestClassifier
# 18                    FNR                   101  RandomForestClassifier
# 19                    FNR                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income              20  OK 2023-07-17 17:36:15.513
# 1   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 2   Folktables_GA_2018_Income              20  OK 2023-07-17 17:45:52.937
# 3   Folktables_GA_2018_Income              20  OK 2023-07-17 17:49:07.225
# 4   Folktables_GA_2018_Income              20  OK 2023-07-17 17:53:16.901
# 5   Folktables_GA_2018_Income              20  OK 2023-07-17 17:57:20.827
# 6   Folktables_GA_2018_Income              20  OK 2023-07-17 17:36:15.513
# 7   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 8   Folktables_GA_2018_Income              20  OK 2023-07-17 17:45:52.937
# 9   Folktables_GA_2018_Income              20  OK 2023-07-17 17:49:07.225
# 10  Folktables_GA_2018_Income              20  OK 2023-07-17 17:53:16.901
# 11  Folktables_GA_2018_Income              20  OK 2023-07-17 17:57:20.827
# 12  Folktables_GA_2018_Income              20  OK 2023-07-17 17:36:15.513
# 13  Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 14  Folktables_GA_2018_Income              20  OK 2023-07-17 17:45:52.937
# 15  Folktables_GA_2018_Income              20  OK 2023-07-17 17:49:07.225
# 16  Folktables_GA_2018_Income              20  OK 2023-07-17 17:53:16.901
# 17  Folktables_GA_2018_Income              20  OK 2023-07-17 17:57:20.827
# 18  Folktables_GA_2018_Income              20  OK 2023-07-17 17:36:15.513
# 19  Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
#
#                             Session_Uuid  ... SEX&RAC1P_priv  \
# 0   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.795304
# 1   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.797712
# 2   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.791090
# 3   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.808309
# 4   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.808902
# 5   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.805341
# 6   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.636755
# 7   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.639642
# 8   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.638445
# 9   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.629901
# 10  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.629014
# 11  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.629691
# 12  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.713322
# 13  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.719533
# 14  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.710592
# 15  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.731505
# 16  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.733444
# 17  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.728027
# 18  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.311075
# 19  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.298046
#
#     SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect   SEX_dis  \
# 0                 1.000000                  0.000000  0.831183
# 1                 1.000000                  0.000000  0.827957
# 2                 1.000000                  0.000000  0.829032
# 3                 1.000000                  0.000000  0.837500
# 4                 1.000000                  0.000000  0.837500
# 5                 1.000000                  0.000000  0.834375
# 6                 0.583872                  0.842222  0.585888
# 7                 0.588846                  0.839951  0.584667
# 8                 0.583744                  0.845582  0.585307
# 9                 0.580300                  0.839056  0.600616
# 10                0.577768                  0.845935  0.592227
# 11                0.577590                  0.845243  0.591568
# 12                1.000000                  0.000000  0.662366
# 13                1.000000                  0.000000  0.658120
# 14                1.000000                  0.000000  0.656587
# 15                1.000000                  0.000000  0.668085
# 16                1.000000                  0.000000  0.660870
# 17                1.000000                  0.000000  0.656587
# 18                0.000000                  1.000000  0.412214
# 19                0.000000                  1.000000  0.412214
#
#     SEX_dis_correct  SEX_dis_incorrect  SEX_priv  SEX_priv_correct  \
# 0          1.000000           0.000000  0.778505          1.000000
# 1          1.000000           0.000000  0.785047          1.000000
# 2          1.000000           0.000000  0.775701          1.000000
# 3          1.000000           0.000000  0.793269          1.000000
# 4          1.000000           0.000000  0.795192          1.000000
# 5          1.000000           0.000000  0.792308          1.000000
# 6          0.539133           0.816085  0.657796          0.602501
# 7          0.535488           0.821340  0.663173          0.612420
# 8          0.536280           0.823041  0.660651          0.604826
# 9          0.554815           0.836669  0.636090          0.582953
# 10         0.545312           0.834020  0.640132          0.586391
# 11         0.543704           0.832694  0.641892          0.587673
# 12         1.000000           0.000000  0.724739          1.000000
# 13         1.000000           0.000000  0.736842          1.000000
# 14         1.000000           0.000000  0.726651          1.000000
# 15         1.000000           0.000000  0.753157          1.000000
# 16         1.000000           0.000000  0.759322          1.000000
# 17         1.000000           0.000000  0.755102          1.000000
# 18         0.000000           1.000000  0.284404          0.000000
# 19         0.000000           1.000000  0.261468          0.000000
#
#     SEX_priv_incorrect   overall
# 0             0.000000  0.803000
# 1             0.000000  0.805000
# 2             0.000000  0.800500
# 3             0.000000  0.814500
# 4             0.000000  0.815500
# 5             0.000000  0.812500
# 6             0.852146  0.624359
# 7             0.848529  0.626667
# 8             0.853711  0.625616
# 9             0.839991  0.619063
# 10            0.848788  0.617138
# 11            0.848727  0.617736
# 12            0.000000  0.702866
# 13            0.000000  0.709389
# 14            0.000000  0.702461
# 15            0.000000  0.723341
# 16            0.000000  0.725651
# 17            0.000000  0.721190
# 18            1.000000  0.332378
# 19            1.000000  0.318052
#
# [20 rows x 34 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.2].head(20)
# Out:
#                     Metric  Bootstrap_Model_Seed              Model_Name  \
# 1                 Accuracy                   101  RandomForestClassifier
# 7    Aleatoric_Uncertainty                   101  RandomForestClassifier
# 13                      F1                   101  RandomForestClassifier
# 19                     FNR                   101  RandomForestClassifier
# 25                     FPR                   101  RandomForestClassifier
# 31                     IQR                   101  RandomForestClassifier
# 37                  Jitter                   101  RandomForestClassifier
# 43         Label_Stability                   101  RandomForestClassifier
# 49                    Mean                   101  RandomForestClassifier
# 55     Overall_Uncertainty                   101  RandomForestClassifier
# 61                     PPV                   101  RandomForestClassifier
# 67     Per_Sample_Accuracy                   101  RandomForestClassifier
# 73           Positive-Rate                   101  RandomForestClassifier
# 79             Sample_Size                   101  RandomForestClassifier
# 85          Selection-Rate                   101  RandomForestClassifier
# 91                     Std                   101  RandomForestClassifier
# 97                     TNR                   101  RandomForestClassifier
# 103                    TPR                   101  RandomForestClassifier
#
#                                           Model_Params Run_Number  \
# 1    {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7    {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 13   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 25   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 31   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 37   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 43   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 49   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 55   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 61   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 67   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 73   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 79   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 85   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 91   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 97   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 103  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                   Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 1    Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 7    Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 13   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 19   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 25   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 31   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 37   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 43   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 49   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 55   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 61   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 67   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 73   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 79   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 85   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 91   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 97   Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
# 103  Folktables_GA_2018_Income              20  OK 2023-07-17 17:41:05.348
#
#                              Session_Uuid  ... SEX&RAC1P_priv  \
# 1    da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.797712
# 7    da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.639642
# 13   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.719533
# 19   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.298046
# 25   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.146132
# 31   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.081197
# 37   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.087344
# 43   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.879169
# 49   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.621414
# 55   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.659640
# 61   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.738014
# 67   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.784738
# 73   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.951140
# 79   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...    1661.000000
# 85   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.351595
# 91   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.061600
# 97   da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.853868
# 103  da196782-b063-488c-9ad7-bc52ccf8e6ed  ...       0.701954
#
#      SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect     SEX_dis  \
# 1                  1.000000                  0.000000    0.827957
# 7                  0.588846                  0.839951    0.584667
# 13                 1.000000                  0.000000    0.658120
# 19                 0.000000                  1.000000    0.412214
# 25                 0.000000                  1.000000    0.077844
# 31                 0.073987                  0.109630    0.072804
# 37                 0.066252                  0.170520    0.066870
# 43                 0.908000                  0.765476    0.907742
# 49                 0.646660                  0.521862    0.729314
# 55                 0.607368                  0.865770    0.602619
# 61                 1.000000                  0.000000    0.747573
# 67                 0.953698                  0.118452    0.822581
# 73                 1.000000                  0.836066    0.786260
# 79              1325.000000                336.000000  930.000000
# 85                 0.325283                  0.455357    0.221505
# 91                 0.056341                  0.082339    0.055288
# 97                 1.000000                  0.000000    0.922156
# 103                1.000000                  0.000000    0.587786
#
#      SEX_dis_correct  SEX_dis_incorrect     SEX_priv  SEX_priv_correct  \
# 1           1.000000           0.000000     0.785047          1.000000
# 7           0.535488           0.821340     0.663173          0.612420
# 13          1.000000           0.000000     0.736842          1.000000
# 19          0.000000           1.000000     0.261468          0.000000
# 25          0.000000           1.000000     0.182965          0.000000
# 31          0.065910           0.105982     0.083863          0.076544
# 37          0.047068           0.162171     0.097865          0.076660
# 43          0.937403           0.765000     0.863925          0.891548
# 49          0.758177           0.590412     0.573803          0.594337
# 55          0.552045           0.846007     0.683509          0.631280
# 61          1.000000           0.000000     0.735160          1.000000
# 67          0.968442           0.120625     0.768037          0.945536
# 73          1.000000           0.481481     1.004587          1.000000
# 79        770.000000         160.000000  1070.000000        840.000000
# 85          0.200000           0.325000     0.409346          0.383333
# 91          0.050538           0.078145     0.063592          0.058129
# 97          1.000000           0.000000     0.817035          1.000000
# 103         1.000000           0.000000     0.738532          1.000000
#
#      SEX_priv_incorrect      overall
# 1              0.000000     0.805000
# 7              0.848529     0.626667
# 13             0.000000     0.709389
# 19             1.000000     0.318052
# 25             1.000000     0.129032
# 31             0.110591     0.078720
# 37             0.175309     0.083453
# 43             0.763043     0.884300
# 49             0.498809     0.646116
# 55             0.874259     0.645895
# 61             0.000000     0.739130
# 67             0.119783     0.793400
# 73             1.017544     0.922636
# 79           230.000000  2000.000000
# 85             0.504348     0.322000
# 91             0.083542     0.059730
# 97             0.000000     0.870968
# 103            0.000000     0.681948
#
# [18 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.5].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR -0.151499 -0.159205  -0.158097
# 1             Equalized_Odds_FPR -0.120653 -0.082084  -0.100882
# 2             Equalized_Odds_FNR  0.151499  0.159205   0.158097
# 3               Disparate_Impact  0.756761  0.783636   0.724705
# 4  Statistical_Parity_Difference -0.246586 -0.210955  -0.262293
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.5
# 1  RandomForestClassifier           Exp_iter_1                 0.5
# 2  RandomForestClassifier           Exp_iter_1                 0.5
# 3  RandomForestClassifier           Exp_iter_1                 0.5
# 4  RandomForestClassifier           Exp_iter_1                 0.5

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11   Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 12     Overall_Uncertainty_Parity  RandomForestClassifier
# 13             Equalized_Odds_TPR  RandomForestClassifier
# 14             Equalized_Odds_FPR  RandomForestClassifier
# 15             Equalized_Odds_FNR  RandomForestClassifier
# 16               Disparate_Impact  RandomForestClassifier
# 17  Statistical_Parity_Difference  RandomForestClassifier
# 18                Accuracy_Parity  RandomForestClassifier
# 19          Label_Stability_Ratio  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 0.0    SEX     -0.127810
# 1            Exp_iter_1                 0.0    SEX     -0.104880
# 2            Exp_iter_1                 0.0    SEX      0.127810
# 3            Exp_iter_1                 0.0    SEX      0.794863
# 4            Exp_iter_1                 0.0    SEX     -0.199961
# 5            Exp_iter_1                 0.0    SEX      0.052678
# 6            Exp_iter_1                 0.0    SEX      1.061463
# 7            Exp_iter_1                 0.0    SEX     -0.010465
# 8            Exp_iter_1                 0.0    SEX     -0.008447
# 9            Exp_iter_1                 0.0    SEX      0.874180
# 10           Exp_iter_1                 0.0    SEX     -0.036395
# 11           Exp_iter_1                 0.0    SEX     -0.071909
# 12           Exp_iter_1                 0.0    SEX     -0.074575
# 13           Exp_iter_1                 0.0  RAC1P     -0.164672
# 14           Exp_iter_1                 0.0  RAC1P     -0.070122
# 15           Exp_iter_1                 0.0  RAC1P      0.164672
# 16           Exp_iter_1                 0.0  RAC1P      0.792431
# 17           Exp_iter_1                 0.0  RAC1P     -0.197191
# 18           Exp_iter_1                 0.0  RAC1P      0.020310
# 19           Exp_iter_1                 0.0  RAC1P      1.025686

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='SEX_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='SEX_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='SEX',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio', 'Jitter_Parity'])
# Out:
# alt.VConcatChart(...)
