# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/dh3553/projects/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '78c3da49-e095-43f3-8cc1-fa34bab0357c'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (360, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  RandomForestClassifier
# 1   Accuracy                   101  RandomForestClassifier
# 2   Accuracy                   101  RandomForestClassifier
# 3   Accuracy                   101  RandomForestClassifier
# 4   Accuracy                   101  RandomForestClassifier
# 5   Accuracy                   101  RandomForestClassifier
# 6   Accuracy                   101  RandomForestClassifier
# 7   Accuracy                   101  RandomForestClassifier
# 8   Accuracy                   101  RandomForestClassifier
# 9   Accuracy                   101  RandomForestClassifier
# 10  Accuracy                   201  RandomForestClassifier
# 11  Accuracy                   201  RandomForestClassifier
# 12  Accuracy                   301  RandomForestClassifier
# 13  Accuracy                   301  RandomForestClassifier
# 14  Accuracy                   401  RandomForestClassifier
# 15  Accuracy                   401  RandomForestClassifier
# 16  Accuracy                   501  RandomForestClassifier
# 17  Accuracy                   501  RandomForestClassifier
# 18  Accuracy                   601  RandomForestClassifier
# 19  Accuracy                   601  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income             200  OK 2023-07-18 11:35:29.212
# 1   Folktables_GA_2018_Income             200  OK 2023-07-18 00:42:39.317
# 2   Folktables_GA_2018_Income             200  OK 2023-07-18 11:07:08.956
# 3   Folktables_GA_2018_Income             200  OK 2023-07-18 11:07:47.852
# 4   Folktables_GA_2018_Income             200  OK 2023-07-18 00:10:59.799
# 5   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
#
# 3                  0.0   0.7980
# 4                  0.0   0.8020
# 5                  0.0   0.7960
# 6                  0.0   0.7945
# 7                  0.0   0.7970
# 8                  0.0   0.7965
# 9                  0.0   0.7980
# 10                 0.0   0.8130
# 11                 0.0   0.8110
# 12                 0.0   0.8210
# 13                 0.0   0.8185
# 14                 0.0   0.8220
# 15                 0.0   0.8240
# 16                 0.0   0.8150
# 17                 0.0   0.8155
# 18                 0.0   0.8090
# 19                 0.0   0.8110
#
# [20 rows x 34 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.2].head(20)
# Out:
#                     Metric  Bootstrap_Model_Seed              Model_Name  \
# 5                 Accuracy                   101  RandomForestClassifier
# 25   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 45                      F1                   101  RandomForestClassifier
# 65                     FNR                   101  RandomForestClassifier
# 85                     FPR                   101  RandomForestClassifier
# 105                    IQR                   101  RandomForestClassifier
# 125                 Jitter                   101  RandomForestClassifier
# 145        Label_Stability                   101  RandomForestClassifier
# 165                   Mean                   101  RandomForestClassifier
# 185    Overall_Uncertainty                   101  RandomForestClassifier
# 205                    PPV                   101  RandomForestClassifier
# 225    Per_Sample_Accuracy                   101  RandomForestClassifier
# 245          Positive-Rate                   101  RandomForestClassifier
# 265            Sample_Size                   101  RandomForestClassifier
# 285         Selection-Rate                   101  RandomForestClassifier
# 305                    Std                   101  RandomForestClassifier
# 325                    TNR                   101  RandomForestClassifier
# 345                    TPR                   101  RandomForestClassifier
#
#                                           Model_Params Run_Number  \
# 5    {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 25   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 45   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 65   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 85   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 105  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 125  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 145  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 165  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 185  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 205  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 225  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 245  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 265  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 285  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 305  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 325  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 345  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                   Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 5    Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 25   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 45   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 65   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 85   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 105  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 125  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 145  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 165  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 185  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 205  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 225  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 245  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 265  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 285  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 305  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 325  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 345  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
#
#                              Session_Uuid  ... SEX&RAC1P_priv  \
# 5    78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.790488
# 25   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.677995
# 45   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.706081
# 65   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.319218
# 85   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.145177
# 105  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.066470
# 125  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.072810
# 145  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.894551
# 165  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.624910
# 185  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.689381
# 205  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.733333
# 225  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.785620
# 245  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.928339
# 265  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...    1661.000000
# 285  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.343167
# 305  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.048160
# 325  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.854823
# 345  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.680782
#
#      SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect     SEX_dis  \
# 5                  1.000000                  0.000000    0.819355
# 25                 0.625828                  0.874819    0.633203
# 45                 1.000000                  0.000000    0.629956
# 65                 0.000000                  1.000000    0.454198
# 85                 0.000000                  1.000000    0.073353
# 105                0.060717                  0.088179    0.060790
# 125                0.051102                  0.154711    0.055381
# 145                0.927091                  0.771782    0.921097
# 165                0.649701                  0.531378    0.724816
# 185                0.636390                  0.889313    0.643582
# 205                1.000000                  0.000000    0.744792
# 225                0.963507                  0.114454    0.818462
# 245                1.000000                  0.775510    0.732824
# 265             1313.000000                348.000000  930.000000
# 285                0.318355                  0.436782    0.206452
# 305                0.044087                  0.063528    0.044146
# 325                1.000000                  0.000000    0.926647
# 345                1.000000                  0.000000    0.545802
#
#      SEX_dis_correct  SEX_dis_incorrect     SEX_priv  SEX_priv_correct  \
# 5           1.000000           0.000000     0.775701          1.000000
# 25          0.584811           0.852695     0.696019          0.643167
# 45          1.000000           0.000000     0.718970          1.000000
# 65          0.000000           1.000000     0.295872          0.000000
# 85          0.000000           1.000000     0.175079          0.000000
# 105         0.055284           0.085767     0.069653          0.063922
# 125         0.036160           0.142563     0.082000          0.060439
# 145         0.950486           0.787798     0.881514          0.912723
# 165         0.753948           0.592681     0.584189          0.603191
# 185         0.594348           0.866893     0.708135          0.654525
# 205         1.000000           0.000000     0.734450          1.000000
# 225         0.975243           0.107351     0.767252          0.956301
# 245         1.000000           0.411765     0.958716          1.000000
# 265       762.000000         168.000000  1070.000000        830.000000
# 285         0.187664           0.291667     0.390654          0.369880
# 305         0.040194           0.062075     0.050388          0.046367
# 325         1.000000           0.000000     0.824921          1.000000
# 345         1.000000           0.000000     0.704128          1.000000
#
#      SEX_priv_incorrect      overall
# 5              0.000000     0.796000
# 25             0.878797     0.666810
# 45             0.000000     0.688073
# 65             1.000000     0.355301
# 85             1.000000     0.122888
# 105            0.089474     0.065532
# 125            0.156566     0.069622
# 145            0.773583     0.899920
# 165            0.518473     0.649581
# 185            0.893538     0.678118
# 205            0.000000     0.737705
# 225            0.113458     0.791065
# 245            0.860465     0.873926
# 265          240.000000  2000.000000
# 285            0.462500     0.305000
# 305            0.064295     0.047486
# 325            0.000000     0.877112
# 345            0.000000     0.644699
#
# [18 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.5].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR -0.124729 -0.262252  -0.279277
# 1             Equalized_Odds_FPR -0.112686 -0.103790  -0.118580
# 2             Equalized_Odds_FNR  0.124729  0.262252   0.279277
# 3               Disparate_Impact  0.782651  0.624367   0.532062
# 4  Statistical_Parity_Difference -0.209871 -0.368410  -0.439739
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.5
# 1  RandomForestClassifier           Exp_iter_1                 0.5
# 2  RandomForestClassifier           Exp_iter_1                 0.5
# 3  RandomForestClassifier           Exp_iter_1                 0.5
# 4  RandomForestClassifier           Exp_iter_1                 0.5

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11   Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 12     Overall_Uncertainty_Parity  RandomForestClassifier
# 13             Equalized_Odds_TPR  RandomForestClassifier
# 14             Equalized_Odds_FPR  RandomForestClassifier
# 15             Equalized_Odds_FNR  RandomForestClassifier
# 16               Disparate_Impact  RandomForestClassifier
# 17  Statistical_Parity_Difference  RandomForestClassifier
# 18                Accuracy_Parity  RandomForestClassifier
# 19          Label_Stability_Ratio  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 1.0    SEX     -0.124729
# 1            Exp_iter_1                 1.0    SEX     -0.117338
# 2            Exp_iter_1                 1.0    SEX      0.124729
# 3            Exp_iter_1                 1.0    SEX      0.775017
# 4            Exp_iter_1                 1.0    SEX     -0.218275
# 5            Exp_iter_1                 1.0    SEX      0.063612
# 6            Exp_iter_1                 1.0    SEX      1.053378
# 7            Exp_iter_1                 1.0    SEX     -0.011239
# 8            Exp_iter_1                 1.0    SEX     -0.007844
# 9            Exp_iter_1                 1.0    SEX      0.870125
# 10           Exp_iter_1                 1.0    SEX     -0.030372
# 11           Exp_iter_1                 1.0    SEX     -0.064423
# 12           Exp_iter_1                 1.0    SEX     -0.067090
# 13           Exp_iter_1                 1.0  RAC1P     -0.247169
# 14           Exp_iter_1                 1.0  RAC1P     -0.098302
# 15           Exp_iter_1                 1.0  RAC1P      0.247169
# 16           Exp_iter_1                 1.0  RAC1P      0.651109
# 17           Exp_iter_1                 1.0  RAC1P     -0.340169
# 18           Exp_iter_1                 1.0  RAC1P      0.016078
# 19           Exp_iter_1                 1.0  RAC1P      1.018104

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='SEX_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='SEX_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='SEX',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio', 'Jitter_Parity'])
# Out:
# alt.VConcatChart(...)
