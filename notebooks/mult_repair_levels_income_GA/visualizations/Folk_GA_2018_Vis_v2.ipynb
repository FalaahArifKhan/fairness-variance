# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '26beff01-939d-4d98-be67-65b150b352b2'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (1188, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  RandomForestClassifier
# 1   Accuracy                   101  RandomForestClassifier
# 2   Accuracy                   101  RandomForestClassifier
# 3   Accuracy                   101  RandomForestClassifier
# 4   Accuracy                   101  RandomForestClassifier
# 5   Accuracy                   101  RandomForestClassifier
# 6   Accuracy                   101  RandomForestClassifier
# 7   Accuracy                   101  RandomForestClassifier
# 8   Accuracy                   101  RandomForestClassifier
# 9   Accuracy                   101  RandomForestClassifier
# 10  Accuracy                   101  RandomForestClassifier
# 11  Accuracy                   201  RandomForestClassifier
# 12  Accuracy                   201  RandomForestClassifier
# 13  Accuracy                   201  RandomForestClassifier
# 14  Accuracy                   201  RandomForestClassifier
# 15  Accuracy                   201  RandomForestClassifier
# 16  Accuracy                   201  RandomForestClassifier
# 17  Accuracy                   201  RandomForestClassifier
# 18  Accuracy                   201  RandomForestClassifier
# 19  Accuracy                   201  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 1   Folktables_GA_2018_Income             200  OK 2023-07-23 01:19:34.560
# 2   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 3   Folktables_GA_2018_Income             200  OK 2023-07-23 01:43:02.560
# 4   Folktables_GA_2018_Income             200  OK 2023-07-23 04:16:36.782
# 5   Folktables_GA_2018_Income             200  OK 2023-07-23 02:27:24.049
# 6   Folktables_GA_2018_Income             200  OK 2023-07-23 01:08:10.525
# 7   Folktables_GA_2018_Income             200  OK 2023-07-23 03:39:34.934
# 8   Folktables_GA_2018_Income             200  OK 2023-07-23 01:14:25.556
# 9   Folktables_GA_2018_Income             200  OK 2023-07-23 01:49:09.414
# 10  Folktables_GA_2018_Income             200  OK 2023-07-23 02:50:24.094
# 11  Folktables_GA_2018_Income             200  OK 2023-07-23 12:24:18.525
# 12  Folktables_GA_2018_Income             200  OK 2023-07-23 13:12:57.796
# 13  Folktables_GA_2018_Income             200  OK 2023-07-23 12:55:55.110
# 14  Folktables_GA_2018_Income             200  OK 2023-07-23 11:37:41.620
# 15  Folktables_GA_2018_Income             200  OK 2023-07-23 11:05:44.385
# 16  Folktables_GA_2018_Income             200  OK 2023-07-23 12:05:18.854
# 17  Folktables_GA_2018_Income             200  OK 2023-07-23 11:21:54.019
# 18  Folktables_GA_2018_Income             200  OK 2023-07-23 10:50:21.876
# 19  Folktables_GA_2018_Income             200  OK 2023-07-23 10:42:54.152
#
#                             Session_Uuid  ... SEX&RAC1P_priv  \
# 0   26beff01-939d-4d98-be67-65b150b352b2  ...       0.801127
# 1   26beff01-939d-4d98-be67-65b150b352b2  ...       0.808374
# 2   26beff01-939d-4d98-be67-65b150b352b2  ...       0.812399
# 3   26beff01-939d-4d98-be67-65b150b352b2  ...       0.796296
# 4   26beff01-939d-4d98-be67-65b150b352b2  ...       0.797907
# 5   26beff01-939d-4d98-be67-65b150b352b2  ...       0.797101
# 6   26beff01-939d-4d98-be67-65b150b352b2  ...       0.803543
# 7   26beff01-939d-4d98-be67-65b150b352b2  ...       0.796296
# 8   26beff01-939d-4d98-be67-65b150b352b2  ...       0.807568
# 9   26beff01-939d-4d98-be67-65b150b352b2  ...       0.811594
# 10  26beff01-939d-4d98-be67-65b150b352b2  ...       0.800322
# 11  26beff01-939d-4d98-be67-65b150b352b2  ...       0.811155
# 12  26beff01-939d-4d98-be67-65b150b352b2  ...       0.813546
# 13  26beff01-939d-4d98-be67-65b150b352b2  ...       0.813546
# 14  26beff01-939d-4d98-be67-65b150b352b2  ...       0.810359
# 15  26beff01-939d-4d98-be67-65b150b352b2  ...       0.811155
# 16  26beff01-939d-4d98-be67-65b150b352b2  ...       0.812749
# 17  26beff01-939d-4d98-be67-65b150b352b2  ...       0.815139
# 18  26beff01-939d-4d98-be67-65b150b352b2  ...       0.815936
# 19  26beff01-939d-4d98-be67-65b150b352b2  ...       0.812749
#
#     SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect   SEX_dis  \
# 0                      1.0                       0.0  0.827778
# 1                      1.0                       0.0  0.834722
# 2                      1.0                       0.0  0.840278
# 3                      1.0                       0.0  0.826389
# 4                      1.0                       0.0  0.826389
# 5                      1.0                       0.0  0.827778
# 6                      1.0                       0.0  0.825000
# 7                      1.0                       0.0  0.827778
# 8                      1.0                       0.0  0.834722
# 9                      1.0                       0.0  0.838889
# 10                     1.0                       0.0  0.827778
# 11                     1.0                       0.0  0.839065
# 12                     1.0                       0.0  0.844567
# 13                     1.0                       0.0  0.843191
# 14                     1.0                       0.0  0.844567
# 15                     1.0                       0.0  0.844567
# 16                     1.0                       0.0  0.848693
# 17                     1.0                       0.0  0.848693
# 18                     1.0                       0.0  0.845942
# 19                     1.0                       0.0  0.840440
#
#     SEX_dis_correct  SEX_dis_incorrect  SEX_priv  SEX_priv_correct  \
# 0               1.0                0.0  0.791026               1.0
# 1               1.0                0.0  0.794872               1.0
# 2               1.0                0.0  0.797436               1.0
# 3               1.0                0.0  0.783333               1.0
# 4               1.0                0.0  0.788462               1.0
# 5               1.0                0.0  0.785897               1.0
# 6               1.0                0.0  0.794872               1.0
# 7               1.0                0.0  0.785897               1.0
# 8               1.0                0.0  0.796154               1.0
# 9               1.0                0.0  0.796154               1.0
# 10              1.0                0.0  0.791026               1.0
# 11              1.0                0.0  0.802070               1.0
# 12              1.0                0.0  0.802070               1.0
# 13              1.0                0.0  0.803364               1.0
# 14              1.0                0.0  0.798189               1.0
# 15              1.0                0.0  0.799483               1.0
# 16              1.0                0.0  0.798189               1.0
# 17              1.0                0.0  0.798189               1.0
# 18              1.0                0.0  0.804657               1.0
# 19              1.0                0.0  0.803364               1.0
#
#     SEX_priv_incorrect   overall
# 0                  0.0  0.808667
# 1                  0.0  0.814000
# 2                  0.0  0.818000
# 3                  0.0  0.804000
# 4                  0.0  0.806667
# 5                  0.0  0.806000
# 6                  0.0  0.809333
# 7                  0.0  0.806000
# 8                  0.0  0.814667
# 9                  0.0  0.816667
# 10                 0.0  0.808667
# 11                 0.0  0.820000
# 12                 0.0  0.822667
# 13                 0.0  0.822667
# 14                 0.0  0.820667
# 15                 0.0  0.821333
# 16                 0.0  0.822667
# 17                 0.0  0.822667
# 18                 0.0  0.824667
# 19                 0.0  0.821333
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
#                                                                             867
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# Run_Number                                                                Run_1
# Dataset_Name                                          Folktables_GA_2018_Income
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-07-23 01:49:09.414000
# Session_Uuid                               26beff01-939d-4d98-be67-65b150b352b2
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                               [0.0, 0.1, 0.2, 0.3]
# Intervention_Param                                                          0.1
# RAC1P_dis                                                                 488.0
# RAC1P_dis_correct                                                         412.0
# RAC1P_dis_incorrect                                                        76.0
# RAC1P_priv                                                               1012.0
# RAC1P_priv_correct                                                        813.0
# RAC1P_priv_incorrect                                                      199.0
# SEX&RAC1P_dis                                                             258.0
# SEX&RAC1P_dis_correct                                                     217.0
# SEX&RAC1P_dis_incorrect                                                    41.0
# SEX&RAC1P_priv                                                           1242.0
# SEX&RAC1P_priv_correct                                                   1008.0
# SEX&RAC1P_priv_incorrect                                                  234.0
# SEX_dis                                                                   720.0
# SEX_dis_correct                                                           604.0
# SEX_dis_incorrect                                                         116.0
# SEX_priv                                                                  780.0
# SEX_priv_correct                                                          621.0
# SEX_priv_incorrect                                                        159.0
# overall                                                                  1500.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.3].head(20)
# Out:
#                      Metric  Bootstrap_Model_Seed              Model_Name  \
# 2                  Accuracy                   101  RandomForestClassifier
# 68    Aleatoric_Uncertainty                   101  RandomForestClassifier
# 134                      F1                   101  RandomForestClassifier
# 200                     FNR                   101  RandomForestClassifier
# 266                     FPR                   101  RandomForestClassifier
# 332                     IQR                   101  RandomForestClassifier
# 398                  Jitter                   101  RandomForestClassifier
# 464         Label_Stability                   101  RandomForestClassifier
# 530                    Mean                   101  RandomForestClassifier
# 596     Overall_Uncertainty                   101  RandomForestClassifier
# 662                     PPV                   101  RandomForestClassifier
# 728     Per_Sample_Accuracy                   101  RandomForestClassifier
# 794           Positive-Rate                   101  RandomForestClassifier
# 860             Sample_Size                   101  RandomForestClassifier
# 926          Selection-Rate                   101  RandomForestClassifier
# 992                     Std                   101  RandomForestClassifier
# 1058                    TNR                   101  RandomForestClassifier
# 1124                    TPR                   101  RandomForestClassifier
#
#                                            Model_Params Run_Number  \
# 2     {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 68    {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 134   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 200   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 266   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 332   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 398   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 464   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 530   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 596   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 662   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 728   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 794   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 860   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 926   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 992   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1058  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1124  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
#
#                    Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 2     Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 68    Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 134   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 200   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 266   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 332   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 398   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 464   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 530   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 596   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 662   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 728   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 794   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 860   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 926   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 992   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 1058  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 1124  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
#
#                               Session_Uuid  ... SEX&RAC1P_priv  \
# 2     26beff01-939d-4d98-be67-65b150b352b2  ...       0.812399
# 68    26beff01-939d-4d98-be67-65b150b352b2  ...       0.632524
# 134   26beff01-939d-4d98-be67-65b150b352b2  ...       0.722288
# 200   26beff01-939d-4d98-be67-65b150b352b2  ...       0.345572
# 266   26beff01-939d-4d98-be67-65b150b352b2  ...       0.093710
# 332   26beff01-939d-4d98-be67-65b150b352b2  ...       0.081742
# 398   26beff01-939d-4d98-be67-65b150b352b2  ...       0.072563
# 464   26beff01-939d-4d98-be67-65b150b352b2  ...       0.898382
# 530   26beff01-939d-4d98-be67-65b150b352b2  ...       0.647063
# 596   26beff01-939d-4d98-be67-65b150b352b2  ...       0.650657
# 662   26beff01-939d-4d98-be67-65b150b352b2  ...       0.805851
# 728   26beff01-939d-4d98-be67-65b150b352b2  ...       0.804771
# 794   26beff01-939d-4d98-be67-65b150b352b2  ...       0.812095
# 860   26beff01-939d-4d98-be67-65b150b352b2  ...    1242.000000
# 926   26beff01-939d-4d98-be67-65b150b352b2  ...       0.302738
# 992   26beff01-939d-4d98-be67-65b150b352b2  ...       0.058517
# 1058  26beff01-939d-4d98-be67-65b150b352b2  ...       0.906290
# 1124  26beff01-939d-4d98-be67-65b150b352b2  ...       0.654428
#
#       SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect     SEX_dis  \
# 2                   1.000000                  0.000000    0.840278
# 68                  0.583198                  0.846131    0.611247
# 134                 1.000000                  0.000000    0.696570
# 200                 0.000000                  1.000000    0.356098
# 266                 0.000000                  1.000000    0.081553
# 332                 0.074670                  0.112367    0.080130
# 398                 0.052503                  0.159431    0.071075
# 464                 0.927820                  0.770901    0.896931
# 530                 0.664443                  0.571801    0.698450
# 596                 0.599997                  0.870037    0.629214
# 662                 1.000000                  0.000000    0.758621
# 728                 0.963791                  0.116137    0.830021
# 794                 1.000000                  0.456250    0.848780
# 860              1009.000000                233.000000  720.000000
# 926                 0.300297                  0.313305    0.241667
# 992                 0.053603                  0.079801    0.056951
# 1058                1.000000                  0.000000    0.918447
# 1124                1.000000                  0.000000    0.643902
#
#       SEX_dis_correct  SEX_dis_incorrect    SEX_priv  SEX_priv_correct  \
# 2            1.000000           0.000000    0.797436          1.000000
# 68           0.570675           0.824690    0.634553          0.580480
# 134          1.000000           0.000000    0.724739          1.000000
# 200          0.000000           1.000000    0.350000          0.000000
# 266          0.000000           1.000000    0.100000          0.000000
# 332          0.073578           0.114598    0.081635          0.074689
# 398          0.051777           0.172597    0.072975          0.053895
# 464          0.926281           0.742522    0.899090          0.926206
# 530          0.724855           0.559538    0.629470          0.641977
# 596          0.587301           0.849717    0.652630          0.597396
# 662          1.000000           0.000000    0.818898          1.000000
# 728          0.962793           0.131522    0.789147          0.963103
# 794          1.000000           0.575342    0.793750          1.000000
# 860        605.000000         115.000000  780.000000        622.000000
# 926          0.218182           0.365217    0.325641          0.334405
# 992          0.052547           0.080119    0.058488          0.053488
# 1058         1.000000           0.000000    0.900000          1.000000
# 1124         1.000000           0.000000    0.650000          1.000000
#
#       SEX_priv_incorrect      overall
# 2               0.000000     0.818000
# 68              0.847421     0.623366
# 134             0.000000     0.713536
# 200             1.000000     0.352381
# 266             1.000000     0.090256
# 332             0.108983     0.080913
# 398             0.148088     0.072063
# 464             0.792342     0.898053
# 530             0.580233     0.662580
# 596             0.870067     0.641390
# 662             0.000000     0.794393
# 728             0.104335     0.808767
# 794             0.410714     0.815238
# 860           158.000000  1500.000000
# 926             0.291139     0.285333
# 992             0.078175     0.057750
# 1058            0.000000     0.909744
# 1124            0.000000     0.647619
#
# [18 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.9].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR -0.016387  0.077789   0.007141
# 1             Equalized_Odds_FPR -0.011228  0.004746   0.000760
# 2             Equalized_Odds_FNR  0.016387 -0.077789  -0.007141
# 3               Disparate_Impact  1.067680  1.262328   1.177947
# 4  Statistical_Parity_Difference  0.048857  0.182431   0.129137
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.9
# 1  RandomForestClassifier           Exp_iter_1                 0.9
# 2  RandomForestClassifier           Exp_iter_1                 0.9
# 3  RandomForestClassifier           Exp_iter_1                 0.9
# 4  RandomForestClassifier           Exp_iter_1                 0.9

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11             Equalized_Odds_TPR  RandomForestClassifier
# 12             Equalized_Odds_FPR  RandomForestClassifier
# 13             Equalized_Odds_FNR  RandomForestClassifier
# 14               Disparate_Impact  RandomForestClassifier
# 15  Statistical_Parity_Difference  RandomForestClassifier
# 16                Accuracy_Parity  RandomForestClassifier
# 17          Label_Stability_Ratio  RandomForestClassifier
# 18                     IQR_Parity  RandomForestClassifier
# 19                     Std_Parity  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 0.2    SEX     -0.033003
# 1            Exp_iter_1                 0.2    SEX     -0.016041
# 2            Exp_iter_1                 0.2    SEX      0.033003
# 3            Exp_iter_1                 0.2    SEX      1.038527
# 4            Exp_iter_1                 0.2    SEX      0.029497
# 5            Exp_iter_1                 0.2    SEX      0.036752
# 6            Exp_iter_1                 0.2    SEX      0.995895
# 7            Exp_iter_1                 0.2    SEX     -0.002048
# 8            Exp_iter_1                 0.2    SEX     -0.001658
# 9            Exp_iter_1                 0.2    SEX      0.969420
# 10           Exp_iter_1                 0.2    SEX     -0.000275
# 11           Exp_iter_1                 0.2  RAC1P      0.044794
# 12           Exp_iter_1                 0.2  RAC1P     -0.009382
# 13           Exp_iter_1                 0.2  RAC1P     -0.044794
# 14           Exp_iter_1                 0.2  RAC1P      1.166225
# 15           Exp_iter_1                 0.2  RAC1P      0.124036
# 16           Exp_iter_1                 0.2  RAC1P      0.055798
# 17           Exp_iter_1                 0.2  RAC1P      1.021134
# 18           Exp_iter_1                 0.2  RAC1P     -0.002881
# 19           Exp_iter_1                 0.2  RAC1P     -0.003116

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Std',
                                                   group='SEX&RAC1P',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Label_Stability',
                                                   group='SEX&RAC1P',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='SEX&RAC1P',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Std_Parity', 'Label_Stability_Ratio'])
# Out:
# alt.VConcatChart(...)
