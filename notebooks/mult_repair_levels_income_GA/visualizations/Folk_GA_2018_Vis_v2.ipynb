# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/dh3553/projects/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '26beff01-939d-4d98-be67-65b150b352b2'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (198, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3                Accuracy                   101  RandomForestClassifier
# 4                Accuracy                   101  RandomForestClassifier
# 5                Accuracy                   101  RandomForestClassifier
# 6                Accuracy                   101  RandomForestClassifier
# 7                Accuracy                   101  RandomForestClassifier
# 8                Accuracy                   101  RandomForestClassifier
# 9                Accuracy                   101  RandomForestClassifier
# 10               Accuracy                   101  RandomForestClassifier
# 11  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 12  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 13  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 14  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 15  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 16  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 17  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 18  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 19  Aleatoric_Uncertainty                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 1   Folktables_GA_2018_Income             200  OK 2023-07-23 01:19:34.560
# 2   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 3   Folktables_GA_2018_Income             200  OK 2023-07-23 01:43:02.560
# 4   Folktables_GA_2018_Income             200  OK 2023-07-23 04:16:36.782
# 5   Folktables_GA_2018_Income             200  OK 2023-07-23 02:27:24.049
# 6   Folktables_GA_2018_Income             200  OK 2023-07-23 01:08:10.525
# 7   Folktables_GA_2018_Income             200  OK 2023-07-23 03:39:34.934
# 8   Folktables_GA_2018_Income             200  OK 2023-07-23 01:14:25.556
# 9   Folktables_GA_2018_Income             200  OK 2023-07-23 01:49:09.414
# 10  Folktables_GA_2018_Income             200  OK 2023-07-23 02:50:24.094
# 11  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 12  Folktables_GA_2018_Income             200  OK 2023-07-23 01:19:34.560
# 13  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 14  Folktables_GA_2018_Income             200  OK 2023-07-23 01:43:02.560
# 15  Folktables_GA_2018_Income             200  OK 2023-07-23 04:16:36.782
# 16  Folktables_GA_2018_Income             200  OK 2023-07-23 02:27:24.049
# 17  Folktables_GA_2018_Income             200  OK 2023-07-23 01:08:10.525
# 18  Folktables_GA_2018_Income             200  OK 2023-07-23 03:39:34.934
# 19  Folktables_GA_2018_Income             200  OK 2023-07-23 01:14:25.556
#
#                             Session_Uuid  ... SEX&RAC1P_priv  \
# 0   26beff01-939d-4d98-be67-65b150b352b2  ...       0.801127
# 1   26beff01-939d-4d98-be67-65b150b352b2  ...       0.808374
# 2   26beff01-939d-4d98-be67-65b150b352b2  ...       0.812399
# 3   26beff01-939d-4d98-be67-65b150b352b2  ...       0.796296
# 4   26beff01-939d-4d98-be67-65b150b352b2  ...       0.797907
# 5   26beff01-939d-4d98-be67-65b150b352b2  ...       0.797101
# 6   26beff01-939d-4d98-be67-65b150b352b2  ...       0.803543
# 7   26beff01-939d-4d98-be67-65b150b352b2  ...       0.796296
# 8   26beff01-939d-4d98-be67-65b150b352b2  ...       0.807568
# 9   26beff01-939d-4d98-be67-65b150b352b2  ...       0.811594
# 10  26beff01-939d-4d98-be67-65b150b352b2  ...       0.800322
# 11  26beff01-939d-4d98-be67-65b150b352b2  ...       0.632126
# 12  26beff01-939d-4d98-be67-65b150b352b2  ...       0.631608
# 13  26beff01-939d-4d98-be67-65b150b352b2  ...       0.632524
# 14  26beff01-939d-4d98-be67-65b150b352b2  ...       0.649997
# 15  26beff01-939d-4d98-be67-65b150b352b2  ...       0.652451
# 16  26beff01-939d-4d98-be67-65b150b352b2  ...       0.650213
# 17  26beff01-939d-4d98-be67-65b150b352b2  ...       0.642803
# 18  26beff01-939d-4d98-be67-65b150b352b2  ...       0.638928
# 19  26beff01-939d-4d98-be67-65b150b352b2  ...       0.656312
#
#     SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect   SEX_dis  \
# 0                 1.000000                  0.000000  0.827778
# 1                 1.000000                  0.000000  0.834722
# 2                 1.000000                  0.000000  0.840278
# 3                 1.000000                  0.000000  0.826389
# 4                 1.000000                  0.000000  0.826389
# 5                 1.000000                  0.000000  0.827778
# 6                 1.000000                  0.000000  0.825000
# 7                 1.000000                  0.000000  0.827778
# 8                 1.000000                  0.000000  0.834722
# 9                 1.000000                  0.000000  0.838889
# 10                1.000000                  0.000000  0.827778
# 11                0.579008                  0.846106  0.612344
# 12                0.580720                  0.846275  0.610452
# 13                0.583198                  0.846131  0.611247
# 14                0.598338                  0.851937  0.630936
# 15                0.602060                  0.851405  0.632470
# 16                0.599120                  0.850936  0.630739
# 17                0.591856                  0.851184  0.623213
# 18                0.585501                  0.847778  0.619824
# 19                0.606592                  0.864971  0.635264
#
#     SEX_dis_correct  SEX_dis_incorrect  SEX_priv  SEX_priv_correct  \
# 0          1.000000           0.000000  0.791026          1.000000
# 1          1.000000           0.000000  0.794872          1.000000
# 2          1.000000           0.000000  0.797436          1.000000
# 3          1.000000           0.000000  0.783333          1.000000
# 4          1.000000           0.000000  0.788462          1.000000
# 5          1.000000           0.000000  0.785897          1.000000
# 6          1.000000           0.000000  0.794872          1.000000
# 7          1.000000           0.000000  0.785897          1.000000
# 8          1.000000           0.000000  0.796154          1.000000
# 9          1.000000           0.000000  0.796154          1.000000
# 10         1.000000           0.000000  0.791026          1.000000
# 11         0.566604           0.832193  0.634673          0.579573
# 12         0.567567           0.827040  0.633655          0.578536
# 13         0.570675           0.824690  0.634553          0.580480
# 14         0.586809           0.840979  0.653757          0.599022
# 15         0.588670           0.840957  0.656866          0.605144
# 16         0.587253           0.839751  0.654610          0.601350
# 17         0.577048           0.840848  0.645085          0.592537
# 18         0.574955           0.835483  0.642467          0.587331
# 19         0.594068           0.843323  0.657764          0.604530
#
#     SEX_priv_incorrect   overall
# 0             0.000000  0.808667
# 1             0.000000  0.814000
# 2             0.000000  0.818000
# 3             0.000000  0.804000
# 4             0.000000  0.806667
# 5             0.000000  0.806000
# 6             0.000000  0.809333
# 7             0.000000  0.806000
# 8             0.000000  0.814667
# 9             0.000000  0.816667
# 10            0.000000  0.808667
# 11            0.843239  0.623955
# 12            0.847245  0.622518
# 13            0.847421  0.623366
# 14            0.851645  0.642803
# 15            0.849646  0.645155
# 16            0.850111  0.643152
# 17            0.848708  0.634587
# 18            0.844853  0.631599
# 19            0.865680  0.646964
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
#                                                                             152
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# Run_Number                                                                Run_1
# Dataset_Name                                          Folktables_GA_2018_Income
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-07-23 01:49:09.414000
# Session_Uuid                               26beff01-939d-4d98-be67-65b150b352b2
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                               [0.0, 0.1, 0.2, 0.3]
# Intervention_Param                                                          0.1
# RAC1P_dis                                                                 488.0
# RAC1P_dis_correct                                                         412.0
# RAC1P_dis_incorrect                                                        76.0
# RAC1P_priv                                                               1012.0
# RAC1P_priv_correct                                                        813.0
# RAC1P_priv_incorrect                                                      199.0
# SEX&RAC1P_dis                                                             258.0
# SEX&RAC1P_dis_correct                                                     217.0
# SEX&RAC1P_dis_incorrect                                                    41.0
# SEX&RAC1P_priv                                                           1242.0
# SEX&RAC1P_priv_correct                                                   1008.0
# SEX&RAC1P_priv_incorrect                                                  234.0
# SEX_dis                                                                   720.0
# SEX_dis_correct                                                           604.0
# SEX_dis_incorrect                                                         116.0
# SEX_priv                                                                  780.0
# SEX_priv_correct                                                          621.0
# SEX_priv_incorrect                                                        159.0
# overall                                                                  1500.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.3].head(20)
# Out:
#                     Metric  Bootstrap_Model_Seed              Model_Name  \
# 2                 Accuracy                   101  RandomForestClassifier
# 13   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 24                      F1                   101  RandomForestClassifier
# 35                     FNR                   101  RandomForestClassifier
# 46                     FPR                   101  RandomForestClassifier
# 57                     IQR                   101  RandomForestClassifier
# 68                  Jitter                   101  RandomForestClassifier
# 79         Label_Stability                   101  RandomForestClassifier
# 90                    Mean                   101  RandomForestClassifier
# 101    Overall_Uncertainty                   101  RandomForestClassifier
# 112                    PPV                   101  RandomForestClassifier
# 123    Per_Sample_Accuracy                   101  RandomForestClassifier
# 134          Positive-Rate                   101  RandomForestClassifier
# 145            Sample_Size                   101  RandomForestClassifier
# 156         Selection-Rate                   101  RandomForestClassifier
# 167                    Std                   101  RandomForestClassifier
# 178                    TNR                   101  RandomForestClassifier
# 189                    TPR                   101  RandomForestClassifier
#
#                                           Model_Params Run_Number  \
# 2    {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 13   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 24   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 35   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 46   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 57   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 68   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 79   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 90   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 101  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 112  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 123  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 134  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 145  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 156  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 167  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 178  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 189  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
#
#                   Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 2    Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 13   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 24   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 35   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 46   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 57   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 68   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 79   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 90   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 101  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 112  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 123  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 134  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 145  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 156  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 167  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 178  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 189  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
#
#                              Session_Uuid  ... SEX&RAC1P_priv  \
# 2    26beff01-939d-4d98-be67-65b150b352b2  ...       0.812399
# 13   26beff01-939d-4d98-be67-65b150b352b2  ...       0.632524
# 24   26beff01-939d-4d98-be67-65b150b352b2  ...       0.722288
# 35   26beff01-939d-4d98-be67-65b150b352b2  ...       0.345572
# 46   26beff01-939d-4d98-be67-65b150b352b2  ...       0.093710
# 57   26beff01-939d-4d98-be67-65b150b352b2  ...       0.081742
# 68   26beff01-939d-4d98-be67-65b150b352b2  ...       0.072563
# 79   26beff01-939d-4d98-be67-65b150b352b2  ...       0.898382
# 90   26beff01-939d-4d98-be67-65b150b352b2  ...       0.647063
# 101  26beff01-939d-4d98-be67-65b150b352b2  ...       0.650657
# 112  26beff01-939d-4d98-be67-65b150b352b2  ...       0.805851
# 123  26beff01-939d-4d98-be67-65b150b352b2  ...       0.804771
# 134  26beff01-939d-4d98-be67-65b150b352b2  ...       0.812095
# 145  26beff01-939d-4d98-be67-65b150b352b2  ...    1242.000000
# 156  26beff01-939d-4d98-be67-65b150b352b2  ...       0.302738
# 167  26beff01-939d-4d98-be67-65b150b352b2  ...       0.058517
# 178  26beff01-939d-4d98-be67-65b150b352b2  ...       0.906290
# 189  26beff01-939d-4d98-be67-65b150b352b2  ...       0.654428
#
#      SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect     SEX_dis  \
# 2                  1.000000                  0.000000    0.840278
# 13                 0.583198                  0.846131    0.611247
# 24                 1.000000                  0.000000    0.696570
# 35                 0.000000                  1.000000    0.356098
# 46                 0.000000                  1.000000    0.081553
# 57                 0.074670                  0.112367    0.080130
# 68                 0.052503                  0.159431    0.071075
# 79                 0.927820                  0.770901    0.896931
# 90                 0.664443                  0.571801    0.698450
# 101                0.599997                  0.870037    0.629214
# 112                1.000000                  0.000000    0.758621
# 123                0.963791                  0.116137    0.830021
# 134                1.000000                  0.456250    0.848780
# 145             1009.000000                233.000000  720.000000
# 156                0.300297                  0.313305    0.241667
# 167                0.053603                  0.079801    0.056951
# 178                1.000000                  0.000000    0.918447
# 189                1.000000                  0.000000    0.643902
#
#      SEX_dis_correct  SEX_dis_incorrect    SEX_priv  SEX_priv_correct  \
# 2           1.000000           0.000000    0.797436          1.000000
# 13          0.570675           0.824690    0.634553          0.580480
# 24          1.000000           0.000000    0.724739          1.000000
# 35          0.000000           1.000000    0.350000          0.000000
# 46          0.000000           1.000000    0.100000          0.000000
# 57          0.073578           0.114598    0.081635          0.074689
# 68          0.051777           0.172597    0.072975          0.053895
# 79          0.926281           0.742522    0.899090          0.926206
# 90          0.724855           0.559538    0.629470          0.641977
# 101         0.587301           0.849717    0.652630          0.597396
# 112         1.000000           0.000000    0.818898          1.000000
# 123         0.962793           0.131522    0.789147          0.963103
# 134         1.000000           0.575342    0.793750          1.000000
# 145       605.000000         115.000000  780.000000        622.000000
# 156         0.218182           0.365217    0.325641          0.334405
# 167         0.052547           0.080119    0.058488          0.053488
# 178         1.000000           0.000000    0.900000          1.000000
# 189         1.000000           0.000000    0.650000          1.000000
#
#      SEX_priv_incorrect      overall
# 2              0.000000     0.818000
# 13             0.847421     0.623366
# 24             0.000000     0.713536
# 35             1.000000     0.352381
# 46             1.000000     0.090256
# 57             0.108983     0.080913
# 68             0.148088     0.072063
# 79             0.792342     0.898053
# 90             0.580233     0.662580
# 101            0.870067     0.641390
# 112            0.000000     0.794393
# 123            0.104335     0.808767
# 134            0.410714     0.815238
# 145          158.000000  1500.000000
# 156            0.291139     0.285333
# 167            0.078175     0.057750
# 178            0.000000     0.909744
# 189            0.000000     0.647619
#
# [18 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.9].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR -0.016387  0.077789   0.007141
# 1             Equalized_Odds_FPR -0.011228  0.004746   0.000760
# 2             Equalized_Odds_FNR  0.016387 -0.077789  -0.007141
# 3               Disparate_Impact  1.067680  1.262328   1.177947
# 4  Statistical_Parity_Difference  0.048857  0.182431   0.129137
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.9
# 1  RandomForestClassifier           Exp_iter_1                 0.9
# 2  RandomForestClassifier           Exp_iter_1                 0.9
# 3  RandomForestClassifier           Exp_iter_1                 0.9
# 4  RandomForestClassifier           Exp_iter_1                 0.9

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11   Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 12     Overall_Uncertainty_Parity  RandomForestClassifier
# 13             Equalized_Odds_TPR  RandomForestClassifier
# 14             Equalized_Odds_FPR  RandomForestClassifier
# 15             Equalized_Odds_FNR  RandomForestClassifier
# 16               Disparate_Impact  RandomForestClassifier
# 17  Statistical_Parity_Difference  RandomForestClassifier
# 18                Accuracy_Parity  RandomForestClassifier
# 19          Label_Stability_Ratio  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 0.2    SEX     -0.033003
# 1            Exp_iter_1                 0.2    SEX     -0.016041
# 2            Exp_iter_1                 0.2    SEX      0.033003
# 3            Exp_iter_1                 0.2    SEX      1.038527
# 4            Exp_iter_1                 0.2    SEX      0.029497
# 5            Exp_iter_1                 0.2    SEX      0.036752
# 6            Exp_iter_1                 0.2    SEX      0.995895
# 7            Exp_iter_1                 0.2    SEX     -0.002048
# 8            Exp_iter_1                 0.2    SEX     -0.001658
# 9            Exp_iter_1                 0.2    SEX      0.969420
# 10           Exp_iter_1                 0.2    SEX     -0.000275
# 11           Exp_iter_1                 0.2    SEX     -0.022329
# 12           Exp_iter_1                 0.2    SEX     -0.022623
# 13           Exp_iter_1                 0.2  RAC1P      0.044794
# 14           Exp_iter_1                 0.2  RAC1P     -0.009382
# 15           Exp_iter_1                 0.2  RAC1P     -0.044794
# 16           Exp_iter_1                 0.2  RAC1P      1.166225
# 17           Exp_iter_1                 0.2  RAC1P      0.124036
# 18           Exp_iter_1                 0.2  RAC1P      0.055798
# 19           Exp_iter_1                 0.2  RAC1P      1.021134

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='RAC1P',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio',
                                                              'Jitter_Parity', 'Disparate_Impact'])
# Out:
# alt.VConcatChart(...)
