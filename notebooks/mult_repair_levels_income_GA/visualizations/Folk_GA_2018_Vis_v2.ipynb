# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '16f662aa-e869-43c2-9c15-61648847bd7c'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (72, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3                Accuracy                   101  RandomForestClassifier
# 4   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 5   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 6   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 7   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 8                      F1                   101  RandomForestClassifier
# 9                      F1                   101  RandomForestClassifier
# 10                     F1                   101  RandomForestClassifier
# 11                     F1                   101  RandomForestClassifier
# 12                    FNR                   101  RandomForestClassifier
# 13                    FNR                   101  RandomForestClassifier
# 14                    FNR                   101  RandomForestClassifier
# 15                    FNR                   101  RandomForestClassifier
# 16                    FPR                   101  RandomForestClassifier
# 17                    FPR                   101  RandomForestClassifier
# 18                    FPR                   101  RandomForestClassifier
# 19                    FPR                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income              50  OK 2023-07-22 23:52:23.049
# 1   Folktables_GA_2018_Income              50  OK 2023-07-22 23:57:15.804
# 2   Folktables_GA_2018_Income              50  OK 2023-07-23 00:05:18.174
# 3   Folktables_GA_2018_Income              50  OK 2023-07-23 00:13:24.290
# 4   Folktables_GA_2018_Income              50  OK 2023-07-22 23:52:23.049
# 5   Folktables_GA_2018_Income              50  OK 2023-07-22 23:57:15.804
# 6   Folktables_GA_2018_Income              50  OK 2023-07-23 00:05:18.174
# 7   Folktables_GA_2018_Income              50  OK 2023-07-23 00:13:24.290
# 13         0.000000           1.000000  0.359375          0.000000
# 14         0.000000           1.000000  0.384375          0.000000
# 15         0.000000           1.000000  0.396875          0.000000
# 16         0.000000           1.000000  0.100000          0.000000
# 17         0.000000           1.000000  0.104348          0.000000
# 18         0.000000           1.000000  0.091304          0.000000
# 19         0.000000           1.000000  0.084783          0.000000
#
#     SEX_priv_incorrect   overall
# 0             0.000000  0.818667
# 1             0.000000  0.816667
# 2             0.000000  0.808000
# 3             0.000000  0.805333
# 4             0.837745  0.610723
# 5             0.844347  0.617221
# 6             0.830873  0.613217
# 7             0.828035  0.613064
# 8             0.000000  0.714286
# 9             0.000000  0.711438
# 10            0.000000  0.688985
# 11            0.000000  0.682609
# 12            1.000000  0.352381
# 13            1.000000  0.354286
# 14            1.000000  0.392381
# 15            1.000000  0.401905
# 16            1.000000  0.089231
# 17            1.000000  0.091282
# 18            1.000000  0.084103
# 19            1.000000  0.083077
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [Metric, Bootstrap_Model_Seed, Model_Name, Model_Params, Run_Number, Dataset_Name, Num_Estimators, Tag, Record_Create_Date_Time, Session_Uuid, Experiment_Iteration, Dataset_Split_Seed, Model_Init_Seed, Fair_Intervention_Params_Lst, Intervention_Param, RAC1P_dis, RAC1P_dis_correct, RAC1P_dis_incorrect, RAC1P_priv, RAC1P_priv_correct, RAC1P_priv_incorrect, SEX&RAC1P_dis, SEX&RAC1P_dis_correct, SEX&RAC1P_dis_incorrect, SEX&RAC1P_priv, SEX&RAC1P_priv_correct, SEX&RAC1P_priv_incorrect, SEX_dis, SEX_dis_correct, SEX_dis_incorrect, SEX_priv, SEX_priv_correct, SEX_priv_incorrect, overall]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.3].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 1                Accuracy                   101  RandomForestClassifier
# 5   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 9                      F1                   101  RandomForestClassifier
# 13                    FNR                   101  RandomForestClassifier
# 17                    FPR                   101  RandomForestClassifier
# 21                    IQR                   101  RandomForestClassifier
# 25                 Jitter                   101  RandomForestClassifier
# 29        Label_Stability                   101  RandomForestClassifier
# 33                   Mean                   101  RandomForestClassifier
# 37    Overall_Uncertainty                   101  RandomForestClassifier
# 41                    PPV                   101  RandomForestClassifier
# 45    Per_Sample_Accuracy                   101  RandomForestClassifier
# 49          Positive-Rate                   101  RandomForestClassifier
# 53            Sample_Size                   101  RandomForestClassifier
# 57         Selection-Rate                   101  RandomForestClassifier
# 61                    Std                   101  RandomForestClassifier
# 65                    TNR                   101  RandomForestClassifier
# 69                    TPR                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
# 49                1.000000                  0.451220    0.853659
# 53             1004.000000                238.000000  720.000000
# 57                0.297809                  0.310924    0.243056
# 61                0.061694                  0.089923    0.065151
# 65                1.000000                  0.000000    0.920388
# 69                1.000000                  0.000000    0.653659
#
#     SEX_dis_correct  SEX_dis_incorrect    SEX_priv  SEX_priv_correct  \
# 1          1.000000           0.000000    0.791026          1.000000
# 5          0.568251           0.817015    0.626704          0.569207
# 9          1.000000           0.000000    0.715532          1.000000
# 13         0.000000           1.000000    0.359375          0.000000
# 17         0.000000           1.000000    0.104348          0.000000
# 21         0.084259           0.118460    0.090824          0.082246
# 25         0.062466           0.177485    0.080786          0.055345
# 29         0.912697           0.750357    0.890205          0.927715
# 33         0.720431           0.558089    0.626916          0.640885
# 37         0.590850           0.846160    0.651089          0.592089
# 41         1.000000           0.000000    0.810277          1.000000
# 45         0.956020           0.124821    0.788949          0.963857
# 49         1.000000           0.577465    0.790625          1.000000
# 53       608.000000         112.000000  780.000000        617.000000
# 57         0.220395           0.366071    0.324359          0.332253
# 61         0.061194           0.086631    0.067263          0.061192
# 65         1.000000           0.000000    0.895652          1.000000
# 69         1.000000           0.000000    0.640625          1.000000
#
#     SEX_priv_incorrect      overall
# 1             0.000000     0.816667
# 5             0.844347     0.617221
# 9             0.000000     0.711438
# 13            1.000000     0.354286
# 17            1.000000     0.091282
# 21            0.123295     0.090226
# 25            0.177088     0.080581
# 29            0.748221     0.888880
# 33            0.574037     0.659681
# 37            0.874420     0.641237
# 41            0.000000     0.792056
# 45            0.126871     0.807080
# 49            0.417391     0.815238
# 53          163.000000  1500.000000
# 57            0.294479     0.285333
# 61            0.090243     0.066249
# 65            0.000000     0.908718
# 69            0.000000     0.645714
#
# [18 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.9].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR -0.012881  0.087980   0.035080
# 1             Equalized_Odds_FPR -0.003229  0.005929   0.004578
# 2             Equalized_Odds_FNR  0.012881 -0.087980  -0.035080
# 3               Disparate_Impact  1.096720  1.281230   1.233609
# 4  Statistical_Parity_Difference  0.070122  0.197718   0.171044
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.9
# 1  RandomForestClassifier           Exp_iter_1                 0.9
# 2  RandomForestClassifier           Exp_iter_1                 0.9
# 3  RandomForestClassifier           Exp_iter_1                 0.9
# 4  RandomForestClassifier           Exp_iter_1                 0.9

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11   Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 12     Overall_Uncertainty_Parity  RandomForestClassifier
# 13             Equalized_Odds_TPR  RandomForestClassifier
# 14             Equalized_Odds_FPR  RandomForestClassifier
# 15             Equalized_Odds_FNR  RandomForestClassifier
# 16               Disparate_Impact  RandomForestClassifier
# 17  Statistical_Parity_Difference  RandomForestClassifier
# 18                Accuracy_Parity  RandomForestClassifier
# 19          Label_Stability_Ratio  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 0.0    SEX      0.001905
# 1            Exp_iter_1                 0.0    SEX     -0.020388
# 2            Exp_iter_1                 0.0    SEX     -0.001905
# 3            Exp_iter_1                 0.0    SEX      1.073556
# 4            Exp_iter_1                 0.0    SEX      0.058155
# 5            Exp_iter_1                 0.0    SEX      0.046902
# 6            Exp_iter_1                 0.0    SEX      0.995887
# 7            Exp_iter_1                 0.0    SEX      0.000341
# 8            Exp_iter_1                 0.0    SEX     -0.001065
# 9            Exp_iter_1                 0.0    SEX      0.984251
# 10           Exp_iter_1                 0.0    SEX      0.000917
# 11           Exp_iter_1                 0.0    SEX     -0.019796
# 12           Exp_iter_1                 0.0    SEX     -0.019773
# 13           Exp_iter_1                 0.0  RAC1P      0.011818
# 14           Exp_iter_1                 0.0  RAC1P     -0.017038
# 15           Exp_iter_1                 0.0  RAC1P     -0.011818
# 16           Exp_iter_1                 0.0  RAC1P      1.095432
# 17           Exp_iter_1                 0.0  RAC1P      0.075813
# 18           Exp_iter_1                 0.0  RAC1P      0.047050
# 19           Exp_iter_1                 0.0  RAC1P      1.026769

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='RAC1P',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio',
                                                              'Jitter_Parity', 'Disparate_Impact'])
# Out:
# alt.VConcatChart(...)
