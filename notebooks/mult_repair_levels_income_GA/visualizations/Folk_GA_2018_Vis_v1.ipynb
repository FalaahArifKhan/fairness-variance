# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '78c3da49-e095-43f3-8cc1-fa34bab0357c'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (1188, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  RandomForestClassifier
# 1   Accuracy                   101  RandomForestClassifier
# 2   Accuracy                   101  RandomForestClassifier
# 3   Accuracy                   101  RandomForestClassifier
# 4   Accuracy                   101  RandomForestClassifier
# 5   Accuracy                   101  RandomForestClassifier
# 6   Accuracy                   101  RandomForestClassifier
# 7   Accuracy                   101  RandomForestClassifier
# 8   Accuracy                   101  RandomForestClassifier
# 9   Accuracy                   101  RandomForestClassifier
# 10  Accuracy                   101  RandomForestClassifier
# 11  Accuracy                   201  RandomForestClassifier
# 12  Accuracy                   201  RandomForestClassifier
# 13  Accuracy                   201  RandomForestClassifier
# 14  Accuracy                   201  RandomForestClassifier
# 15  Accuracy                   201  RandomForestClassifier
# 16  Accuracy                   201  RandomForestClassifier
# 17  Accuracy                   201  RandomForestClassifier
# 18  Accuracy                   201  RandomForestClassifier
# 19  Accuracy                   201  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 4   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 15  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income             200  OK 2023-07-18 11:35:29.212
# 1   Folktables_GA_2018_Income             200  OK 2023-07-18 16:39:30.404
# 2   Folktables_GA_2018_Income             200  OK 2023-07-18 00:42:39.317
# 3   Folktables_GA_2018_Income             200  OK 2023-07-18 11:07:08.956
# 4   Folktables_GA_2018_Income             200  OK 2023-07-18 11:07:47.852
# 5   Folktables_GA_2018_Income             200  OK 2023-07-18 00:10:59.799
# 6   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 7   Folktables_GA_2018_Income             200  OK 2023-07-17 23:00:07.102
# 8   Folktables_GA_2018_Income             200  OK 2023-07-18 11:05:56.008
# 9   Folktables_GA_2018_Income             200  OK 2023-07-18 15:03:09.521
# 10  Folktables_GA_2018_Income             200  OK 2023-07-18 03:27:08.856
# 11  Folktables_GA_2018_Income             200  OK 2023-07-18 21:49:19.939
# 12  Folktables_GA_2018_Income             200  OK 2023-07-18 20:47:26.106
# 13  Folktables_GA_2018_Income             200  OK 2023-07-18 20:53:01.571
# 14  Folktables_GA_2018_Income             200  OK 2023-07-18 16:28:22.364
# 15  Folktables_GA_2018_Income             200  OK 2023-07-18 18:09:44.991
# 16  Folktables_GA_2018_Income             200  OK 2023-07-19 12:23:47.322
# 17  Folktables_GA_2018_Income             200  OK 2023-07-19 00:21:42.315
# 18  Folktables_GA_2018_Income             200  OK 2023-07-18 15:03:46.443
# 19  Folktables_GA_2018_Income             200  OK 2023-07-18 17:11:21.785
#
#                             Session_Uuid  ... SEX&RAC1P_priv  \
# 0   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.787477
# 1   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.789886
# 2   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.790488
# 3   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.788682
# 4   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.791090
# 5   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.793498
# 6   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.790488
# 7   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.787477
# 8   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.789886
# 9   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.790488
# 10  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.791692
# 11  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.807715
# 12  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.808902
# 13  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.808902
# 14  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.810089
# 15  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.811276
# 16  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.811869
# 17  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.805935
# 18  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.808309
# 19  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.807715
#
#     SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect   SEX_dis  \
# 0                      1.0                       0.0  0.829032
# 1                      1.0                       0.0  0.825806
# 2                      1.0                       0.0  0.826882
# 3                      1.0                       0.0  0.827957
# 4                      1.0                       0.0  0.831183
# 5                      1.0                       0.0  0.833333
# 6                      1.0                       0.0  0.819355
# 7                      1.0                       0.0  0.825806
# 8                      1.0                       0.0  0.824731
# 9                      1.0                       0.0  0.824731
# 10                     1.0                       0.0  0.823656
# 11                     1.0                       0.0  0.836458
# 12                     1.0                       0.0  0.835417
# 13                     1.0                       0.0  0.837500
# 14                     1.0                       0.0  0.839583
# 15                     1.0                       0.0  0.836458
# 16                     1.0                       0.0  0.841667
# 17                     1.0                       0.0  0.833333
# 18                     1.0                       0.0  0.835417
# 19                     1.0                       0.0  0.835417
#
#     SEX_dis_correct  SEX_dis_incorrect  SEX_priv  SEX_priv_correct  \
# 0               1.0                0.0  0.765421               1.0
# 1               1.0                0.0  0.771028               1.0
# 2               1.0                0.0  0.772897               1.0
# 3               1.0                0.0  0.767290               1.0
# 4               1.0                0.0  0.769159               1.0
# 5               1.0                0.0  0.774766               1.0
# 6               1.0                0.0  0.775701               1.0
# 7               1.0                0.0  0.767290               1.0
# 8               1.0                0.0  0.772897               1.0
# 9               1.0                0.0  0.771963               1.0
# 10              1.0                0.0  0.775701               1.0
# 11              1.0                0.0  0.787500               1.0
# 12              1.0                0.0  0.790385               1.0
# 13              1.0                0.0  0.788462               1.0
# 14              1.0                0.0  0.788462               1.0
# 15              1.0                0.0  0.793269               1.0
# 16              1.0                0.0  0.796154               1.0
# 17              1.0                0.0  0.787500               1.0
# 18              1.0                0.0  0.788462               1.0
# 19              1.0                0.0  0.787500               1.0
#
#     SEX_priv_incorrect  overall
# 0                  0.0   0.7950
# 1                  0.0   0.7965
# 2                  0.0   0.7980
# 3                  0.0   0.7955
# 4                  0.0   0.7980
# 5                  0.0   0.8020
# 6                  0.0   0.7960
# 7                  0.0   0.7945
# 8                  0.0   0.7970
# 9                  0.0   0.7965
# 10                 0.0   0.7980
# 11                 0.0   0.8110
# 12                 0.0   0.8120
# 13                 0.0   0.8120
# 14                 0.0   0.8130
# 15                 0.0   0.8140
# 16                 0.0   0.8180
# 17                 0.0   0.8095
# 18                 0.0   0.8110
# 19                 0.0   0.8105
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
#                                                                             865
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# Run_Number                                                                Run_1
# Dataset_Name                                          Folktables_GA_2018_Income
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-07-17 23:00:07.102000
# Session_Uuid                               78c3da49-e095-43f3-8cc1-fa34bab0357c
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                                         [0.1, 0.9]
# Intervention_Param                                                          0.1
# RAC1P_dis                                                                 644.0
# RAC1P_dis_correct                                                         521.0
# RAC1P_dis_incorrect                                                       123.0
# RAC1P_priv                                                               1356.0
# RAC1P_priv_correct                                                       1068.0
# RAC1P_priv_incorrect                                                      288.0
# SEX&RAC1P_dis                                                             339.0
# SEX&RAC1P_dis_correct                                                     281.0
# SEX&RAC1P_dis_incorrect                                                    58.0
# SEX&RAC1P_priv                                                           1661.0
# SEX&RAC1P_priv_correct                                                   1308.0
# SEX&RAC1P_priv_incorrect                                                  353.0
# SEX_dis                                                                   930.0
# SEX_dis_correct                                                           768.0
# SEX_dis_incorrect                                                         162.0
# SEX_priv                                                                 1070.0
# SEX_priv_correct                                                          821.0
# SEX_priv_incorrect                                                        249.0
# overall                                                                  2000.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.2].head(20)
# Out:
#                      Metric  Bootstrap_Model_Seed              Model_Name  \
# 6                  Accuracy                   101  RandomForestClassifier
# 72    Aleatoric_Uncertainty                   101  RandomForestClassifier
# 138                      F1                   101  RandomForestClassifier
# 204                     FNR                   101  RandomForestClassifier
# 270                     FPR                   101  RandomForestClassifier
# 336                     IQR                   101  RandomForestClassifier
# 402                  Jitter                   101  RandomForestClassifier
# 468         Label_Stability                   101  RandomForestClassifier
# 534                    Mean                   101  RandomForestClassifier
# 600     Overall_Uncertainty                   101  RandomForestClassifier
# 666                     PPV                   101  RandomForestClassifier
# 732     Per_Sample_Accuracy                   101  RandomForestClassifier
# 798           Positive-Rate                   101  RandomForestClassifier
# 864             Sample_Size                   101  RandomForestClassifier
# 930          Selection-Rate                   101  RandomForestClassifier
# 996                     Std                   101  RandomForestClassifier
# 1062                    TNR                   101  RandomForestClassifier
# 1128                    TPR                   101  RandomForestClassifier
#
#                                            Model_Params Run_Number  \
# 6     {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 72    {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 138   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 204   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 270   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 336   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 402   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 468   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 534   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 600   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 666   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 732   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 798   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 864   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 930   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 996   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1062  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1128  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                    Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 6     Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 72    Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 138   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 204   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 270   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 336   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 402   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 468   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 534   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 600   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 666   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 732   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 798   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 864   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 930   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 996   Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 1062  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
# 1128  Folktables_GA_2018_Income             200  OK 2023-07-18 00:17:05.545
#
#                               Session_Uuid  ... SEX&RAC1P_priv  \
# 6     78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.790488
# 72    78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.677995
# 138   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.706081
# 204   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.319218
# 270   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.145177
# 336   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.066470
# 402   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.072810
# 468   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.894551
# 534   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.624910
# 600   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.689381
# 666   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.733333
# 732   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.785620
# 798   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.928339
# 864   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...    1661.000000
# 930   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.343167
# 996   78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.048160
# 1062  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.854823
# 1128  78c3da49-e095-43f3-8cc1-fa34bab0357c  ...       0.680782
#
#       SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect     SEX_dis  \
# 6                   1.000000                  0.000000    0.819355
# 72                  0.625828                  0.874819    0.633203
# 138                 1.000000                  0.000000    0.629956
# 204                 0.000000                  1.000000    0.454198
# 270                 0.000000                  1.000000    0.073353
# 336                 0.060717                  0.088179    0.060790
# 402                 0.051102                  0.154711    0.055381
# 468                 0.927091                  0.771782    0.921097
# 534                 0.649701                  0.531378    0.724816
# 600                 0.636390                  0.889313    0.643582
# 666                 1.000000                  0.000000    0.744792
# 732                 0.963507                  0.114454    0.818462
# 798                 1.000000                  0.775510    0.732824
# 864              1313.000000                348.000000  930.000000
# 930                 0.318355                  0.436782    0.206452
# 996                 0.044087                  0.063528    0.044146
# 1062                1.000000                  0.000000    0.926647
# 1128                1.000000                  0.000000    0.545802
#
#       SEX_dis_correct  SEX_dis_incorrect     SEX_priv  SEX_priv_correct  \
# 6            1.000000           0.000000     0.775701          1.000000
# 72           0.584811           0.852695     0.696019          0.643167
# 138          1.000000           0.000000     0.718970          1.000000
# 204          0.000000           1.000000     0.295872          0.000000
# 270          0.000000           1.000000     0.175079          0.000000
# 336          0.055284           0.085767     0.069653          0.063922
# 402          0.036160           0.142563     0.082000          0.060439
# 468          0.950486           0.787798     0.881514          0.912723
# 534          0.753948           0.592681     0.584189          0.603191
# 600          0.594348           0.866893     0.708135          0.654525
# 666          1.000000           0.000000     0.734450          1.000000
# 732          0.975243           0.107351     0.767252          0.956301
# 798          1.000000           0.411765     0.958716          1.000000
# 864        762.000000         168.000000  1070.000000        830.000000
# 930          0.187664           0.291667     0.390654          0.369880
# 996          0.040194           0.062075     0.050388          0.046367
# 1062         1.000000           0.000000     0.824921          1.000000
# 1128         1.000000           0.000000     0.704128          1.000000
#
#       SEX_priv_incorrect      overall
# 6               0.000000     0.796000
# 72              0.878797     0.666810
# 138             0.000000     0.688073
# 204             1.000000     0.355301
# 270             1.000000     0.122888
# 336             0.089474     0.065532
# 402             0.156566     0.069622
# 468             0.773583     0.899920
# 534             0.518473     0.649581
# 600             0.893538     0.678118
# 666             0.000000     0.737705
# 732             0.113458     0.791065
# 798             0.860465     0.873926
# 864           240.000000  2000.000000
# 930             0.462500     0.305000
# 996             0.064295     0.047486
# 1062            0.000000     0.877112
# 1128            0.000000     0.644699
#
# [18 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.5].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR -0.124729 -0.262252  -0.279277
# 1             Equalized_Odds_FPR -0.112686 -0.103790  -0.118580
# 2             Equalized_Odds_FNR  0.124729  0.262252   0.279277
# 3               Disparate_Impact  0.782651  0.624367   0.532062
# 4  Statistical_Parity_Difference -0.209871 -0.368410  -0.439739
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.5
# 1  RandomForestClassifier           Exp_iter_1                 0.5
# 2  RandomForestClassifier           Exp_iter_1                 0.5
# 3  RandomForestClassifier           Exp_iter_1                 0.5
# 4  RandomForestClassifier           Exp_iter_1                 0.5

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11   Aleatoric_Uncertainty_Parity  RandomForestClassifier
# 12     Overall_Uncertainty_Parity  RandomForestClassifier
# 13             Equalized_Odds_TPR  RandomForestClassifier
# 14             Equalized_Odds_FPR  RandomForestClassifier
# 15             Equalized_Odds_FNR  RandomForestClassifier
# 16               Disparate_Impact  RandomForestClassifier
# 17  Statistical_Parity_Difference  RandomForestClassifier
# 18                Accuracy_Parity  RandomForestClassifier
# 19          Label_Stability_Ratio  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 1.0    SEX     -0.124729
# 1            Exp_iter_1                 1.0    SEX     -0.117338
# 2            Exp_iter_1                 1.0    SEX      0.124729
# 3            Exp_iter_1                 1.0    SEX      0.775017
# 4            Exp_iter_1                 1.0    SEX     -0.218275
# 5            Exp_iter_1                 1.0    SEX      0.063612
# 6            Exp_iter_1                 1.0    SEX      1.053378
# 7            Exp_iter_1                 1.0    SEX     -0.011239
# 8            Exp_iter_1                 1.0    SEX     -0.007844
# 9            Exp_iter_1                 1.0    SEX      0.870125
# 10           Exp_iter_1                 1.0    SEX     -0.030372
# 11           Exp_iter_1                 1.0    SEX     -0.064423
# 12           Exp_iter_1                 1.0    SEX     -0.067090
# 13           Exp_iter_1                 1.0  RAC1P     -0.247169
# 14           Exp_iter_1                 1.0  RAC1P     -0.098302
# 15           Exp_iter_1                 1.0  RAC1P      0.247169
# 16           Exp_iter_1                 1.0  RAC1P      0.651109
# 17           Exp_iter_1                 1.0  RAC1P     -0.340169
# 18           Exp_iter_1                 1.0  RAC1P      0.016078
# 19           Exp_iter_1                 1.0  RAC1P      1.018104

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='RAC1P',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio', 'Jitter_Parity'])
# Out:
# alt.VConcatChart(...)
