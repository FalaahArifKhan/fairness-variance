# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Law_School'
EXPERIMENT_SESSION_UUID = '9430484b-bec6-42a0-ac65-11c53446a61f'
SENSITIVE_ATTRS = ['male', 'race', 'male&race']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (1254, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  RandomForestClassifier
# 1   Accuracy                   101  RandomForestClassifier
# 2   Accuracy                   101  RandomForestClassifier
# 3   Accuracy                   101  RandomForestClassifier
# 4   Accuracy                   101  RandomForestClassifier
# 5   Accuracy                   101  RandomForestClassifier
# 6   Accuracy                   101  RandomForestClassifier
# 7   Accuracy                   101  RandomForestClassifier
# 8   Accuracy                   101  RandomForestClassifier
# 9   Accuracy                   101  RandomForestClassifier
# 10  Accuracy                   101  RandomForestClassifier
# 11  Accuracy                   201  RandomForestClassifier
# 12  Accuracy                   201  RandomForestClassifier
# 13  Accuracy                   201  RandomForestClassifier
# 14  Accuracy                   201  RandomForestClassifier
# 15  Accuracy                   201  RandomForestClassifier
# 16  Accuracy                   201  RandomForestClassifier
# 17  Accuracy                   201  RandomForestClassifier
# 18  Accuracy                   201  RandomForestClassifier
# 19  Accuracy                   201  RandomForestClassifier
#
#                                          Model_Params Run_Number Dataset_Name  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 4   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 5   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 6   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 7   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 8   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 9   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1   Law_School
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 15  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 16  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 17  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 18  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 19  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0              200  OK 2023-08-06 20:24:49.316
# 1              200  OK 2023-08-06 20:42:39.570
# 2              200  OK 2023-08-06 20:11:09.736
# 3              200  OK 2023-08-06 20:06:36.458
# 4              200  OK 2023-08-06 17:01:48.157
# 5              200  OK 2023-08-06 20:24:54.964
# 6              200  OK 2023-08-06 20:27:22.026
# 7              200  OK 2023-08-06 16:29:29.723
# 8              200  OK 2023-08-06 20:05:50.892
# 9              200  OK 2023-08-06 16:11:50.781
# 10             200  OK 2023-08-06 20:17:50.239
# 11             200  OK 2023-08-06 22:47:26.303
# 12             200  OK 2023-08-06 22:57:45.882
# 13             200  OK 2023-08-06 22:40:27.680
# 14             200  OK 2023-08-06 22:54:27.644
# 15             200  OK 2023-08-06 22:16:28.017
# 16             200  OK 2023-08-06 22:23:22.847
# 17             200  OK 2023-08-06 22:42:46.501
# 18             200  OK 2023-08-06 22:46:10.416
# 19             200  OK 2023-08-06 23:04:38.802
#
#                             Session_Uuid  ... male_priv  male_priv_correct  \
# 0   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.910435                1.0
# 1   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.907826                1.0
# 2   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.907826                1.0
# 3   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.907826                1.0
# 4   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.904348                1.0
# 5   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.905217                1.0
# 6   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.912174                1.0
# 7   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.908696                1.0
# 8   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.907826                1.0
# 9   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.907826                1.0
# 10  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.910435                1.0
# 11  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.916037                1.0
# 12  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.912678                1.0
# 13  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.916037                1.0
# 14  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.912678                1.0
# 15  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.911839                1.0
# 16  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.916037                1.0
# 17  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.919395                1.0
# 18  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.915197                1.0
# 19  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.919395                1.0
#
#     male_priv_incorrect   overall  race_dis  race_dis_correct  \
# 0                   0.0  0.899519  0.755747               1.0
# 1                   0.0  0.898558  0.764368               1.0
# 2                   0.0  0.898558  0.758621               1.0
# 3                   0.0  0.898558  0.747126               1.0
# 4                   0.0  0.896154  0.755747               1.0
# 5                   0.0  0.896154  0.761494               1.0
# 6                   0.0  0.900481  0.761494               1.0
# 7                   0.0  0.897596  0.764368               1.0
# 8                   0.0  0.898077  0.752874               1.0
# 9                   0.0  0.898077  0.770115               1.0
# 10                  0.0  0.900000  0.764368               1.0
# 11                  0.0  0.908173  0.806349               1.0
# 12                  0.0  0.907692  0.800000               1.0
# 13                  0.0  0.907212  0.793651               1.0
# 14                  0.0  0.907212  0.806349               1.0
# 15                  0.0  0.907212  0.793651               1.0
# 16                  0.0  0.909615  0.803175               1.0
# 17                  0.0  0.910577  0.806349               1.0
# 18                  0.0  0.908654  0.796825               1.0
# 19                  0.0  0.910096  0.800000               1.0
#
#     race_dis_incorrect  race_priv  race_priv_correct  race_priv_incorrect
# 0                  0.0   0.928406                1.0                  0.0
# 1                  0.0   0.925520                1.0                  0.0
# 2                  0.0   0.926674                1.0                  0.0
# 3                  0.0   0.928984                1.0                  0.0
# 4                  0.0   0.924365                1.0                  0.0
# 5                  0.0   0.923210                1.0                  0.0
# 6                  0.0   0.928406                1.0                  0.0
# 7                  0.0   0.924365                1.0                  0.0
# 8                  0.0   0.927252                1.0                  0.0
# 9                  0.0   0.923788                1.0                  0.0
# 10                 0.0   0.927252                1.0                  0.0
# 11                 0.0   0.926346                1.0                  0.0
# 12                 0.0   0.926912                1.0                  0.0
# 13                 0.0   0.927479                1.0                  0.0
# 14                 0.0   0.925212                1.0                  0.0
# 15                 0.0   0.927479                1.0                  0.0
# 16                 0.0   0.928612                1.0                  0.0
# 17                 0.0   0.929178                1.0                  0.0
# 18                 0.0   0.928612                1.0                  0.0
# 19                 0.0   0.929745                1.0                  0.0
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.2)].T
# Out:
#                                                                             865
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...
# Run_Number                                                                Run_1
# Dataset_Name                                                         Law_School
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-08-06 16:29:29.723000
# Session_Uuid                               9430484b-bec6-42a0-ac65-11c53446a61f
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                                    [0.0, 0.2, 0.4]
# Intervention_Param                                                          0.2
# male&race_dis                                                             172.0
# male&race_dis_correct                                                     130.0
# male&race_dis_incorrect                                                    42.0
# male&race_priv                                                           1908.0
# male&race_priv_correct                                                   1737.0
# male&race_priv_incorrect                                                  171.0
# male_dis                                                                  930.0
# male_dis_correct                                                          822.0
# male_dis_incorrect                                                        108.0
# male_priv                                                                1150.0
# male_priv_correct                                                        1045.0
# male_priv_incorrect                                                       105.0
# overall                                                                  2080.0
# race_dis                                                                  348.0
# race_dis_correct                                                          266.0
# race_dis_incorrect                                                         82.0
# race_priv                                                                1732.0
# race_priv_correct                                                        1601.0
# race_priv_incorrect                                                       131.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11             Equalized_Odds_TPR  RandomForestClassifier
# 12             Equalized_Odds_FPR  RandomForestClassifier
# 13             Equalized_Odds_FNR  RandomForestClassifier
# 14               Disparate_Impact  RandomForestClassifier
# 15  Statistical_Parity_Difference  RandomForestClassifier
# 16                Accuracy_Parity  RandomForestClassifier
# 17          Label_Stability_Ratio  RandomForestClassifier
# 18                     IQR_Parity  RandomForestClassifier
# 19                     Std_Parity  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param Group  Metric_Value
# 0            Exp_iter_1                 0.8  male     -0.004913
# 1            Exp_iter_1                 0.8  male      0.044118
# 2            Exp_iter_1                 0.8  male      0.004913
# 3            Exp_iter_1                 0.8  male      1.019277
# 4            Exp_iter_1                 0.8  male      0.020492
# 5            Exp_iter_1                 0.8  male     -0.024413
# 6            Exp_iter_1                 0.8  male      1.004173
# 7            Exp_iter_1                 0.8  male     -0.004060
# 8            Exp_iter_1                 0.8  male     -0.002787
# 9            Exp_iter_1                 0.8  male      0.943639
# 10           Exp_iter_1                 0.8  male     -0.001791
# 11           Exp_iter_1                 0.8  race     -0.092666
# 12           Exp_iter_1                 0.8  race     -0.222222
# 13           Exp_iter_1                 0.8  race      0.092666
# 14           Exp_iter_1                 0.8  race      1.075152
# 15           Exp_iter_1                 0.8  race      0.079764
# 16           Exp_iter_1                 0.8  race     -0.172659
# 17           Exp_iter_1                 0.8  race      0.884930
# 18           Exp_iter_1                 0.8  race      0.047657
# 19           Exp_iter_1                 0.8  race      0.032461

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='race_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='race_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Std',
                                                   group='race',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Label_Stability',
                                                   group='race',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='race',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Std_Parity', 'Label_Stability_Ratio'])
# Out:
# alt.VConcatChart(...)
