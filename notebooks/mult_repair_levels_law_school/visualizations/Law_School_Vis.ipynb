# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/dh3553/projects/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Law_School'
EXPERIMENT_SESSION_UUID = '9430484b-bec6-42a0-ac65-11c53446a61f'
SENSITIVE_ATTRS = ['male', 'race', 'male&race']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (57, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 4   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 5   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 6                      F1                   101  RandomForestClassifier
# 7                      F1                   101  RandomForestClassifier
# 8                      F1                   101  RandomForestClassifier
# 9                     FNR                   101  RandomForestClassifier
# 10                    FNR                   101  RandomForestClassifier
# 11                    FNR                   101  RandomForestClassifier
# 12                    FPR                   101  RandomForestClassifier
# 13                    FPR                   101  RandomForestClassifier
# 14                    FPR                   101  RandomForestClassifier
# 15                    IQR                   101  RandomForestClassifier
# 16                    IQR                   101  RandomForestClassifier
# 17                    IQR                   101  RandomForestClassifier
# 18                 Jitter                   101  RandomForestClassifier
# 19                 Jitter                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number Dataset_Name  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 4   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 5   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 6   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 7   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 8   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 9   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 10  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 15  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 16  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 17  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 18  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
# 19  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1   Law_School
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0              200  OK 2023-08-06 17:01:48.157
# 1              200  OK 2023-08-06 16:29:29.723
# 2              200  OK 2023-08-06 16:11:50.781
# 3              200  OK 2023-08-06 17:01:48.157
# 4              200  OK 2023-08-06 16:29:29.723
# 5              200  OK 2023-08-06 16:11:50.781
# 6              200  OK 2023-08-06 17:01:48.157
# 7              200  OK 2023-08-06 16:29:29.723
# 8              200  OK 2023-08-06 16:11:50.781
# 9              200  OK 2023-08-06 17:01:48.157
# 10             200  OK 2023-08-06 16:29:29.723
# 11             200  OK 2023-08-06 16:11:50.781
# 12             200  OK 2023-08-06 17:01:48.157
# 13             200  OK 2023-08-06 16:29:29.723
# 14             200  OK 2023-08-06 16:11:50.781
# 15             200  OK 2023-08-06 17:01:48.157
# 16             200  OK 2023-08-06 16:29:29.723
# 17             200  OK 2023-08-06 16:11:50.781
# 18             200  OK 2023-08-06 17:01:48.157
# 19             200  OK 2023-08-06 16:29:29.723
#
#                             Session_Uuid  ... male_priv  male_priv_correct  \
# 0   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.904348           1.000000
# 1   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.908696           1.000000
# 2   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.907826           1.000000
# 3   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.358458           0.314899
# 4   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.347945           0.307089
# 5   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.324111           0.282911
# 6   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.948064           1.000000
# 7   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.950355           1.000000
# 8   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.949858           1.000000
# 9   9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.026188           0.000000
# 10  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.025218           0.000000
# 11  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.026188           0.000000
# 12  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.697479           0.000000
# 13  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.663866           0.000000
# 14  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.663866           0.000000
# 15  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.062478           0.055115
# 16  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.057385           0.051111
# 17  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.061464           0.054210
# 18  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.038091           0.023868
# 19  9430484b-bec6-42a0-ac65-11c53446a61f  ...  0.033700           0.021580
#
#     male_priv_incorrect   overall  race_dis  race_dis_correct  \
# 0              0.000000  0.896154  0.755747          1.000000
# 1              0.000000  0.897596  0.764368          1.000000
# 2              0.000000  0.898077  0.770115          1.000000
# 3              0.770281  0.351636  0.609990          0.531928
# 4              0.754565  0.343515  0.611949          0.538078
# 5              0.729894  0.322009  0.599103          0.526544
# 6              0.000000  0.943396  0.839319          1.000000
# 7              0.000000  0.944109  0.842308          1.000000
# 8              0.000000  0.944269  0.843750          1.000000
# 9              1.000000  0.024390  0.104839          0.000000
# 10             1.000000  0.024932  0.116935          0.000000
# 11             1.000000  0.026558  0.129032          0.000000
# 12             1.000000  0.727660  0.590000          0.000000
# 13             1.000000  0.710638  0.530000          0.000000
# 14             1.000000  0.693617  0.480000          0.000000
# 15             0.132098  0.061592  0.102397          0.090982
# 16             0.119819  0.057210  0.100267          0.090347
# 17             0.132910  0.060659  0.106325          0.096073
# 18             0.172566  0.038247  0.103303          0.066906
# 19             0.154325  0.035388  0.104269          0.069887
#
#     race_dis_incorrect  race_priv  race_priv_correct  race_priv_incorrect
# 0             0.000000   0.924365           1.000000             0.000000
# 1             0.000000   0.924365           1.000000             0.000000
# 2             0.000000   0.923788           1.000000             0.000000
# 3             0.851524   0.299726           0.269759             0.665971
# 4             0.851579   0.289581           0.259033             0.662915
# 5             0.842176   0.266334           0.235372             0.641628
# 6             0.000000   0.960146           1.000000             0.000000
# 7             0.000000   0.960194           1.000000             0.000000
# 8             0.000000   0.959903           1.000000             0.000000
# 9             1.000000   0.011897           0.000000             1.000000
# 10            1.000000   0.010645           0.000000             1.000000
# 11            1.000000   0.010645           0.000000             1.000000
# 12            1.000000   0.829630           0.000000             1.000000
# 13            1.000000   0.844444           0.000000             1.000000
# 14            1.000000   0.851852           0.000000             1.000000
# 15            0.137717   0.053394           0.047803             0.121722
# 16            0.132445   0.048559           0.043386             0.111779
# 17            0.140669   0.051484           0.045652             0.122174
# 18            0.215918   0.025175           0.016794             0.127603
# 19            0.215802   0.021548           0.012982             0.126230
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.2)].T
# Out:
#                                                                              40
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...
# Run_Number                                                                Run_1
# Dataset_Name                                                         Law_School
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-08-06 16:29:29.723000
# Session_Uuid                               9430484b-bec6-42a0-ac65-11c53446a61f
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                                    [0.0, 0.2, 0.4]
# Intervention_Param                                                          0.2
# male&race_dis                                                             172.0
# male&race_dis_correct                                                     130.0
# male&race_dis_incorrect                                                    42.0
# male&race_priv                                                           1908.0
# male&race_priv_correct                                                   1737.0
# male&race_priv_incorrect                                                  171.0
# male_dis                                                                  930.0
# male_dis_correct                                                          822.0
# male_dis_incorrect                                                        108.0
# male_priv                                                                1150.0
# male_priv_correct                                                        1045.0
# male_priv_incorrect                                                       105.0
# overall                                                                  2080.0
# race_dis                                                                  348.0
# race_dis_correct                                                          266.0
# race_dis_incorrect                                                         82.0
# race_priv                                                                1732.0
# race_priv_correct                                                        1601.0
# race_priv_incorrect                                                       131.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11             Equalized_Odds_TPR  RandomForestClassifier
# 12             Equalized_Odds_FPR  RandomForestClassifier
# 13             Equalized_Odds_FNR  RandomForestClassifier
# 14               Disparate_Impact  RandomForestClassifier
# 15  Statistical_Parity_Difference  RandomForestClassifier
# 16                Accuracy_Parity  RandomForestClassifier
# 17          Label_Stability_Ratio  RandomForestClassifier
# 18                     IQR_Parity  RandomForestClassifier
# 19                     Std_Parity  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param Group  Metric_Value
# 0            Exp_iter_1                 0.4  male      0.004075
# 1            Exp_iter_1                 0.4  male      0.061142
# 2            Exp_iter_1                 0.4  male     -0.004075
# 3            Exp_iter_1                 0.4  male      1.030047
# 4            Exp_iter_1                 0.4  male      0.031679
# 5            Exp_iter_1                 0.4  male     -0.018326
# 6            Exp_iter_1                 0.4  male      1.000066
# 7            Exp_iter_1                 0.4  male     -0.001982
# 8            Exp_iter_1                 0.4  male     -0.001163
# 9            Exp_iter_1                 0.4  male      0.973268
# 10           Exp_iter_1                 0.4  male      0.000347
# 11           Exp_iter_1                 0.4  race     -0.092941
# 12           Exp_iter_1                 0.4  race     -0.239630
# 13           Exp_iter_1                 0.4  race      0.092941
# 14           Exp_iter_1                 0.4  race      1.070712
# 15           Exp_iter_1                 0.4  race      0.074830
# 16           Exp_iter_1                 0.4  race     -0.168618
# 17           Exp_iter_1                 0.4  race      0.879752
# 18           Exp_iter_1                 0.4  race      0.049003
# 19           Exp_iter_1                 0.4  race      0.034086

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='race_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='race_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='race',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='race',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio',
                                                              'Jitter_Parity', 'Disparate_Impact'])
# Out:
# alt.VConcatChart(...)
