# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
import os.path

from source.utils.stability_utils import display_result_plots

# %%
results_dir = os.path.join('..', '..', 'results', 'final_stability_fairness_metrics')
display_result_plots(results_dir + '/')
