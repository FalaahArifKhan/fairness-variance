# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_CA_2018_Public_Coverage'
EXPERIMENT_SESSION_UUID = '163da20d-0491-493d-b718-b33de7b259fd'
SENSITIVE_ATTRS = ['gender', 'race', 'gender&race']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (76, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3                Accuracy                   101  RandomForestClassifier
# 4   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 5   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 6   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 7   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 8                      F1                   101  RandomForestClassifier
# 9                      F1                   101  RandomForestClassifier
# 10                     F1                   101  RandomForestClassifier
# 11                     F1                   101  RandomForestClassifier
# 12                    FNR                   101  RandomForestClassifier
# 13                    FNR                   101  RandomForestClassifier
# 14                    FNR                   101  RandomForestClassifier
# 15                    FNR                   101  RandomForestClassifier
# 16                    FPR                   101  RandomForestClassifier
# 17                    FPR                   101  RandomForestClassifier
# 18                    FPR                   101  RandomForestClassifier
# 19                    FPR                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number Dataset_Name  \
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1     Diabetes
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0               20  OK 2023-08-03 22:21:05.906
# 1               20  OK 2023-08-03 22:22:48.037
# 2               20  OK 2023-08-03 22:24:37.560
# 3               20  OK 2023-08-03 22:18:02.608
# 4               20  OK 2023-08-03 22:21:05.906
# 5               20  OK 2023-08-03 22:22:48.037
# 6               20  OK 2023-08-03 22:24:37.560
# 7               20  OK 2023-08-03 22:18:02.608
# 8               20  OK 2023-08-03 22:21:05.906
# 9               20  OK 2023-08-03 22:22:48.037
# 10              20  OK 2023-08-03 22:24:37.560
# 11              20  OK 2023-08-03 22:18:02.608
# 12              20  OK 2023-08-03 22:21:05.906
# 13              20  OK 2023-08-03 22:22:48.037
# 14              20  OK 2023-08-03 22:24:37.560
# 15              20  OK 2023-08-03 22:18:02.608
# 16              20  OK 2023-08-03 22:21:05.906
# 17              20  OK 2023-08-03 22:22:48.037
# 18              20  OK 2023-08-03 22:24:37.560
# 19              20  OK 2023-08-03 22:18:02.608
#
#                             Session_Uuid  ... gender_priv  \
# 0   163da20d-0491-493d-b718-b33de7b259fd  ...    0.767442
# 1   163da20d-0491-493d-b718-b33de7b259fd  ...    0.767442
# 2   163da20d-0491-493d-b718-b33de7b259fd  ...    0.768169
# 3   163da20d-0491-493d-b718-b33de7b259fd  ...    0.754042
# 4   163da20d-0491-493d-b718-b33de7b259fd  ...    0.770206
# 5   163da20d-0491-493d-b718-b33de7b259fd  ...    0.768452
# 6   163da20d-0491-493d-b718-b33de7b259fd  ...    0.768123
# 7   163da20d-0491-493d-b718-b33de7b259fd  ...    0.769017
# 8   163da20d-0491-493d-b718-b33de7b259fd  ...    0.080460
# 9   163da20d-0491-493d-b718-b33de7b259fd  ...    0.064327
# 10  163da20d-0491-493d-b718-b33de7b259fd  ...    0.085960
# 11  163da20d-0491-493d-b718-b33de7b259fd  ...    0.080586
# 12  163da20d-0491-493d-b718-b33de7b259fd  ...    0.957317
# 13  163da20d-0491-493d-b718-b33de7b259fd  ...    0.966463
# 14  163da20d-0491-493d-b718-b33de7b259fd  ...    0.954268
# 15  163da20d-0491-493d-b718-b33de7b259fd  ...    0.957282
# 16  163da20d-0491-493d-b718-b33de7b259fd  ...    0.005725
# 17  163da20d-0491-493d-b718-b33de7b259fd  ...    0.002863
# 18  163da20d-0491-493d-b718-b33de7b259fd  ...    0.005725
# 19  163da20d-0491-493d-b718-b33de7b259fd  ...    0.005898
#
#     gender_priv_correct  gender_priv_incorrect   overall  race_dis  \
# 0              1.000000               0.000000  0.760333  0.761619
# 1              1.000000               0.000000  0.760667  0.761619
# 2              1.000000               0.000000  0.760000  0.761619
# 3              1.000000               0.000000  0.760717  0.755081
# 4              0.759863               0.804340  0.774733  0.780421
# 5              0.758283               0.802007  0.773059  0.783260
# 6              0.757937               0.801870  0.773270  0.782764
# 7              0.759420               0.798437  0.774399  0.777299
# 8              1.000000               0.000000  0.072258  0.036364
# 9              1.000000               0.000000  0.067532  0.024540
# 10             1.000000               0.000000  0.074550  0.024540
# 11             1.000000               0.000000  0.079125  0.039841
# 12             0.000000               1.000000  0.962008  0.981013
# 13             0.000000               1.000000  0.964722  0.987342
# 14             0.000000               1.000000  0.960651  0.987342
# 15             0.000000               1.000000  0.958185  0.979592
# 16             0.000000               1.000000  0.004419  0.007859
# 17             0.000000               1.000000  0.003093  0.005894
# 18             0.000000               1.000000  0.005303  0.005894
# 19             0.000000               1.000000  0.004930  0.001353
#
#     race_dis_correct  race_dis_incorrect  race_priv  race_priv_correct  \
# 0           1.000000            0.000000   0.759966           1.000000
# 1           1.000000            0.000000   0.760394           1.000000
# 2           1.000000            0.000000   0.759537           1.000000
# 3           1.000000            0.000000   0.762263           1.000000
# 4           0.769165            0.816385   0.773106           0.763101
# 5           0.772549            0.817479   0.770142           0.760607
# 6           0.771728            0.818024   0.770556           0.759795
# 7           0.765438            0.813866   0.773604           0.764368
# 8           1.000000            0.000000   0.081967           1.000000
# 9           1.000000            0.000000   0.079077           1.000000
# 10          1.000000            0.000000   0.087805           1.000000
# 11          1.000000            0.000000   0.089648           1.000000
# 12          0.000000            1.000000   0.956822           0.000000
# 13          0.000000            1.000000   0.958549           0.000000
# 14          0.000000            1.000000   0.953368           0.000000
# 15          0.000000            1.000000   0.952218           0.000000
# 16          0.000000            1.000000   0.003421           0.000000
# 17          0.000000            1.000000   0.002281           0.000000
# 18          0.000000            1.000000   0.005131           0.000000
# 19          0.000000            1.000000   0.005906           0.000000
#
#     race_priv_incorrect
# 0              0.000000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.804785
# 5              0.800403
# 6              0.804544
# 7              0.803220
# 8              0.000000
# 9              0.000000
# 10             0.000000
# 11             0.000000
# 12             1.000000
# 13             1.000000
# 14             1.000000
# 15             1.000000
# 16             1.000000
# 17             1.000000
# 18             1.000000
# 19             1.000000
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [Metric, Bootstrap_Model_Seed, Model_Name, Model_Params, Run_Number, Dataset_Name, Num_Estimators, Tag, Record_Create_Date_Time, Session_Uuid, Experiment_Iteration, Dataset_Split_Seed, Model_Init_Seed, Fair_Intervention_Params_Lst, Intervention_Param, gender&race_dis, gender&race_dis_correct, gender&race_dis_incorrect, gender&race_priv, gender&race_priv_correct, gender&race_priv_incorrect, gender_dis, gender_dis_correct, gender_dis_incorrect, gender_priv, gender_priv_correct, gender_priv_incorrect, overall, race_dis, race_dis_correct, race_dis_incorrect, race_priv, race_priv_correct, race_priv_incorrect]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11             Equalized_Odds_TPR  RandomForestClassifier
# 12             Equalized_Odds_FPR  RandomForestClassifier
# 13             Equalized_Odds_FNR  RandomForestClassifier
# 14               Disparate_Impact  RandomForestClassifier
# 15  Statistical_Parity_Difference  RandomForestClassifier
# 16                Accuracy_Parity  RandomForestClassifier
# 17          Label_Stability_Ratio  RandomForestClassifier
# 18                     IQR_Parity  RandomForestClassifier
# 19                     Std_Parity  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param   Group  Metric_Value
# 0            Exp_iter_1                 0.0  gender     -0.005060
# 1            Exp_iter_1                 0.0  gender     -0.002084
# 2            Exp_iter_1                 0.0  gender      0.005060
# 3            Exp_iter_1                 0.0  gender      0.810408
# 4            Exp_iter_1                 0.0  gender     -0.011486
# 5            Exp_iter_1                 0.0  gender     -0.000537
# 6            Exp_iter_1                 0.0  gender      0.996180
# 7            Exp_iter_1                 0.0  gender      0.000684
# 8            Exp_iter_1                 0.0  gender      0.000256
# 9            Exp_iter_1                 0.0  gender      1.004923
# 10           Exp_iter_1                 0.0  gender      0.002621
# 11           Exp_iter_1                 0.0    race     -0.025782
# 12           Exp_iter_1                 0.0    race     -0.000058
# 13           Exp_iter_1                 0.0    race      0.025782
# 14           Exp_iter_1                 0.0    race      0.575560
# 15           Exp_iter_1                 0.0    race     -0.025366
# 16           Exp_iter_1                 0.0    race     -0.002764
# 17           Exp_iter_1                 0.0    race      1.002257
# 18           Exp_iter_1                 0.0    race      0.000213
# 19           Exp_iter_1                 0.0    race      0.000351

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='RAC1P',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='RAC1P',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio',
                                                              'Jitter_Parity', 'Disparate_Impact'])
# Out:
# alt.VConcatChart(...)
