# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/dh3553/projects/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_CA_2018_Public_Coverage'
EXPERIMENT_SESSION_UUID = 'f88d9187-81c1-496e-a809-65185798edd6'
SENSITIVE_ATTRS = ['gender', 'race', 'gender&race']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (190, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3                Accuracy                   101  RandomForestClassifier
# 4                Accuracy                   101  RandomForestClassifier
# 5                Accuracy                   101  RandomForestClassifier
# 6                Accuracy                   101  RandomForestClassifier
# 7                Accuracy                   101  RandomForestClassifier
# 8                Accuracy                   101  RandomForestClassifier
# 9                Accuracy                   101  RandomForestClassifier
# 10  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 11  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 12  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 13  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 14  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 15  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 16  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 17  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 18  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 19  Aleatoric_Uncertainty                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number Dataset_Name  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 4   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 5   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 6   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 7   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 8   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 9   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 10  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 15  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 16  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 17  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 18  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
# 19  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1     Diabetes
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0              200  OK 2023-08-05 11:04:48.791
# 1              200  OK 2023-08-05 11:22:30.211
# 2              200  OK 2023-08-05 11:05:37.835
# 3              200  OK 2023-08-05 10:49:26.823
# 4              200  OK 2023-08-05 11:02:27.223
# 5              200  OK 2023-08-05 11:05:00.615
# 6              200  OK 2023-08-05 11:08:13.393
# 7              200  OK 2023-08-05 11:09:21.153
# 8              200  OK 2023-08-05 11:14:14.556
# 9              200  OK 2023-08-05 11:39:39.451
# 10             200  OK 2023-08-05 11:04:48.791
# 11             200  OK 2023-08-05 11:22:30.211
# 12             200  OK 2023-08-05 11:05:37.835
# 13             200  OK 2023-08-05 10:49:26.823
# 14             200  OK 2023-08-05 11:02:27.223
# 15             200  OK 2023-08-05 11:05:00.615
# 16             200  OK 2023-08-05 11:08:13.393
# 17             200  OK 2023-08-05 11:09:21.153
# 18             200  OK 2023-08-05 11:14:14.556
# 19             200  OK 2023-08-05 11:39:39.451
#
#                             Session_Uuid  ... gender_priv  \
# 0   f88d9187-81c1-496e-a809-65185798edd6  ...    0.755512
# 1   f88d9187-81c1-496e-a809-65185798edd6  ...    0.755512
# 2   f88d9187-81c1-496e-a809-65185798edd6  ...    0.756002
# 3   f88d9187-81c1-496e-a809-65185798edd6  ...    0.754532
# 4   f88d9187-81c1-496e-a809-65185798edd6  ...    0.755512
# 5   f88d9187-81c1-496e-a809-65185798edd6  ...    0.754042
# 6   f88d9187-81c1-496e-a809-65185798edd6  ...    0.754042
# 7   f88d9187-81c1-496e-a809-65185798edd6  ...    0.754532
# 8   f88d9187-81c1-496e-a809-65185798edd6  ...    0.754042
# 9   f88d9187-81c1-496e-a809-65185798edd6  ...    0.755512
# 10  f88d9187-81c1-496e-a809-65185798edd6  ...    0.771279
# 11  f88d9187-81c1-496e-a809-65185798edd6  ...    0.762986
# 12  f88d9187-81c1-496e-a809-65185798edd6  ...    0.759909
# 13  f88d9187-81c1-496e-a809-65185798edd6  ...    0.758757
# 14  f88d9187-81c1-496e-a809-65185798edd6  ...    0.758647
# 15  f88d9187-81c1-496e-a809-65185798edd6  ...    0.772838
# 16  f88d9187-81c1-496e-a809-65185798edd6  ...    0.773520
# 17  f88d9187-81c1-496e-a809-65185798edd6  ...    0.770998
# 18  f88d9187-81c1-496e-a809-65185798edd6  ...    0.773692
# 19  f88d9187-81c1-496e-a809-65185798edd6  ...    0.763865
#
#     gender_priv_correct  gender_priv_incorrect   overall  race_dis  \
# 0              1.000000               0.000000  0.762030  0.758130
# 1              1.000000               0.000000  0.761592  0.756098
# 2              1.000000               0.000000  0.761155  0.756098
# 3              1.000000               0.000000  0.761374  0.757114
# 4              1.000000               0.000000  0.761592  0.757114
# 5              1.000000               0.000000  0.761155  0.757114
# 6              1.000000               0.000000  0.761592  0.759146
# 7              1.000000               0.000000  0.761374  0.756098
# 8              1.000000               0.000000  0.762030  0.759146
# 9              1.000000               0.000000  0.761592  0.756098
# 10             0.762590               0.798131  0.778420  0.797451
# 11             0.753688               0.791716  0.769139  0.776331
# 12             0.750836               0.788023  0.766281  0.778716
# 13             0.749006               0.788733  0.764490  0.768355
# 14             0.749068               0.788248  0.764194  0.769935
# 15             0.763691               0.800881  0.779525  0.799097
# 16             0.764453               0.801318  0.780718  0.801303
# 17             0.762076               0.798423  0.777951  0.798078
# 18             0.765001               0.800335  0.780824  0.802327
# 19             0.754574               0.792573  0.770468  0.781276
#
#     race_dis_correct  race_dis_incorrect  race_priv  race_priv_correct  \
# 0           1.000000            0.000000   0.763099           1.000000
# 1           1.000000            0.000000   0.763099           1.000000
# 2           1.000000            0.000000   0.762542           1.000000
# 3           1.000000            0.000000   0.762542           1.000000
# 4           1.000000            0.000000   0.762821           1.000000
# 5           1.000000            0.000000   0.762263           1.000000
# 6           1.000000            0.000000   0.762263           1.000000
# 7           1.000000            0.000000   0.762821           1.000000
# 8           1.000000            0.000000   0.762821           1.000000
# 9           1.000000            0.000000   0.763099           1.000000
# 10          0.788515            0.825457   0.773201           0.764255
# 11          0.764845            0.811941   0.767167           0.757996
# 12          0.767579            0.813241   0.762870           0.753635
# 13          0.756651            0.804838   0.763430           0.754177
# 14          0.758260            0.806328   0.762620           0.753361
# 15          0.789769            0.828172   0.774157           0.765082
# 16          0.792508            0.829024   0.775073           0.766097
# 17          0.788288            0.828429   0.772431           0.763579
# 18          0.793677            0.829593   0.774927           0.766406
# 19          0.770125            0.815844   0.767504           0.758342
#
#     race_priv_incorrect
# 0              0.000000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# 5              0.000000
# 6              0.000000
# 7              0.000000
# 8              0.000000
# 9              0.000000
# 10             0.802019
# 11             0.796709
# 12             0.792526
# 13             0.793144
# 14             0.792396
# 15             0.803256
# 16             0.803851
# 17             0.800902
# 18             0.802330
# 19             0.797016
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
#                                                                             134
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...
# Run_Number                                                                Run_1
# Dataset_Name                                                           Diabetes
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-08-05 11:02:27.223000
# Session_Uuid                               f88d9187-81c1-496e-a809-65185798edd6
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                                              [0.1]
# Intervention_Param                                                          0.1
# gender&race_dis                                                           592.0
# gender&race_dis_correct                                                   449.0
# gender&race_dis_incorrect                                                 143.0
# gender&race_priv                                                         3980.0
# gender&race_priv_correct                                                 3033.0
# gender&race_priv_incorrect                                                947.0
# gender_dis                                                               2531.0
# gender_dis_correct                                                       1940.0
# gender_dis_incorrect                                                      591.0
# gender_priv                                                              2041.0
# gender_priv_correct                                                      1542.0
# gender_priv_incorrect                                                     499.0
# overall                                                                  4572.0
# race_dis                                                                  984.0
# race_dis_correct                                                          745.0
# race_dis_incorrect                                                        239.0
# race_priv                                                                3588.0
# race_priv_correct                                                        2737.0
# race_priv_incorrect                                                       851.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11             Equalized_Odds_TPR  RandomForestClassifier
# 12             Equalized_Odds_FPR  RandomForestClassifier
# 13             Equalized_Odds_FNR  RandomForestClassifier
# 14               Disparate_Impact  RandomForestClassifier
# 15  Statistical_Parity_Difference  RandomForestClassifier
# 16                Accuracy_Parity  RandomForestClassifier
# 17          Label_Stability_Ratio  RandomForestClassifier
# 18                     IQR_Parity  RandomForestClassifier
# 19                     Std_Parity  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param   Group  Metric_Value
# 0            Exp_iter_1                 0.7  gender     -0.000625
# 1            Exp_iter_1                 0.7  gender     -0.001080
# 2            Exp_iter_1                 0.7  gender      0.000625
# 3            Exp_iter_1                 0.7  gender      0.951355
# 4            Exp_iter_1                 0.7  gender     -0.003023
# 5            Exp_iter_1                 0.7  gender      0.011774
# 6            Exp_iter_1                 0.7  gender      0.995475
# 7            Exp_iter_1                 0.7  gender     -0.000091
# 8            Exp_iter_1                 0.7  gender      0.000291
# 9            Exp_iter_1                 0.7  gender      1.005009
# 10           Exp_iter_1                 0.7  gender      0.003981
# 11           Exp_iter_1                 0.7    race     -0.017404
# 12           Exp_iter_1                 0.7    race     -0.004184
# 13           Exp_iter_1                 0.7    race      0.017404
# 14           Exp_iter_1                 0.7    race      0.547285
# 15           Exp_iter_1                 0.7    race     -0.030387
# 16           Exp_iter_1                 0.7    race     -0.004969
# 17           Exp_iter_1                 0.7    race      1.005832
# 18           Exp_iter_1                 0.7    race     -0.000066
# 19           Exp_iter_1                 0.7    race      0.000513

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='race_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='race_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='race',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='race',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio',
                                                              'Jitter_Parity', 'Disparate_Impact'])
# Out:
# alt.VConcatChart(...)
