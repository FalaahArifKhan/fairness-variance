# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'stress_testing_with_cols_nulls'
DB_COLLECTION_NAME = f'exp_{EXPERIMENT_NAME}'
DATASET_NAME = 'COMPAS'
EXPERIMENT_SESSION_UUID = 'b78b8941-d4f2-40bc-b07f-e79fa0ff8709'
SENSITIVE_ATTRS = ['sex', 'race', 'sex&race']
PREPROCESSING_TECHNIQUES = ['cat: mode, num: median']

# %%
# MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression', 'RandomForestClassifier',
#                'XGBClassifier', 'KNeighborsClassifier']
MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (80, 25)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  DecisionTreeClassifier
# 1   Accuracy                   101  DecisionTreeClassifier
# 2   Accuracy                   101  DecisionTreeClassifier
# 3   Accuracy                   101  DecisionTreeClassifier
# 4   Accuracy                   101  DecisionTreeClassifier
# 10   Entropy                   101  DecisionTreeClassifier
# 11   Entropy                   101  DecisionTreeClassifier
# 12   Entropy                   101  DecisionTreeClassifier
# 13   Entropy                   101  DecisionTreeClassifier
# 14   Entropy                   101  DecisionTreeClassifier
# 20        F1                   101  DecisionTreeClassifier
# 21        F1                   101  DecisionTreeClassifier
# 22        F1                   101  DecisionTreeClassifier
# 23        F1                   101  DecisionTreeClassifier
# 24        F1                   101  DecisionTreeClassifier
# 30       FNR                   101  DecisionTreeClassifier
# 31       FNR                   101  DecisionTreeClassifier
# 32       FNR                   101  DecisionTreeClassifier
# 33       FNR                   101  DecisionTreeClassifier
# 34       FNR                   101  DecisionTreeClassifier
#
#                                          Model_Params Run_Number Dataset_Name  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 1   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 2   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 3   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 10  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 11  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 12  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 13  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 14  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 20  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 21  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 22  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 23  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 24  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 30  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 31  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 32  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 33  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 34  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
#
#     Num_Estimators  Test_Set_Index Tag Record_Create_Date_Time  ...  \
# 0               10               0  OK 2023-05-02 09:50:34.990  ...
# 1               10               1  OK 2023-05-02 09:50:34.999  ...
# 2               10               2  OK 2023-05-02 09:50:35.007  ...
# 3               10               3  OK 2023-05-02 09:50:35.017  ...
# 4               10               4  OK 2023-05-02 09:50:35.028  ...
# 10              10               0  OK 2023-05-02 09:50:34.990  ...
# 11              10               1  OK 2023-05-02 09:50:34.999  ...
# 12              10               2  OK 2023-05-02 09:50:35.007  ...
# 13              10               3  OK 2023-05-02 09:50:35.017  ...
# 14              10               4  OK 2023-05-02 09:50:35.028  ...
# 20              10               0  OK 2023-05-02 09:50:34.990  ...
# 21              10               1  OK 2023-05-02 09:50:34.999  ...
# 22              10               2  OK 2023-05-02 09:50:35.007  ...
# 23              10               3  OK 2023-05-02 09:50:35.017  ...
# 24              10               4  OK 2023-05-02 09:50:35.028  ...
# 30              10               0  OK 2023-05-02 09:50:34.990  ...
# 31              10               1  OK 2023-05-02 09:50:34.999  ...
# 32              10               2  OK 2023-05-02 09:50:35.007  ...
# 33              10               3  OK 2023-05-02 09:50:35.017  ...
# 34              10               4  OK 2023-05-02 09:50:35.028  ...
#
#    Dataset_Split_Seed Model_Init_Seed Injector_Config_Lst   overall  race_dis  \
# 0                 100             100        [1, 2, 3, 4]  0.708333  0.708978
# 1                 100             100        [1, 2, 3, 4]  0.695076  0.684211
# 2                 100             100        [1, 2, 3, 4]  0.681818  0.678019
# 3                 100             100        [1, 2, 3, 4]  0.696970  0.705882
# 4                 100             100        [1, 2, 3, 4]  0.704545  0.708978
# 10                100             100        [1, 2, 3, 4]  0.233258  0.000000
# 11                100             100        [1, 2, 3, 4]  0.235022  0.000000
# 12                100             100        [1, 2, 3, 4]  0.233250  0.000000
# 13                100             100        [1, 2, 3, 4]  0.234094  0.000000
# 14                100             100        [1, 2, 3, 4]  0.231128  0.000000
# 20                100             100        [1, 2, 3, 4]  0.670940  0.713415
# 21                100             100        [1, 2, 3, 4]  0.649237  0.681250
# 22                100             100        [1, 2, 3, 4]  0.626667  0.670886
# 23                100             100        [1, 2, 3, 4]  0.649123  0.704050
# 24                100             100        [1, 2, 3, 4]  0.656388  0.702532
# 30                100             100        [1, 2, 3, 4]  0.396154  0.331429
# 31                100             100        [1, 2, 3, 4]  0.426923  0.377143
# 32                100             100        [1, 2, 3, 4]  0.457692  0.394286
# 33                100             100        [1, 2, 3, 4]  0.430769  0.354286
# 34                100             100        [1, 2, 3, 4]  0.426923  0.365714
#
#     race_priv  sex&race_dis sex&race_priv   sex_dis  sex_priv
# 0    0.707317      0.706320      0.723404  0.704918  0.722772
# 1    0.712195      0.676580      0.723404  0.688525  0.722772
# 2    0.687805      0.669145      0.723404  0.672131  0.722772
# 3    0.682927      0.710037      0.680851  0.700234  0.683168
# 4    0.697561      0.702602      0.723404  0.697892  0.732673
# 10   0.206868      0.000000      0.000000  0.247079  0.000000
# 11   0.198711      0.000000      0.000000  0.250884  0.000000
# 12   0.199198      0.000000      0.000000  0.247069  0.000000
# 13   0.213706      0.000000      0.000000  0.249953  0.000000
# 14   0.204191      0.000000      0.000000  0.247808  0.000000
# 20   0.571429      0.732203      0.518519  0.691176  0.533333
# 21   0.575540      0.696864      0.518519  0.666667  0.533333
# 22   0.522388      0.685512      0.518519  0.641026  0.533333
# 23   0.518519      0.729167      0.400000  0.678392  0.448276
# 24   0.550725      0.716312      0.518519  0.671756  0.557377
# 30   0.529412      0.294118      0.611111  0.359091  0.600000
# 31   0.529412      0.346405      0.611111  0.395455  0.600000
# 32   0.588235      0.366013      0.611111  0.431818  0.600000
# 33   0.588235      0.313725      0.722222  0.386364  0.675000
# 34   0.552941      0.339869      0.611111  0.400000  0.575000
#
# [20 rows x 25 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_avg_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_avg_runs_group_metrics_dct=exp_avg_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %% [markdown]
# ### Subgroup metrics per dataset, experiment iteration, and model

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='variance')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='error')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Group metrics per dataset and model

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='variance')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='fairness')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset and multiple models

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Jitter',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Label_Stability',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='F1',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Accuracy',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific group metric per dataset, experiment iteration, and multiple models

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric=visualizer.all_group_variance_metrics_lst[1],
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric='Disparate_Impact',
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset, one model, and multiple preprocessing techniques

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_and_preprocessing_plot(subgroup_metric='Jitter', model_name=MODEL_NAMES[0])
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Box plots for subgroup metrics per model and experiment iteration

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for subgroup metrics per model and error level

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for group metrics per model and error level

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='sex',
                                                                  group_metrics_type='fairness')

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='sex',
                                                                  group_metrics_type='variance')

# %% [markdown]
# ### One box plot for both error and variance metrics for subgroups

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics=['F1', 'Accuracy', 'Jitter', 'Label_Stability'])
