# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'stress_testing_with_cols_nulls'
DB_COLLECTION_NAME = f'exp_{EXPERIMENT_NAME}'
DATASET_NAME = 'COMPAS'
EXPERIMENT_SESSION_UUID = '98282d8d-a623-4919-98e5-b1e33d34f56d'
SENSITIVE_ATTRS = ['sex', 'race', 'sex&race']
PREPROCESSING_TECHNIQUES = ['cat: mode, num: median']

# %%
MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression', 'RandomForestClassifier',
               'XGBClassifier', 'KNeighborsClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (400, 25)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  DecisionTreeClassifier
# 1   Accuracy                   101  DecisionTreeClassifier
# 2   Accuracy                   101  DecisionTreeClassifier
# 3   Accuracy                   101  DecisionTreeClassifier
# 4   Accuracy                   101  DecisionTreeClassifier
# 25  Accuracy                   201  DecisionTreeClassifier
# 26  Accuracy                   201  DecisionTreeClassifier
# 27  Accuracy                   201  DecisionTreeClassifier
# 28  Accuracy                   201  DecisionTreeClassifier
# 29  Accuracy                   201  DecisionTreeClassifier
# 50  Accuracy                   301  DecisionTreeClassifier
# 51  Accuracy                   301  DecisionTreeClassifier
# 52  Accuracy                   301  DecisionTreeClassifier
# 53  Accuracy                   301  DecisionTreeClassifier
# 54  Accuracy                   301  DecisionTreeClassifier
# 75  Accuracy                   401  DecisionTreeClassifier
# 76  Accuracy                   401  DecisionTreeClassifier
# 77  Accuracy                   401  DecisionTreeClassifier
# 78  Accuracy                   401  DecisionTreeClassifier
# 79  Accuracy                   401  DecisionTreeClassifier
#
#                                          Model_Params Run_Number Dataset_Name  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 1   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 2   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 3   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 25  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 26  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 27  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 28  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 29  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 50  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 51  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 52  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 53  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 54  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 75  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 76  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 77  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 78  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
# 79  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1       COMPAS
#
#     Num_Estimators  Test_Set_Index Tag Record_Create_Date_Time  ...  \
# 0              200               0  OK 2023-05-02 12:32:15.385  ...
# 1              200               1  OK 2023-05-02 12:32:15.398  ...
# 2              200               2  OK 2023-05-02 12:32:15.409  ...
# 3              200               3  OK 2023-05-02 12:32:15.419  ...
# 4              200               4  OK 2023-05-02 12:32:15.429  ...
# 25             200               0  OK 2023-05-02 12:37:37.425  ...
# 26             200               1  OK 2023-05-02 12:37:37.436  ...
# 27             200               2  OK 2023-05-02 12:37:37.447  ...
# 28             200               3  OK 2023-05-02 12:37:37.457  ...
# 29             200               4  OK 2023-05-02 12:37:37.467  ...
# 50             200               0  OK 2023-05-02 12:37:30.365  ...
# 51             200               1  OK 2023-05-02 12:37:30.376  ...
# 52             200               2  OK 2023-05-02 12:37:30.387  ...
# 53             200               3  OK 2023-05-02 12:37:30.396  ...
# 54             200               4  OK 2023-05-02 12:37:30.406  ...
# 75             200               0  OK 2023-05-02 12:38:39.866  ...
# 76             200               1  OK 2023-05-02 12:38:39.877  ...
# 77             200               2  OK 2023-05-02 12:38:39.887  ...
# 78             200               3  OK 2023-05-02 12:38:39.897  ...
# 79             200               4  OK 2023-05-02 12:38:39.907  ...
#
#    Dataset_Split_Seed Model_Init_Seed Injector_Config_Lst   overall  race_dis  \
# 0                 100             100        [1, 2, 3, 4]  0.710227  0.708978
# 1                 100             100        [1, 2, 3, 4]  0.691288  0.678019
# 2                 100             100        [1, 2, 3, 4]  0.687500  0.678019
# 3                 100             100        [1, 2, 3, 4]  0.693182  0.699690
# 4                 100             100        [1, 2, 3, 4]  0.704545  0.708978
# 25                200             200        [1, 2, 3, 4]  0.678030  0.672783
# 26                200             200        [1, 2, 3, 4]  0.683712  0.678899
# 27                200             200        [1, 2, 3, 4]  0.670455  0.669725
# 28                200             200        [1, 2, 3, 4]  0.664773  0.663609
# 29                200             200        [1, 2, 3, 4]  0.660985  0.645260
# 50                300             300        [1, 2, 3, 4]  0.664773  0.657051
# 51                300             300        [1, 2, 3, 4]  0.666667  0.663462
# 52                300             300        [1, 2, 3, 4]  0.643939  0.634615
# 53                300             300        [1, 2, 3, 4]  0.649621  0.637821
# 54                300             300        [1, 2, 3, 4]  0.638258  0.625000
# 75                400             400        [1, 2, 3, 4]  0.679924  0.629870
# 76                400             400        [1, 2, 3, 4]  0.678030  0.626623
# 77                400             400        [1, 2, 3, 4]  0.676136  0.623377
# 78                400             400        [1, 2, 3, 4]  0.668561  0.610390
# 79                400             400        [1, 2, 3, 4]  0.679924  0.626623
#
#     race_priv  sex&race_dis sex&race_priv   sex_dis  sex_priv
# 0    0.712195      0.706320      0.723404  0.707260  0.722772
# 1    0.712195      0.669145      0.723404  0.683841  0.722772
# 2    0.702439      0.669145      0.744681  0.676815  0.732673
# 3    0.682927      0.706320      0.680851  0.697892  0.673267
# 4    0.697561      0.702602      0.702128  0.700234  0.722772
# 25   0.686567      0.680297      0.708333  0.680095  0.669811
# 26   0.691542      0.680297      0.708333  0.682464  0.688679
# 27   0.671642      0.684015      0.687500  0.677725  0.641509
# 28   0.666667      0.672862      0.687500  0.668246  0.650943
# 29   0.686567      0.646840      0.687500  0.661137  0.660377
# 50   0.675926      0.639216      0.716981  0.648325  0.727273
# 51   0.671296      0.643137      0.716981  0.648325  0.736364
# 52   0.657407      0.615686      0.679245  0.629187  0.700000
# 53   0.666667      0.615686      0.716981  0.629187  0.727273
# 54   0.657407      0.603922      0.698113  0.619617  0.709091
# 75   0.750000      0.626506      0.736842  0.677184  0.689655
# 76   0.750000      0.618474      0.719298  0.674757  0.689655
# 77   0.750000      0.622490      0.736842  0.674757  0.681034
# 78   0.750000      0.606426      0.736842  0.665049  0.681034
# 79   0.754545      0.630522      0.754386  0.679612  0.681034
#
# [20 rows x 25 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_avg_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_avg_runs_group_metrics_dct=exp_avg_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %% [markdown]
# ### Subgroup metrics per dataset, experiment iteration, and model

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='variance',
                                                mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='error',
                                                mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Group metrics per dataset and model

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='variance',
                                             mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='fairness',
                                             mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset and multiple models

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Jitter',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Label_Stability',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='F1',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Accuracy',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific group metric per dataset, experiment iteration, and multiple models

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric=visualizer.all_group_variance_metrics_lst[1],
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES,
                                                       mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric=visualizer.all_group_fairness_metrics_lst[3],
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES,
                                                       mode='max_num_columns')

# %% [markdown]
# ### Specific subgroup metric per dataset, one model, and multiple preprocessing techniques

# %%
# visualizer.create_subgroups_grid_pct_lines_per_model_and_preprocessing_plot(subgroup_metric='Jitter',
#                                                                             model_name=MODEL_NAMES[0],
#                                                                             mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Box plots for subgroup metrics per model and experiment iteration

# %%
# visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
#                                                                    target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
#                                                                    subgroup_metrics_type='variance')

# %%
# visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
#                                                                    target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
#                                                                    subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for subgroup metrics per model and error level

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for group metrics per model and error level

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='sex',
                                                                  group_metrics_type='fairness')

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='sex',
                                                                  group_metrics_type='variance')

# %% [markdown]
# ### One box plot for both error and variance metrics for subgroups

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics=['F1', 'Accuracy', 'Jitter', 'Label_Stability'],
                                                                     legend_loc='lower left')

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name='RandomForestClassifier',
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics=['Accuracy', 'F1', 'Jitter', 'Label_Stability'],
                                                mode='max_num_columns')
# Out:
# all_percentage_subgroup_metrics_df
#                  Model_Name  Test_Set_Index Metric       Subgroup  \
# 14   RandomForestClassifier             0.0     F1        overall
# 15   RandomForestClassifier             0.0     F1       race_dis
# 16   RandomForestClassifier             0.0     F1      race_priv
# 17   RandomForestClassifier             0.0     F1   sex&race_dis
# 18   RandomForestClassifier             0.0     F1  sex&race_priv
# 19   RandomForestClassifier             0.0     F1        sex_dis
# 20   RandomForestClassifier             0.0     F1       sex_priv
# 126  RandomForestClassifier             1.0     F1        overall
# 127  RandomForestClassifier             1.0     F1       race_dis
# 128  RandomForestClassifier             1.0     F1      race_priv
# 129  RandomForestClassifier             1.0     F1   sex&race_dis
# 130  RandomForestClassifier             1.0     F1  sex&race_priv
# 131  RandomForestClassifier             1.0     F1        sex_dis
# 132  RandomForestClassifier             1.0     F1       sex_priv
# 238  RandomForestClassifier             2.0     F1        overall
# 239  RandomForestClassifier             2.0     F1       race_dis
# 240  RandomForestClassifier             2.0     F1      race_priv
# 241  RandomForestClassifier             2.0     F1   sex&race_dis
# 242  RandomForestClassifier             2.0     F1  sex&race_priv
# 243  RandomForestClassifier             2.0     F1        sex_dis
# 244  RandomForestClassifier             2.0     F1       sex_priv
# 350  RandomForestClassifier             3.0     F1        overall
# 351  RandomForestClassifier             3.0     F1       race_dis
# 352  RandomForestClassifier             3.0     F1      race_priv
# 353  RandomForestClassifier             3.0     F1   sex&race_dis
# 354  RandomForestClassifier             3.0     F1  sex&race_priv
# 355  RandomForestClassifier             3.0     F1        sex_dis
# 356  RandomForestClassifier             3.0     F1       sex_priv
# 462  RandomForestClassifier             4.0     F1        overall
# 463  RandomForestClassifier             4.0     F1       race_dis
# 464  RandomForestClassifier             4.0     F1      race_priv
# 465  RandomForestClassifier             4.0     F1   sex&race_dis
# 466  RandomForestClassifier             4.0     F1  sex&race_priv
# 467  RandomForestClassifier             4.0     F1        sex_dis
# 468  RandomForestClassifier             4.0     F1       sex_priv
#
#      Num_Estimators  Metric_Value  Percentage
# 14            200.0      0.630591         0.0
# 15            200.0      0.679527         0.0
# 16            200.0      0.505786         0.0
# 17            200.0      0.695319         0.0
# 18            200.0      0.478122         0.0
# 19            200.0      0.645950         0.0
# 20            200.0      0.519915         0.0
# 126           200.0      0.619825         1.0
# 127           200.0      0.668656         1.0
# 128           200.0      0.496277         1.0
# 129           200.0      0.681495         1.0
# 130           200.0      0.444567         1.0
# 131           200.0      0.634606         1.0
# 132           200.0      0.513029         1.0
# 238           200.0      0.604217         2.0
# 239           200.0      0.654500         2.0
# 240           200.0      0.472542         2.0
# 241           200.0      0.669622         2.0
# 242           200.0      0.463269         2.0
# 243           200.0      0.618476         2.0
# 244           200.0      0.499158         2.0
# 350           200.0      0.601347         3.0
# 351           200.0      0.651867         3.0
# 352           200.0      0.471190         3.0
# 353           200.0      0.673009         3.0
# 354           200.0      0.435495         3.0
# 355           200.0      0.620750         3.0
# 356           200.0      0.461592         3.0
# 462           200.0      0.599664         4.0
# 463           200.0      0.641893         4.0
# 464           200.0      0.492204         4.0
# 465           200.0      0.660703         4.0
# 466           200.0      0.421900         4.0
# 467           200.0      0.618950         4.0
# 468           200.0      0.459973         4.0
# alt.VConcatChart(...)

# %%
# Model names: DecisionTreeClassifier, LogisticRegression, RandomForestClassifier, XGBClassifier, KNeighborsClassifier
visualizer.create_subgroups_grid_pct_lines_plot(model_name='KNeighborsClassifier',
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics=['Accuracy', 'F1', 'Jitter', 'Label_Stability'],
                                                mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
# Model names: DecisionTreeClassifier, LogisticRegression, RandomForestClassifier, XGBClassifier, KNeighborsClassifier
visualizer.create_grid_for_metrics_comparison(model_name='KNeighborsClassifier',
                                              target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                              subgroup_metrics=['F1', 'Label_Stability'],
                                              group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                              mode='max_num_columns')
# Out:
# alt.VConcatChart(...)
