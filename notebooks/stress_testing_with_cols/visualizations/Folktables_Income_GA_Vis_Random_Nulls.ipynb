# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'stress_testing_with_cols_nulls'
DB_COLLECTION_NAME = f'exp_{EXPERIMENT_NAME}'
DATASET_NAME = 'Folktables_Income_GA_2018'
EXPERIMENT_SESSION_UUID = '0526bade-b7fd-49f6-8123-56ed620e55ec'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'AGEP', 'SEX&RAC1P', 'RAC1P&AGEP']
PREPROCESSING_TECHNIQUES = ['cat: mode, num: median']

# %%
# MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression', 'RandomForestClassifier',
#                'XGBClassifier', 'KNeighborsClassifier']

MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (80, 29)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  DecisionTreeClassifier
# 1   Accuracy                   101  DecisionTreeClassifier
# 2   Accuracy                   101  DecisionTreeClassifier
# 3   Accuracy                   101  DecisionTreeClassifier
# 4   Accuracy                   101  DecisionTreeClassifier
# 10   Entropy                   101  DecisionTreeClassifier
# 11   Entropy                   101  DecisionTreeClassifier
# 12   Entropy                   101  DecisionTreeClassifier
# 13   Entropy                   101  DecisionTreeClassifier
# 14   Entropy                   101  DecisionTreeClassifier
# 20        F1                   101  DecisionTreeClassifier
# 21        F1                   101  DecisionTreeClassifier
# 22        F1                   101  DecisionTreeClassifier
# 23        F1                   101  DecisionTreeClassifier
# 24        F1                   101  DecisionTreeClassifier
# 30       FNR                   101  DecisionTreeClassifier
# 31       FNR                   101  DecisionTreeClassifier
# 32       FNR                   101  DecisionTreeClassifier
# 33       FNR                   101  DecisionTreeClassifier
# 34       FNR                   101  DecisionTreeClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 1   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 2   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 3   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 10  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 11  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 12  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 13  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 14  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 20  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 21  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 22  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 23  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 24  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 30  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 31  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 32  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 33  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 34  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
#
#                  Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
# 0   Folktables_Income_GA_2018              10               0  OK
# 1   Folktables_Income_GA_2018              10               1  OK
# 2   Folktables_Income_GA_2018              10               2  OK
# 3   Folktables_Income_GA_2018              10               3  OK
# 4   Folktables_Income_GA_2018              10               4  OK
# 10  Folktables_Income_GA_2018              10               0  OK
# 11  Folktables_Income_GA_2018              10               1  OK
# 12  Folktables_Income_GA_2018              10               2  OK
# 13  Folktables_Income_GA_2018              10               3  OK
# 14  Folktables_Income_GA_2018              10               4  OK
# 20  Folktables_Income_GA_2018              10               0  OK
# 21  Folktables_Income_GA_2018              10               1  OK
# 22  Folktables_Income_GA_2018              10               2  OK
# 23  Folktables_Income_GA_2018              10               3  OK
# 24  Folktables_Income_GA_2018              10               4  OK
# 30  Folktables_Income_GA_2018              10               0  OK
# 31  Folktables_Income_GA_2018              10               1  OK
# 32  Folktables_Income_GA_2018              10               2  OK
# 33  Folktables_Income_GA_2018              10               3  OK
# 34  Folktables_Income_GA_2018              10               4  OK
#
#    Record_Create_Date_Time  ... AGEP_priv RAC1P&AGEP_dis RAC1P&AGEP_priv  \
# 0  2023-05-02 22:30:37.427  ...  0.782194       0.806220        0.766749
# 1  2023-05-02 22:30:37.453  ...  0.777424       0.789474        0.764268
# 2  2023-05-02 22:30:37.474  ...  0.774245       0.791866        0.756824
# 3  2023-05-02 22:30:37.497  ...  0.756757       0.770335        0.734491
# 4  2023-05-02 22:30:37.519  ...  0.751987       0.791866        0.734491
# 10 2023-05-02 22:30:37.427  ...  0.000000       0.000000        0.000000
# 11 2023-05-02 22:30:37.453  ...  0.000000       0.000000        0.000000
# 12 2023-05-02 22:30:37.474  ...  0.000000       0.000000        0.000000
# 13 2023-05-02 22:30:37.497  ...  0.000000       0.000000        0.000000
# 14 2023-05-02 22:30:37.519  ...  0.000000       0.000000        0.000000
# 20 2023-05-02 22:30:37.427  ...  0.706638       0.584615        0.711656
# 21 2023-05-02 22:30:37.453  ...  0.700855       0.560000        0.707692
# 22 2023-05-02 22:30:37.474  ...  0.701681       0.583732        0.703030
# 23 2023-05-02 22:30:37.497  ...  0.684536       0.533981        0.684366
# 24 2023-05-02 22:30:37.519  ...  0.675000       0.579710        0.682493
# 30 2023-05-02 22:30:37.427  ...  0.300847       0.451923        0.283951
# 31 2023-05-02 22:30:37.453  ...  0.305085       0.461538        0.290123
# 32 2023-05-02 22:30:37.474  ...  0.292373       0.413462        0.283951
# 33 2023-05-02 22:30:37.497  ...  0.296610       0.471154        0.283951
# 34 2023-05-02 22:30:37.519  ...  0.313559       0.423077        0.290123
#
#    RAC1P_dis RAC1P_priv  SEX&RAC1P_dis  SEX&RAC1P_priv   SEX_dis  SEX_priv  \
# 0   0.807453   0.780236       0.831858        0.754248  0.820430  0.761682
# 1   0.793478   0.769912       0.820059        0.743791  0.809677  0.749533
# 2   0.796584   0.773599       0.825959        0.749020  0.812903  0.753271
# 3   0.779503   0.757375       0.805310        0.729412  0.797849  0.735514
# 4   0.788820   0.762537       0.811209        0.742484  0.796774  0.748598
# 10  0.000000   0.239663       0.183004        0.269876  0.194158  0.252157
# 11  0.000000   0.244293       0.000000        0.272374  0.000000  0.252299
# 12  0.000000   0.247122       0.196829        0.281117  0.200826  0.268132
# 13  0.000000   0.239147       0.192238        0.268541  0.197869  0.252869
# 14  0.000000   0.232054       0.193412        0.261780  0.193517  0.252042
# 20  0.630952   0.705534       0.641509        0.717718  0.669307  0.697509
# 21  0.612245   0.695312       0.621118        0.709199  0.653620  0.686916
# 22  0.630986   0.699314       0.638037        0.715134  0.658824  0.695150
# 23  0.596591   0.682739       0.592593        0.698690  0.632812  0.677309
# 24  0.611429   0.690979       0.589744        0.714078  0.628684  0.695357
# 30  0.404494   0.313462       0.392857        0.301170  0.354962  0.325688
# 31  0.410112   0.315385       0.404762        0.301170  0.362595  0.325688
# 32  0.370787   0.313462       0.380952        0.295322  0.358779  0.309633
# 33  0.410112   0.319231       0.428571        0.298246  0.381679  0.318807
# 34  0.398876   0.307692       0.452381        0.280702  0.389313  0.295872
#
#      overall
# 0   0.789000
# 1   0.777500
# 2   0.781000
# 3   0.764500
# 4   0.771000
# 10  0.225188
# 11  0.226854
# 12  0.236835
# 13  0.227294
# 14  0.224828
# 20  0.686944
# 21  0.674470
# 22  0.681686
# 23  0.660907
# 24  0.670977
# 30  0.336676
# 31  0.339542
# 32  0.328080
# 33  0.342407
# 34  0.330946
#
# [20 rows x 29 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_avg_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_avg_runs_group_metrics_dct=exp_avg_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %% [markdown]
# ### Subgroup metrics per dataset, experiment iteration, and model

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='variance',
                                                mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='error',
                                                mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Group metrics per dataset and model

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='variance',
                                             mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='fairness',
                                             mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset and multiple models

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Jitter',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Label_Stability',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='F1',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Accuracy',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific group metric per dataset, experiment iteration, and multiple models

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric=visualizer.all_group_variance_metrics_lst[1],
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES,
                                                       mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric='Disparate_Impact',
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES,
                                                       mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset, one model, and multiple preprocessing techniques

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_and_preprocessing_plot(subgroup_metric='Jitter',
                                                                            model_name=MODEL_NAMES[0],
                                                                            mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Box plots for subgroup metrics per model and experiment iteration

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for subgroup metrics per model and error level

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for group metrics per model and error level

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='SEX',
                                                                  group_metrics_type='fairness')

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='SEX',
                                                                  group_metrics_type='variance')

# %% [markdown]
# ### One box plot for both error and variance metrics for subgroups

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics=['F1', 'Accuracy', 'Jitter', 'Label_Stability'])
