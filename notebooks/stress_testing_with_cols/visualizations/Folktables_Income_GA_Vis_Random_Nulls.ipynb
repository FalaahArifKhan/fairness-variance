# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'stress_testing_with_cols_nulls'
DB_COLLECTION_NAME = f'exp_{EXPERIMENT_NAME}'
DATASET_NAME = 'Folktables_Income_GA_2018'
EXPERIMENT_SESSION_UUID = '468547b3-837f-4b3a-8262-f66f2cc13783'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'AGEP', 'SEX&RAC1P', 'RAC1P&AGEP']
PREPROCESSING_TECHNIQUES = ['cat: mode, num: median']

# %%
MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression', 'RandomForestClassifier',
               'XGBClassifier', 'KNeighborsClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (400, 29)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  DecisionTreeClassifier
# 1   Accuracy                   101  DecisionTreeClassifier
# 2   Accuracy                   101  DecisionTreeClassifier
# 3   Accuracy                   101  DecisionTreeClassifier
# 4   Accuracy                   101  DecisionTreeClassifier
# 25  Accuracy                   201  DecisionTreeClassifier
# 26  Accuracy                   201  DecisionTreeClassifier
# 27  Accuracy                   201  DecisionTreeClassifier
# 28  Accuracy                   201  DecisionTreeClassifier
# 29  Accuracy                   201  DecisionTreeClassifier
# 50  Accuracy                   301  DecisionTreeClassifier
# 51  Accuracy                   301  DecisionTreeClassifier
# 52  Accuracy                   301  DecisionTreeClassifier
# 53  Accuracy                   301  DecisionTreeClassifier
# 54  Accuracy                   301  DecisionTreeClassifier
# 75  Accuracy                   401  DecisionTreeClassifier
# 76  Accuracy                   401  DecisionTreeClassifier
# 77  Accuracy                   401  DecisionTreeClassifier
# 78  Accuracy                   401  DecisionTreeClassifier
# 79  Accuracy                   401  DecisionTreeClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 1   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 2   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 3   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 25  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 26  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 27  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 28  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 29  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 50  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 51  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 52  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 53  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 54  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 75  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 76  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 77  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 78  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 79  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
#
#                  Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
# 0   Folktables_Income_GA_2018             200               0  OK
# 1   Folktables_Income_GA_2018             200               1  OK
# 2   Folktables_Income_GA_2018             200               2  OK
# 3   Folktables_Income_GA_2018             200               3  OK
# 4   Folktables_Income_GA_2018             200               4  OK
# 25  Folktables_Income_GA_2018             200               0  OK
# 26  Folktables_Income_GA_2018             200               1  OK
# 27  Folktables_Income_GA_2018             200               2  OK
# 28  Folktables_Income_GA_2018             200               3  OK
# 29  Folktables_Income_GA_2018             200               4  OK
# 50  Folktables_Income_GA_2018             200               0  OK
# 51  Folktables_Income_GA_2018             200               1  OK
# 52  Folktables_Income_GA_2018             200               2  OK
# 53  Folktables_Income_GA_2018             200               3  OK
# 54  Folktables_Income_GA_2018             200               4  OK
# 75  Folktables_Income_GA_2018             200               0  OK
# 76  Folktables_Income_GA_2018             200               1  OK
# 77  Folktables_Income_GA_2018             200               2  OK
# 78  Folktables_Income_GA_2018             200               3  OK
# 79  Folktables_Income_GA_2018             200               4  OK
#
#    Record_Create_Date_Time  ... AGEP_priv RAC1P&AGEP_dis RAC1P&AGEP_priv  \
# 0  2023-05-03 01:23:22.998  ...  0.794913       0.801435        0.776675
# 1  2023-05-03 01:23:23.009  ...  0.783784       0.787081        0.766749
# 2  2023-05-03 01:23:23.020  ...  0.780604       0.794258        0.761787
# 3  2023-05-03 01:23:23.030  ...  0.766296       0.775120        0.741935
# 4  2023-05-03 01:23:23.040  ...  0.764706       0.784689        0.749380
# 25 2023-05-03 01:51:19.294  ...  0.787597       0.828087        0.773672
# 26 2023-05-03 01:51:19.306  ...  0.776744       0.813559        0.771363
# 27 2023-05-03 01:51:19.317  ...  0.772093       0.808717        0.752887
# 28 2023-05-03 01:51:19.327  ...  0.764341       0.813559        0.762125
# 29 2023-05-03 01:51:19.337  ...  0.755039       0.786925        0.732102
# 50 2023-05-03 01:36:56.858  ...  0.768254       0.847682        0.729114
# 51 2023-05-03 01:36:56.869  ...  0.760317       0.836645        0.729114
# 52 2023-05-03 01:36:56.880  ...  0.760317       0.825607        0.726582
# 53 2023-05-03 01:36:56.891  ...  0.753968       0.832230        0.721519
# 54 2023-05-03 01:36:56.902  ...  0.738095       0.825607        0.708861
# 75 2023-05-03 01:18:39.067  ...  0.794872       0.821346        0.767442
# 76 2023-05-03 01:18:39.079  ...  0.779789       0.816705        0.751163
# 77 2023-05-03 01:18:39.091  ...  0.767722       0.807425        0.741860
# 78 2023-05-03 01:18:39.103  ...  0.772247       0.800464        0.755814
# 79 2023-05-03 01:18:39.116  ...  0.770739       0.805104        0.748837
#
#    RAC1P_dis RAC1P_priv  SEX&RAC1P_dis  SEX&RAC1P_priv   SEX_dis  SEX_priv  \
# 0   0.810559   0.786873       0.828909        0.769935  0.816129  0.775701
# 1   0.796584   0.772861       0.814159        0.750327  0.806452  0.757944
# 2   0.801242   0.779499       0.823009        0.758170  0.812903  0.763551
# 3   0.787267   0.763274       0.799410        0.738562  0.796774  0.748598
# 4   0.787267   0.768437       0.802360        0.751634  0.794624  0.757009
# 25  0.824000   0.794182       0.831746        0.779452  0.817708  0.790385
# 26  0.804800   0.792727       0.815873        0.778082  0.811458  0.782692
# 27  0.809600   0.776727       0.822222        0.753425  0.809375  0.766346
# 28  0.798400   0.777455       0.806349        0.758904  0.801042  0.768269
# 29  0.792000   0.758545       0.796825        0.742466  0.783333  0.755769
# 50  0.843023   0.788110       0.855856        0.790859  0.810401  0.804085
# 51  0.828488   0.784299       0.825826        0.790859  0.794150  0.804085
# 52  0.822674   0.776677       0.834835        0.779778  0.795233  0.790158
# 53  0.824128   0.778963       0.834835        0.778393  0.799567  0.790158
# 54  0.812500   0.766006       0.828829        0.771468  0.784399  0.779944
# 75  0.829819   0.792665       0.855457        0.762350  0.840173  0.774674
# 76  0.822289   0.782186       0.843658        0.757009  0.825054  0.770019
# 77  0.810241   0.770210       0.837758        0.742323  0.817495  0.754190
# 78  0.801205   0.778443       0.817109        0.754339  0.812095  0.763501
# 79  0.807229   0.772455       0.825959        0.735648  0.821814  0.751397
#
#     overall
# 0    0.7945
# 1    0.7805
# 2    0.7865
# 3    0.7710
# 4    0.7745
# 25   0.8035
# 26   0.7965
# 27   0.7870
# 28   0.7840
# 29   0.7690
# 50   0.8070
# 51   0.7995
# 52   0.7925
# 53   0.7945
# 54   0.7820
# 75   0.8050
# 76   0.7955
# 77   0.7835
# 78   0.7860
# 79   0.7840
#
# [20 rows x 29 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_avg_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_avg_runs_group_metrics_dct=exp_avg_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %% [markdown]
# ### Subgroup metrics per dataset, experiment iteration, and model

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='variance',
                                                mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='error',
                                                mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Group metrics per dataset and model

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='variance',
                                             mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='fairness',
                                             mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset and multiple models

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Jitter',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Label_Stability',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='F1',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Accuracy',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES,
                                                          mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific group metric per dataset, experiment iteration, and multiple models

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric=visualizer.all_group_variance_metrics_lst[1],
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES,
                                                       mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric='Disparate_Impact',
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES,
                                                       mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset, one model, and multiple preprocessing techniques

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_and_preprocessing_plot(subgroup_metric='Jitter',
                                                                            model_name=MODEL_NAMES[0],
                                                                            mode='max_num_columns')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Box plots for subgroup metrics per model and experiment iteration

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=1,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for subgroup metrics per model and error level

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='error')

# %% [markdown]
# ### Box plots for group metrics per model and error level

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='SEX',
                                                                  group_metrics_type='fairness')

# %%
visualizer.create_group_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                  target_group='SEX',
                                                                  group_metrics_type='variance')

# %% [markdown]
# ### One box plot for both error and variance metrics for subgroups

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics=['F1', 'Accuracy', 'Jitter', 'Label_Stability'],
                                                                     legend_loc='lower left')
