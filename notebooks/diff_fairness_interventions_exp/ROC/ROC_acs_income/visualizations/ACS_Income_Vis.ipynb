# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
EXPERIMENT_SESSION_UUID = 'bec5d2ec-0722-484c-b70b-a0206f680965'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
SENSITIVE_ATTR_FOR_INTERVENTION = 'SEX&RAC1P'
MODEL_NAMES = ['LogisticRegression']
# MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (12, 33)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#              Metric          Model_Name  \
# 0          Accuracy  LogisticRegression
# 1                F1  LogisticRegression
# 2               FNR  LogisticRegression
# 3               FPR  LogisticRegression
# 4            Jitter  LogisticRegression
# 5   Label_Stability  LogisticRegression
# 6               PPV  LogisticRegression
# 7     Positive-Rate  LogisticRegression
# 8       Sample_Size  LogisticRegression
# 9    Selection-Rate  LogisticRegression
# 10              TNR  LogisticRegression
# 11              TPR  LogisticRegression
#
#                                          Model_Params  \
# 0   {'C': 1, 'class_weight': None, 'dual': False, ...
# 1   {'C': 1, 'class_weight': None, 'dual': False, ...
# 2   {'C': 1, 'class_weight': None, 'dual': False, ...
# 3   {'C': 1, 'class_weight': None, 'dual': False, ...
# 4   {'C': 1, 'class_weight': None, 'dual': False, ...
# 5   {'C': 1, 'class_weight': None, 'dual': False, ...
# 6   {'C': 1, 'class_weight': None, 'dual': False, ...
# 7   {'C': 1, 'class_weight': None, 'dual': False, ...
# 8   {'C': 1, 'class_weight': None, 'dual': False, ...
# 9   {'C': 1, 'class_weight': None, 'dual': False, ...
# 10  {'C': 1, 'class_weight': None, 'dual': False, ...
# 11  {'C': 1, 'class_weight': None, 'dual': False, ...
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 1   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 2   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 3   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 4   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 5   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 6   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 7   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 8   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 9   Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 10  Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
# 11  Folktables_GA_2018_Income              50  OK 2024-01-05 15:51:09.908
#
#                             Session_Uuid Experiment_Iteration  \
# 0   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 1   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 2   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 3   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 4   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 5   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 6   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 7   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 8   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 9   bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 10  bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
# 11  bec5d2ec-0722-484c-b70b-a0206f680965           Exp_iter_1
#
#     Dataset_Split_Seed  ...  SEX&RAC1P_priv_correct SEX&RAC1P_priv_incorrect  \
# 0                  100  ...                1.000000                 0.000000
# 1                  100  ...                1.000000                 0.000000
# 2                  100  ...                0.000000                      NaN
# 3                  100  ...                0.000000                 1.000000
# 4                  100  ...                0.030991                 0.080875
# 5                  100  ...                0.951418                 0.901681
# 6                  100  ...                1.000000                 0.000000
# 7                  100  ...                1.000000                      inf
# 8                  100  ...              275.000000               345.000000
# 9                  100  ...                0.876364                 1.000000
# 10                 100  ...                1.000000                 0.000000
# 11                 100  ...                1.000000                      NaN
#
#        SEX_dis  SEX_dis_correct  SEX_dis_incorrect    SEX_priv  \
# 0     0.353723         1.000000           0.000000    0.505348
# 1     0.461197         1.000000           0.000000    0.644914
# 2     0.000000         0.000000                NaN    0.000000
# 3     0.893382         0.000000           1.000000    0.898058
# 4     0.068250         0.049943           0.078270    0.057344
# 5     0.913404         0.926917           0.906008    0.923636
# 6     0.299712         1.000000           0.000000    0.475921
# 7     3.336538         1.000000                inf    2.101190
# 8   376.000000       133.000000         243.000000  374.000000
# 9     0.922872         0.781955           1.000000    0.943850
# 10    0.106618         1.000000           0.000000    0.101942
# 11    1.000000         1.000000                NaN    1.000000
#
#     SEX_priv_correct  SEX_priv_incorrect     overall  Test_Set_Index
# 0           1.000000            0.000000    0.429333               0
# 1           1.000000            0.000000    0.559671               0
# 2           0.000000                 NaN    0.000000               0
# 3           0.000000            1.000000    0.895397               0
# 4           0.029530            0.085758    0.062811               0
# 5           0.951958            0.894703    0.918507               0
# 6           1.000000            0.000000    0.388571               0
# 7           1.000000                 inf    2.573529               0
# 8         189.000000          185.000000  750.000000               0
# 9           0.888889            1.000000    0.933333               0
# 10          1.000000            0.000000    0.104603               0
# 11          1.000000                 NaN    1.000000               0
#
# [12 rows x 33 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           # ylim=(0.75, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Difference'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Statistical_Parity_Difference'],
                                           vals_to_replace=vals_to_replace)
