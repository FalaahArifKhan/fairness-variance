# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
EXPERIMENT_SESSION_UUID = '0626d80f-e288-4f16-b8ab-260eb34d62d3'
SENSITIVE_ATTRS = ['sex']
SENSITIVE_ATTR_FOR_INTERVENTION = 'sex'
# MODEL_NAMES = ['LogisticRegression']
MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (72, 21)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#               Metric      Model_Name  \
# 0           Accuracy  LGBMClassifier
# 24                F1  LGBMClassifier
# 48               FNR  LGBMClassifier
# 72               FPR  LGBMClassifier
# 96            Jitter  LGBMClassifier
# 120  Label_Stability  LGBMClassifier
# 144              PPV  LGBMClassifier
# 168    Positive-Rate  LGBMClassifier
# 192      Sample_Size  LGBMClassifier
# 216   Selection-Rate  LGBMClassifier
# 240              TNR  LGBMClassifier
# 264              TPR  LGBMClassifier
#
#                                           Model_Params  \
# 0    {'boosting_type': 'gbdt', 'class_weight': None...
# 24   {'boosting_type': 'gbdt', 'class_weight': None...
# 48   {'boosting_type': 'gbdt', 'class_weight': None...
# 72   {'boosting_type': 'gbdt', 'class_weight': None...
# 96   {'boosting_type': 'gbdt', 'class_weight': None...
# 120  {'boosting_type': 'gbdt', 'class_weight': None...
# 144  {'boosting_type': 'gbdt', 'class_weight': None...
# 168  {'boosting_type': 'gbdt', 'class_weight': None...
# 192  {'boosting_type': 'gbdt', 'class_weight': None...
# 216  {'boosting_type': 'gbdt', 'class_weight': None...
# 240  {'boosting_type': 'gbdt', 'class_weight': None...
# 264  {'boosting_type': 'gbdt', 'class_weight': None...
#
#                 Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0    Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 24   Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 48   Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 72   Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 96   Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 120  Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 144  Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 168  Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 192  Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 216  Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 240  Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
# 264  Student_Performance_Por             200  OK 2024-01-04 22:15:38.409
#
#                              Session_Uuid Experiment_Iteration  \
# 0    0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 24   0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 48   0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 72   0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 96   0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 120  0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 144  0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 168  0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 192  0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 216  0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 240  0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
# 264  0626d80f-e288-4f16-b8ab-260eb34d62d3           Exp_iter_1
#
#      Dataset_Split_Seed  ...  Fair_Intervention_Params_Lst Intervention_Param  \
# 0                   100  ...                        [True]               True
# 24                  100  ...                        [True]               True
# 48                  100  ...                        [True]               True
# 72                  100  ...                        [True]               True
# 96                  100  ...                        [True]               True
# 120                 100  ...                        [True]               True
# 144                 100  ...                        [True]               True
# 168                 100  ...                        [True]               True
# 192                 100  ...                        [True]               True
# 216                 100  ...                        [True]               True
# 240                 100  ...                        [True]               True
# 264                 100  ...                        [True]               True
#
#         overall    sex_dis  sex_dis_correct  sex_dis_incorrect   sex_priv  \
# 0      0.840491   0.882979              1.0           0.000000   0.782609
# 24     0.913333   0.937853              1.0           0.000000   0.878049
# 48     0.000000   0.000000              0.0                NaN   0.000000
# 72     1.000000   1.000000              NaN           1.000000   1.000000
# 96     0.002140   0.001590              0.0           0.013591   0.002890
# 120    0.997853   0.998404              1.0           0.986364   0.997101
# 144    0.840491   0.882979              1.0           0.000000   0.782609
# 168    1.189781   1.132530              1.0                inf   1.277778
# 192  163.000000  94.000000             83.0          11.000000  69.000000
# 216    1.000000   1.000000              1.0           1.000000   1.000000
# 240    0.000000   0.000000              NaN           0.000000   0.000000
# 264    1.000000   1.000000              1.0                NaN   1.000000
#
#      sex_priv_correct  sex_priv_incorrect  Test_Set_Index
# 0                 1.0            0.000000               0
# 24                1.0            0.000000               0
# 48                0.0                 NaN               0
# 72                NaN            1.000000               0
# 96                0.0            0.013293               0
# 120               1.0            0.986667               0
# 144               1.0            0.000000               0
# 168               1.0                 inf               0
# 192              54.0           15.000000               0
# 216               1.0            1.000000               0
# 240               NaN            0.000000               0
# 264               1.0                 NaN               0
#
# [12 rows x 21 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           ylim=(0.75, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Difference'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Statistical_Parity_Difference'],
                                           vals_to_replace=vals_to_replace)
