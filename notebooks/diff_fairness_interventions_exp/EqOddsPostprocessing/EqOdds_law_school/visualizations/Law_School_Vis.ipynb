# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
EXPERIMENT_SESSION_UUID = '567e7e80-5ed4-4a45-8927-2f7b61ba5647'
SENSITIVE_ATTRS = ['male', 'race']
SENSITIVE_ATTR_FOR_INTERVENTION = 'race'
# MODEL_NAMES = ['LogisticRegression']
MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (72, 33)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#               Metric      Model_Name  \
# 0           Accuracy  LGBMClassifier
# 24                F1  LGBMClassifier
# 48               FNR  LGBMClassifier
# 72               FPR  LGBMClassifier
# 96            Jitter  LGBMClassifier
# 120  Label_Stability  LGBMClassifier
# 144              PPV  LGBMClassifier
# 168    Positive-Rate  LGBMClassifier
# 192      Sample_Size  LGBMClassifier
# 216   Selection-Rate  LGBMClassifier
# 240              TNR  LGBMClassifier
# 264              TPR  LGBMClassifier
#
#                                           Model_Params Dataset_Name  \
# 0    {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 24   {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 48   {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 72   {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 96   {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 120  {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 144  {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 168  {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 192  {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 216  {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 240  {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
# 264  {'boosting_type': 'gbdt', 'class_weight': None...   Law_School
#
#      Num_Estimators Tag Record_Create_Date_Time  \
# 0               200  OK 2024-01-04 12:23:39.246
# 24              200  OK 2024-01-04 12:23:39.246
# 48              200  OK 2024-01-04 12:23:39.246
# 72              200  OK 2024-01-04 12:23:39.246
# 96              200  OK 2024-01-04 12:23:39.246
# 120             200  OK 2024-01-04 12:23:39.246
# 144             200  OK 2024-01-04 12:23:39.246
# 168             200  OK 2024-01-04 12:23:39.246
# 192             200  OK 2024-01-04 12:23:39.246
# 216             200  OK 2024-01-04 12:23:39.246
# 240             200  OK 2024-01-04 12:23:39.246
# 264             200  OK 2024-01-04 12:23:39.246
#
#                              Session_Uuid Experiment_Iteration  \
# 0    567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 24   567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 48   567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 72   567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 96   567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 120  567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 144  567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 168  567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 192  567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 216  567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 240  567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
# 264  567e7e80-5ed4-4a45-8927-2f7b61ba5647           Exp_iter_1
#
#      Dataset_Split_Seed  ...  male_priv_correct male_priv_incorrect  \
# 0                   100  ...           1.000000            0.000000
# 24                  100  ...           1.000000            0.000000
# 48                  100  ...           0.000000            1.000000
# 72                  100  ...           0.000000            1.000000
# 96                  100  ...           0.047433            0.155780
# 120                 100  ...           0.945891            0.783967
# 144                 100  ...           1.000000            0.000000
# 168                 100  ...           1.000000           22.461538
# 192                 100  ...        2580.000000          305.000000
# 216                 100  ...           0.992636            0.957377
# 240                 100  ...           1.000000            0.000000
# 264                 100  ...           1.000000            0.000000
#
#          overall    race_dis  race_dis_correct  race_dis_incorrect  \
# 0       0.888654    0.709069          1.000000            0.000000
# 24      0.940621    0.829773          1.000000            0.000000
# 48      0.003910    0.000000          0.000000                 NaN
# 72      0.941275    1.000000               NaN            1.000000
# 96      0.061325    0.124430          0.069270            0.258869
# 120     0.924602    0.819965          0.902409            0.619028
# 144     0.891004    0.709069          1.000000            0.000000
# 168     1.117941    1.410299          1.000000                 inf
# 192  5200.000000  849.000000        602.000000          247.000000
# 216     0.989808    1.000000          1.000000            1.000000
# 240     0.058725    0.000000               NaN            0.000000
# 264     0.996090    1.000000          1.000000                 NaN
#
#        race_priv  race_priv_correct  race_priv_incorrect  Test_Set_Index
# 0       0.923696           1.000000             0.000000               0
# 24      0.960000           1.000000             0.000000               0
# 48      0.004498           0.000000             1.000000               0
# 72      0.899713           0.000000             1.000000               0
# 96      0.049011           0.045108             0.096256               0
# 120     0.945020           0.950421             0.879639               0
# 144     0.926943           1.000000             0.000000               0
# 168     1.073963           1.000000            17.444444               0
# 192  4351.000000        4019.000000           332.000000               0
# 216     0.987819           0.991291             0.945783               0
# 240     0.100287           1.000000             0.000000               0
# 264     0.995502           1.000000             0.000000               0
#
# [12 rows x 33 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           # ylim=(0.75, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Difference'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Statistical_Parity_Difference'],
                                           vals_to_replace=vals_to_replace)
