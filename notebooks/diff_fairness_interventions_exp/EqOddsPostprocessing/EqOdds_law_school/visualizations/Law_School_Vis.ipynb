# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_bar_plot_for_model_selection

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
EXPERIMENT_SESSION_UUID = '9750a063-e9d0-4d32-bdc6-5ba735602c1c'
SENSITIVE_ATTRS = ['male', 'race']
SENSITIVE_ATTR_FOR_INTERVENTION = 'race'
MODEL_NAMES = ['LogisticRegression']
# MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (12, 33)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#              Metric          Model_Name  \
# 0          Accuracy  LogisticRegression
# 1                F1  LogisticRegression
# 2               FNR  LogisticRegression
# 3               FPR  LogisticRegression
# 4            Jitter  LogisticRegression
# 5   Label_Stability  LogisticRegression
# 6               PPV  LogisticRegression
# 7     Positive-Rate  LogisticRegression
# 8       Sample_Size  LogisticRegression
# 9    Selection-Rate  LogisticRegression
# 10              TNR  LogisticRegression
# 11              TPR  LogisticRegression
#
#                                          Model_Params Dataset_Name  \
# 0   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 1   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 2   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 3   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 4   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 5   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 6   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 7   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 8   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 9   {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 10  {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
# 11  {'C': 1, 'class_weight': None, 'dual': False, ...   Law_School
#
#     Num_Estimators Tag Record_Create_Date_Time  \
# 0              200  OK 2024-01-03 23:48:09.133
# 1              200  OK 2024-01-03 23:48:09.133
# 2              200  OK 2024-01-03 23:48:09.133
# 3              200  OK 2024-01-03 23:48:09.133
# 4              200  OK 2024-01-03 23:48:09.133
# 5              200  OK 2024-01-03 23:48:09.133
# 6              200  OK 2024-01-03 23:48:09.133
# 7              200  OK 2024-01-03 23:48:09.133
# 8              200  OK 2024-01-03 23:48:09.133
# 9              200  OK 2024-01-03 23:48:09.133
# 10             200  OK 2024-01-03 23:48:09.133
# 11             200  OK 2024-01-03 23:48:09.133
#
#                             Session_Uuid Experiment_Iteration  \
# 0   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 1   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 2   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 3   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 4   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 5   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 6   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 7   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 8   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 9   9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 10  9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
# 11  9750a063-e9d0-4d32-bdc6-5ba735602c1c           Exp_iter_1
#
#     Dataset_Split_Seed  ...  male_priv_correct male_priv_incorrect  \
# 0                  100  ...           1.000000            0.000000
# 1                  100  ...           1.000000            0.000000
# 2                  100  ...           0.000000            1.000000
# 3                  100  ...           0.000000            1.000000
# 4                  100  ...           0.036407            0.109855
# 5                  100  ...           0.960435            0.857662
# 6                  100  ...           1.000000            0.000000
# 7                  100  ...           1.000000           19.533333
# 8                  100  ...        2577.000000          308.000000
# 9                  100  ...           0.993015            0.951299
# 10                 100  ...           1.000000            0.000000
# 11                 100  ...           1.000000            0.000000
#
#         overall    race_dis  race_dis_correct  race_dis_incorrect  \
# 0      0.887115    0.709069          1.000000            0.000000
# 1      0.939764    0.829773          1.000000            0.000000
# 2      0.005430    0.000000          0.000000                 NaN
# 3      0.942953    1.000000               NaN            1.000000
# 4      0.046261    0.092147          0.046341            0.203789
# 5      0.946581    0.878375          0.939369            0.729717
# 6      0.890683    0.709069          1.000000            0.000000
# 7      1.116638    1.410299          1.000000                 inf
# 8   5200.000000  849.000000        602.000000          247.000000
# 9      0.988654    1.000000          1.000000            1.000000
# 10     0.057047    0.000000               NaN            0.000000
# 11     0.994570    1.000000          1.000000                 NaN
#
#       race_priv  race_priv_correct  race_priv_incorrect  Test_Set_Index
# 0      0.921857           1.000000             0.000000               0
# 1      0.959007           1.000000             0.000000               0
# 2      0.006247           0.000000             1.000000               0
# 3      0.902579           0.000000             1.000000               0
# 4      0.037308           0.035137             0.062911               0
# 5      0.959890           0.963184             0.921029               0
# 6      0.926608           1.000000             0.000000               0
# 7      1.072464           1.000000            12.600000               0
# 8   4351.000000        4011.000000           340.000000               0
# 9      0.986440           0.991523             0.926471               0
# 10     0.097421           1.000000             0.000000               0
# 11     0.993753           1.000000             0.000000               0
#
# [12 rows x 33 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           # ylim=(0.75, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Difference'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Statistical_Parity_Difference'],
                                           vals_to_replace=vals_to_replace)
