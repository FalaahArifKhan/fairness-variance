# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
DATASET_NAME = 'Student_Performance_Por'
EXPERIMENT_SESSION_UUID = 'ac8635d8-9af0-41c0-816a-6ca2e4ad64dc'
# EXPERIMENT_SESSION_UUID = 'd1a5c7d4-9f88-47de-b872-3b6afaec580d'
# EXPERIMENT_SESSION_UUID = '860bd1b9-e881-4943-822f-4f8dd604428d'
# EXPERIMENT_SESSION_UUID = '5e69166c-e95f-41c8-b554-de7276d5bdf4'
SENSITIVE_ATTRS = ['sex']
MODEL_NAMES = ['LogisticRegression']
# MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (18, 21)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#                    Metric          Model_Name  \
# 0                Accuracy  LogisticRegression
# 1   Aleatoric_Uncertainty  LogisticRegression
# 2                      F1  LogisticRegression
# 3                     FNR  LogisticRegression
# 4                     FPR  LogisticRegression
# 5                     IQR  LogisticRegression
# 6                  Jitter  LogisticRegression
# 7         Label_Stability  LogisticRegression
# 8         Mean_Prediction  LogisticRegression
# 9     Overall_Uncertainty  LogisticRegression
# 10                    PPV  LogisticRegression
# 11          Positive-Rate  LogisticRegression
# 12            Sample_Size  LogisticRegression
# 13         Selection-Rate  LogisticRegression
# 14       Statistical_Bias  LogisticRegression
# 15                    Std  LogisticRegression
# 16                    TNR  LogisticRegression
# 17                    TPR  LogisticRegression
#
#                                          Model_Params  \
# 0   {'C': 1, 'class_weight': None, 'dual': False, ...
# 1   {'C': 1, 'class_weight': None, 'dual': False, ...
# 2   {'C': 1, 'class_weight': None, 'dual': False, ...
# 3   {'C': 1, 'class_weight': None, 'dual': False, ...
# 4   {'C': 1, 'class_weight': None, 'dual': False, ...
# 5   {'C': 1, 'class_weight': None, 'dual': False, ...
# 6   {'C': 1, 'class_weight': None, 'dual': False, ...
# 7   {'C': 1, 'class_weight': None, 'dual': False, ...
# 8   {'C': 1, 'class_weight': None, 'dual': False, ...
# 9   {'C': 1, 'class_weight': None, 'dual': False, ...
# 10  {'C': 1, 'class_weight': None, 'dual': False, ...
# 11  {'C': 1, 'class_weight': None, 'dual': False, ...
# 12  {'C': 1, 'class_weight': None, 'dual': False, ...
# 13  {'C': 1, 'class_weight': None, 'dual': False, ...
# 14  {'C': 1, 'class_weight': None, 'dual': False, ...
# 15  {'C': 1, 'class_weight': None, 'dual': False, ...
# 16  {'C': 1, 'class_weight': None, 'dual': False, ...
# 17  {'C': 1, 'class_weight': None, 'dual': False, ...
#
#                Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 1   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 2   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 3   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 4   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 5   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 6   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 7   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 8   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 9   Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 10  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 11  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 12  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 13  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 14  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 15  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 16  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
# 17  Student_Performance_Por             200  OK 2024-01-02 17:46:57.625
#
#                             Session_Uuid Experiment_Iteration  \
# 0   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 1   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 2   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 3   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 4   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 5   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 6   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 7   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 8   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 9   ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 10  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 11  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 12  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 13  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 14  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 15  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 16  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
# 17  ac8635d8-9af0-41c0-816a-6ca2e4ad64dc           Exp_iter_1
#
#     Dataset_Split_Seed  ...                  Fair_Intervention_Params_Lst  \
# 0                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 1                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 2                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 3                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 4                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 5                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 6                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 7                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 8                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 9                  100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 10                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 11                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 12                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 13                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 14                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 15                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 16                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
# 17                 100  ...  [{'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}]
#
#                             Intervention_Param     overall    sex_dis  \
# 0   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.865031   0.893617
# 1   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.343159   0.322026
# 2   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.920863   0.939759
# 3   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.065693   0.060241
# 4   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.500000   0.454545
# 5   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.027249   0.025467
# 6   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.013141   0.016999
# 7   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.982822   0.976702
# 8   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.170168   0.156880
# 9   {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.348055   0.326499
# 10  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.907801   0.939759
# 11  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    1.029197   1.000000
# 12  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}  163.000000  94.000000
# 13  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.865031   0.882979
# 14  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.161152   0.138937
# 15  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.021163   0.019515
# 16  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.500000   0.545455
# 17  {'k': 10, 'Ax': 0.1, 'Ay': 1.0, 'Az': 2.0}    0.934307   0.939759
#
#     sex_dis_correct  sex_dis_incorrect   sex_priv  sex_priv_correct  \
# 0          1.000000           0.000000   0.826087          1.000000
# 1          0.269022           0.767258   0.371948          0.303348
# 2          1.000000           0.000000   0.892857          1.000000
# 3          0.000000           1.000000   0.074074          0.000000
# 4          0.000000           1.000000   0.533333          0.000000
# 5          0.019459           0.075932   0.029677          0.022529
# 6          0.010644           0.070382   0.007885          0.000521
# 7          0.983690           0.918000   0.991159          0.999474
# 8          0.112740           0.527659   0.188269          0.151996
# 9          0.272348           0.781363   0.377421          0.307507
# 10         1.000000           0.000000   0.862069          1.000000
# 11         1.000000           1.000000   1.074074          1.000000
# 12        84.000000          10.000000  69.000000         57.000000
# 13         0.928571           0.500000   0.840580          0.877193
# 14         0.067880           0.735811   0.191417          0.067481
# 15         0.014994           0.057487   0.023409          0.017769
# 16         1.000000           0.000000   0.466667          1.000000
# 17         1.000000           0.000000   0.925926          1.000000
#
#     sex_priv_incorrect  Test_Set_Index
# 0             0.000000               0
# 1             0.697798               0
# 2             0.000000               0
# 3             1.000000               0
# 4             1.000000               0
# 5             0.063626               0
# 6             0.042864               0
# 7             0.951667               0
# 8             0.360566               0
# 9             0.709514               0
# 10            0.000000               0
# 11            2.000000               0
# 12           12.000000               0
# 13            0.666667               0
# 14            0.780112               0
# 15            0.050201               0
# 16            0.000000               0
# 17            0.000000               0
#
# [18 rows x 21 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           ylim=(0.75, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           metric_names=['Std', 'Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group='sex',
                                           metric_names=['Label_Stability_Difference'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group='sex',
                                           metric_names=['Aleatoric_Uncertainty_Parity',
                                                         'Overall_Uncertainty_Parity'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group='sex',
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group='sex',
                                           metric_names=['Statistical_Parity_Difference'],
                                           vals_to_replace=vals_to_replace)
