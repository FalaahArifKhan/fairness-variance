# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
EXPERIMENT_SESSION_UUID = '0a3f8d21-048c-4599-95fa-a7fcfa14623c'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
SENSITIVE_ATTR_FOR_INTERVENTION = 'SEX&RAC1P'
MODEL_NAMES = ['ExponentiatedGradientReduction']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (19, 33)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#                    Metric                      Model_Name  \
# 0                Accuracy  ExponentiatedGradientReduction
# 1   Aleatoric_Uncertainty  ExponentiatedGradientReduction
# 2   Epistemic_Uncertainty  ExponentiatedGradientReduction
# 3                      F1  ExponentiatedGradientReduction
# 4                     FNR  ExponentiatedGradientReduction
# 5                     FPR  ExponentiatedGradientReduction
# 6                     IQR  ExponentiatedGradientReduction
# 7                  Jitter  ExponentiatedGradientReduction
# 8         Label_Stability  ExponentiatedGradientReduction
# 9         Mean_Prediction  ExponentiatedGradientReduction
# 10    Overall_Uncertainty  ExponentiatedGradientReduction
# 11                    PPV  ExponentiatedGradientReduction
# 12          Positive-Rate  ExponentiatedGradientReduction
# 13            Sample_Size  ExponentiatedGradientReduction
# 14         Selection-Rate  ExponentiatedGradientReduction
# 15       Statistical_Bias  ExponentiatedGradientReduction
# 16                    Std  ExponentiatedGradientReduction
# 17                    TNR  ExponentiatedGradientReduction
# 18                    TPR  ExponentiatedGradientReduction
#
#                                          Model_Params  \
# 0   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 1   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 2   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 3   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 4   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 5   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 6   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 7   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 8   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 9   {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 10  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 11  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 12  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 13  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 14  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 15  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 16  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 17  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
# 18  {'sensitive_attr_for_intervention': 'SEX&RAC1P...
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 1   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 2   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 3   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 4   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 5   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 6   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 7   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 8   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 9   Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 10  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 11  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 12  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 13  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 14  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 15  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 16  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 17  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
# 18  Folktables_GA_2018_Income              10  OK 2024-01-10 00:41:27.581
#
#                             Session_Uuid Experiment_Iteration  \
# 0   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 1   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 2   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 3   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 4   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 5   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 6   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 7   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 8   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 9   0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 10  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 11  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 12  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 13  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 14  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 15  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 16  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 17  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
# 18  0a3f8d21-048c-4599-95fa-a7fcfa14623c           Exp_iter_1
#
#     Dataset_Split_Seed  ...  SEX&RAC1P_priv_correct SEX&RAC1P_priv_incorrect  \
# 0                  100  ...                1.000000                 0.000000
# 1                  100  ...                0.024705                 0.057150
# 2                  100  ...                0.113258                 0.303259
# 3                  100  ...                1.000000                 0.000000
# 4                  100  ...                0.000000                 1.000000
# 5                  100  ...                0.000000                 1.000000
# 6                  100  ...                0.062322                 0.185304
# 7                  100  ...                0.062149                 0.170774
# 8                  100  ...                0.919727                 0.775248
# 9                  100  ...                0.691044                 0.606215
# 10                 100  ...                0.137964                 0.360409
# 11                 100  ...                1.000000                 0.000000
# 12                 100  ...                1.000000                 0.594737
# 13                 100  ...             2489.000000               606.000000
# 14                 100  ...                0.307754                 0.372937
# 15                 100  ...                0.042673                 0.882342
# 16                 100  ...                0.072179                 0.190274
# 17                 100  ...                1.000000                 0.000000
# 18                 100  ...                1.000000                 0.000000
#
#         SEX_dis  SEX_dis_correct  SEX_dis_incorrect     SEX_priv  \
# 0      0.831198         1.000000           0.000000     0.785678
# 1      0.037282         0.031735           0.064599     0.030810
# 2      0.160580         0.121318           0.353912     0.139836
# 3      0.688592         1.000000           0.000000     0.717845
# 4      0.327309         0.000000           1.000000     0.336239
# 5      0.107941         0.000000           1.000000     0.129340
# 6      0.093325         0.066955           0.223175     0.080023
# 7      0.088022         0.065550           0.198680     0.078500
# 8      0.885682         0.915416           0.739274     0.897698
# 9      0.723002         0.761986           0.531041     0.649277
# 10     0.197862         0.153052           0.418512     0.170645
# 11     0.705263         1.000000           0.000000     0.781525
# 12     0.953815         1.000000           0.858896     0.849315
# 13  1795.000000      1492.000000         303.000000  1955.000000
# 14     0.264624         0.224531           0.462046     0.348849
# 15     0.183783         0.046010           0.862195     0.222904
# 16     0.102402         0.078527           0.219965     0.089296
# 17     0.892059         1.000000           0.000000     0.870660
# 18     0.672691         1.000000           0.000000     0.663761
#
#     SEX_priv_correct  SEX_priv_incorrect      overall  Test_Set_Index
# 0           1.000000            0.000000     0.807467               0
# 1           0.024094            0.055431     0.033908               0
# 2           0.104583            0.269067     0.149765               0
# 3           1.000000            0.000000     0.706265               0
# 4           0.000000            1.000000     0.332821               0
# 5           0.000000            1.000000     0.118007               0
# 6           0.056458            0.166407     0.086390               0
# 7           0.057943            0.153858     0.083058               0
# 8           0.925391            0.796181     0.891947               0
# 9           0.656702            0.622058     0.684567               0
# 10          0.128677            0.324497     0.183673               0
# 11          1.000000            0.000000     0.750216               0
# 12          1.000000            0.551852     0.889316               0
# 13       1536.000000          419.000000  3750.000000               0
# 14          0.347005            0.355609     0.308533               0
# 15          0.039792            0.894170     0.204178               0
# 16          0.067134            0.170538     0.095569               0
# 17          1.000000            0.000000     0.881993               0
# 18          1.000000            0.000000     0.667179               0
#
# [19 rows x 33 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           # ylim=(0.75, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           # ylim=(0.75, 1.0),
                                           metric_names=['Aleatoric_Uncertainty', 'Epistemic_Uncertainty', 'Std'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Difference'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Statistical_Parity_Difference'],
                                           vals_to_replace=vals_to_replace)
