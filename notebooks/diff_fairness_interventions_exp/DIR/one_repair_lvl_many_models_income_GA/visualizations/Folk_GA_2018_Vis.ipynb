# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_group_models_box_plot_per_test_set, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'one_repair_lvl_many_models_income_GA'
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
SENSITIVE_ATTR_FOR_INTERVENTION = 'SEX&RAC1P'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '114a1071-264b-49e6-b298-23db4031e9c2'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']
# MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (1320, 35)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#                     Metric  Bootstrap_Model_Seed      Model_Name  \
# 0                 Accuracy                   101  LGBMClassifier
# 1                 Accuracy                   101  LGBMClassifier
# 2                 Accuracy                   101  LGBMClassifier
# 3                 Accuracy                   101  LGBMClassifier
# 4                 Accuracy                   101  LGBMClassifier
# 5                 Accuracy                   101  LGBMClassifier
# 6                 Accuracy                   101  LGBMClassifier
# 7                 Accuracy                   101  LGBMClassifier
# 8                 Accuracy                   101  LGBMClassifier
# 9                 Accuracy                   101  LGBMClassifier
# 10                Accuracy                   101  LGBMClassifier
# 11                Accuracy                   101  LGBMClassifier
# 288  Aleatoric_Uncertainty                   101  LGBMClassifier
# 289  Aleatoric_Uncertainty                   101  LGBMClassifier
# 290  Aleatoric_Uncertainty                   101  LGBMClassifier
# 291  Aleatoric_Uncertainty                   101  LGBMClassifier
# 292  Aleatoric_Uncertainty                   101  LGBMClassifier
# 293  Aleatoric_Uncertainty                   101  LGBMClassifier
# 294  Aleatoric_Uncertainty                   101  LGBMClassifier
# 295  Aleatoric_Uncertainty                   101  LGBMClassifier
#
#                                           Model_Params Run_Number  \
# 0    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 1    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 2    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 3    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 4    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 5    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 6    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 7    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 8    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 9    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 10   {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 11   {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 288  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 289  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 290  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 291  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 292  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 293  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 294  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 295  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
#
#                   Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
# 0    Folktables_GA_2018_Income             200               0  OK
# 1    Folktables_GA_2018_Income             200               1  OK
# 2    Folktables_GA_2018_Income             200               2  OK
# 3    Folktables_GA_2018_Income             200               3  OK
# 4    Folktables_GA_2018_Income             200               0  OK
# 5    Folktables_GA_2018_Income             200               0  OK
# 6    Folktables_GA_2018_Income             200               1  OK
# 7    Folktables_GA_2018_Income             200               1  OK
# 8    Folktables_GA_2018_Income             200               2  OK
# 9    Folktables_GA_2018_Income             200               2  OK
# 10   Folktables_GA_2018_Income             200               3  OK
# 11   Folktables_GA_2018_Income             200               3  OK
# 288  Folktables_GA_2018_Income             200               0  OK
# 289  Folktables_GA_2018_Income             200               1  OK
# 290  Folktables_GA_2018_Income             200               2  OK
# 291  Folktables_GA_2018_Income             200               3  OK
# 292  Folktables_GA_2018_Income             200               0  OK
# 293  Folktables_GA_2018_Income             200               0  OK
# 294  Folktables_GA_2018_Income             200               1  OK
# 295  Folktables_GA_2018_Income             200               1  OK
#
#     Record_Create_Date_Time  ... SEX&RAC1P_priv SEX&RAC1P_priv_correct  \
# 0   2023-07-26 23:28:05.161  ...       0.768116               1.000000
# 1   2023-07-26 23:28:05.173  ...       0.803543               1.000000
# 288  0.601551          0.531585            0.818815  0.582829
# 289  0.602983          0.547651            0.841250  0.593799
# 290  0.615889          0.556621            0.798654  0.620183
# 291  0.601125          0.538683            0.795024  0.602629
# 292  0.608669          0.547554            0.827962  0.591665
# 293  0.616214          0.560164            0.828378  0.596283
# 294  0.603807          0.547427            0.842568  0.594144
# 295  0.592941          0.530610            0.838318  0.583793
#
# [20 rows x 35 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.0][3].head(20)
# Out:
#                      Metric  Bootstrap_Model_Seed              Model_Name  \
# 47                 Accuracy                   101  RandomForestClassifier
# 335   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 623                      F1                   101  RandomForestClassifier
# 911                     FNR                   101  RandomForestClassifier
# 1199                    FPR                   101  RandomForestClassifier
# 1487                    IQR                   101  RandomForestClassifier
# 1775                 Jitter                   101  RandomForestClassifier
# 2063        Label_Stability                   101  RandomForestClassifier
# 2351                   Mean                   101  RandomForestClassifier
# 2639    Overall_Uncertainty                   101  RandomForestClassifier
# 2927                    PPV                   101  RandomForestClassifier
# 3215    Per_Sample_Accuracy                   101  RandomForestClassifier
# 3503          Positive-Rate                   101  RandomForestClassifier
# 3791            Sample_Size                   101  RandomForestClassifier
# 4079         Selection-Rate                   101  RandomForestClassifier
# 4463                    Std                   101  RandomForestClassifier
# 4751                    TNR                   101  RandomForestClassifier
# 5039                    TPR                   101  RandomForestClassifier
#
#                                            Model_Params Run_Number  \
# 47    {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 335   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 623   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 911   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1199  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1487  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1775  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2063  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2351  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2639  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2927  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3215  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3503  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3791  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4079  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4463  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4751  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5039  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                    Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
# 47    Folktables_GA_2018_Income             200               3  OK
# 335   Folktables_GA_2018_Income             200               3  OK
# 623   Folktables_GA_2018_Income             200               3  OK
# 911   Folktables_GA_2018_Income             200               3  OK
# 1199  Folktables_GA_2018_Income             200               3  OK
# 1487  Folktables_GA_2018_Income             200               3  OK
# 1775  Folktables_GA_2018_Income             200               3  OK
# 2063  Folktables_GA_2018_Income             200               3  OK
# 2351  Folktables_GA_2018_Income             200               3  OK
# 2639  Folktables_GA_2018_Income             200               3  OK
# 2927  Folktables_GA_2018_Income             200               3  OK
# 3215  Folktables_GA_2018_Income             200               3  OK
# 3503  Folktables_GA_2018_Income             200               3  OK
# 3791  Folktables_GA_2018_Income             200               3  OK
# 4079  Folktables_GA_2018_Income             200               3  OK
# 4463  Folktables_GA_2018_Income             200               3  OK
# 4751  Folktables_GA_2018_Income             200               3  OK
# 5039  Folktables_GA_2018_Income             200               3  OK
#
#      Record_Create_Date_Time  ... SEX&RAC1P_priv SEX&RAC1P_priv_correct  \
# 47   2023-07-26 23:18:00.820  ...       0.767311               1.000000
# 335  2023-07-26 23:18:00.820  ...       0.686853               0.639397
# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.0][3].head(20)
# Out:
#                            Metric       SEX     RAC1P  SEX&RAC1P  \
# 0                 Accuracy_Parity  0.002564 -0.013615  -0.011497
# 1    Aleatoric_Uncertainty_Parity  0.012020  0.008957   0.015884
# 2     Aleatoric_Uncertainty_Ratio  1.017578  1.013045   1.023126
# 3              Equalized_Odds_FNR -0.017874 -0.006608  -0.018418
# 4              Equalized_Odds_FPR  0.006187  0.009010   0.024936
# 5                      IQR_Parity  0.001362  0.002765   0.002942
# 6                   Jitter_Parity -0.002957  0.020483   0.021028
# 7           Label_Stability_Ratio  1.003072  0.963489   0.959639
# 8      Label_Stability_Difference  0.002735 -0.032946  -0.036238
# 9      Overall_Uncertainty_Parity  0.012335  0.009559   0.016426
# 10      Overall_Uncertainty_Ratio  1.017735  1.013688   1.023512
# 11               Disparate_Impact  1.037949  0.999520   1.070751
# 12  Statistical_Parity_Difference  0.011432  0.022209   0.027113
# 13                     Std_Parity  0.001006  0.001744   0.001768
# 14                      Std_Ratio  1.020124  1.034927   1.035239
# 15             Equalized_Odds_TNR -0.006187 -0.009010  -0.024936
# 16             Equalized_Odds_TPR  0.017874  0.006608   0.018418
#
#                 Model_Name Experiment_Iteration  Intervention_Param  \
# 0   RandomForestClassifier           Exp_iter_1                 0.0
# 1   RandomForestClassifier           Exp_iter_1                 0.0
# 2   RandomForestClassifier           Exp_iter_1                 0.0
# 3   RandomForestClassifier           Exp_iter_1                 0.0
# 4   RandomForestClassifier           Exp_iter_1                 0.0
# 5   RandomForestClassifier           Exp_iter_1                 0.0
# 6   RandomForestClassifier           Exp_iter_1                 0.0
# 7   RandomForestClassifier           Exp_iter_1                 0.0
# 8   RandomForestClassifier           Exp_iter_1                 0.0
# 9   RandomForestClassifier           Exp_iter_1                 0.0
# 10  RandomForestClassifier           Exp_iter_1                 0.0
# 11  RandomForestClassifier           Exp_iter_1                 0.0
# 12  RandomForestClassifier           Exp_iter_1                 0.0
# 13  RandomForestClassifier           Exp_iter_1                 0.0
# 14  RandomForestClassifier           Exp_iter_1                 0.0
# 15  RandomForestClassifier           Exp_iter_1                 0.0
# 16  RandomForestClassifier           Exp_iter_1                 0.0
#
#     Test_Set_Index
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# 5                3
# 6                3
# 7                3
# 8                3
# 9                3
# 10               3
# 11               3
# 12               3
# 13               3
# 14               3
# 15               3
# 16               3

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.7][0].head()
# Out:
#                          Metric       SEX     RAC1P  SEX&RAC1P  \
# 0               Accuracy_Parity  0.040491  0.063776   0.047860
# 1  Aleatoric_Uncertainty_Parity -0.024795 -0.051399  -0.042469
# 2   Aleatoric_Uncertainty_Ratio  0.960486  0.918714   0.931821
# 3            Equalized_Odds_FNR  0.013262 -0.090499  -0.027590
# 4            Equalized_Odds_FPR -0.004707  0.005181   0.004611
#
#                Model_Name Experiment_Iteration  Intervention_Param  \
# 0  RandomForestClassifier           Exp_iter_1                 0.7
# 1  RandomForestClassifier           Exp_iter_1                 0.7
# 2  RandomForestClassifier           Exp_iter_1                 0.7
# 3  RandomForestClassifier           Exp_iter_1                 0.7
# 4  RandomForestClassifier           Exp_iter_1                 0.7
#
#    Test_Set_Index
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           # ylim=(0.6, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Ratio', 'Aleatoric_Uncertainty_Ratio',
                                                         'Overall_Uncertainty_Ratio'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Difference', 'Aleatoric_Uncertainty_Parity',
                                                         'Overall_Uncertainty_Parity'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 5. Out-of-domain boxplots.

# %%
new_vals_to_replace = vals_to_replace
new_vals_to_replace['Test_Set_Index'] = {
    0: 'GA 2018',
    1: 'GA 2017',
    2: 'NY 2018',
    3: 'NY 2017',
}

# %%
create_group_models_box_plot_per_test_set(melted_all_subgroup_metrics_per_model_dct, metric_name='Accuracy',
                                          vals_to_replace=new_vals_to_replace)

# %%
create_group_models_box_plot_per_test_set(melted_all_subgroup_metrics_per_model_dct, metric_name='Aleatoric_Uncertainty',
                                          vals_to_replace=new_vals_to_replace)

# %%
create_group_models_box_plot_per_test_set(melted_all_group_metrics_per_model_dct, metric_name='Equalized_Odds_FNR', group='SEX',
                                          vals_to_replace=new_vals_to_replace)

# %% [markdown]
# ## Figure 3. Scatter plots.

# %%
create_scatter_plot(melted_all_group_metrics_per_model_dct,
                    group='SEX',
                    fairness_metric_name='Equalized_Odds_FPR',
                    stability_metric_name='Label_Stability_Ratio')
# Out:
# alt.Chart(...)

# %%
create_scatter_plot(melted_all_group_metrics_per_model_dct,
                    group='SEX&RAC1P',
                    fairness_metric_name='Equalized_Odds_FPR',
                    stability_metric_name='Label_Stability_Ratio')
# Out:
# alt.Chart(...)

# %%
create_scatter_plot(melted_all_group_metrics_per_model_dct,
                    group='RAC1P',
                    fairness_metric_name='Equalized_Odds_FNR',
                    stability_metric_name='Label_Stability_Ratio')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Figure 6. Responsible model selection

# %%
metrics_value_range_dct = {
    'Accuracy': [0.815, 0.85], # C1
    'Equalized_Odds_FPR': [-0.03, 0.03], # C2
    'Label_Stability': [0.9, 0.94], # C3
    'Label_Stability_Ratio': [1.0, 1.03], # C4
    'Accuracy&Equalized_Odds_FPR': None, # C1 + C2
    'Accuracy&Label_Stability': None, # C1 + C3
    'Accuracy&Label_Stability_Ratio': None, # C1 + C4
    'Accuracy&Equalized_Odds_FPR&Label_Stability&Label_Stability_Ratio': None, # C1 + C2 + C3 + C4
}
create_bar_plot_for_model_selection(melted_all_subgroup_metrics_per_model_dct,
                                    melted_all_group_metrics_per_model_dct,
                                    metrics_value_range_dct,
                                    group='SEX&RAC1P')
# Out:
# alt.Chart(...)
