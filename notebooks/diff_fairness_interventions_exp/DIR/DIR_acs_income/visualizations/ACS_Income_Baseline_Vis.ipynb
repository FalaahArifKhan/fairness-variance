# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
EXPERIMENT_SESSION_UUID = 'ac796b56-9c83-474a-8e7a-2d95ee5efa7e'
SENSITIVE_ATTR_FOR_INTERVENTION = 'SEX&RAC1P'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
# MODEL_NAMES = ['LogisticRegression']
MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
# Append Test_Set_Index to each result set for models
for model_name in models_metrics_dct.keys():
    models_metrics_dct[model_name]['Test_Set_Index'] = 0

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (114, 33)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#                     Metric      Model_Name  \
# 0                 Accuracy  LGBMClassifier
# 24   Aleatoric_Uncertainty  LGBMClassifier
# 48   Epistemic_Uncertainty  LGBMClassifier
# 72                      F1  LGBMClassifier
# 96                     FNR  LGBMClassifier
# 120                    FPR  LGBMClassifier
# 144                    IQR  LGBMClassifier
# 168                 Jitter  LGBMClassifier
# 192        Label_Stability  LGBMClassifier
# 216        Mean_Prediction  LGBMClassifier
# 240    Overall_Uncertainty  LGBMClassifier
# 264                    PPV  LGBMClassifier
# 288          Positive-Rate  LGBMClassifier
# 312            Sample_Size  LGBMClassifier
# 336         Selection-Rate  LGBMClassifier
# 360       Statistical_Bias  LGBMClassifier
# 384                    Std  LGBMClassifier
# 408                    TNR  LGBMClassifier
# 432                    TPR  LGBMClassifier
#
#                                           Model_Params  \
# 0    {'boosting_type': 'gbdt', 'class_weight': None...
# 24   {'boosting_type': 'gbdt', 'class_weight': None...
# 48   {'boosting_type': 'gbdt', 'class_weight': None...
# 72   {'boosting_type': 'gbdt', 'class_weight': None...
# 96   {'boosting_type': 'gbdt', 'class_weight': None...
# 120  {'boosting_type': 'gbdt', 'class_weight': None...
# 144  {'boosting_type': 'gbdt', 'class_weight': None...
# 168  {'boosting_type': 'gbdt', 'class_weight': None...
# 192  {'boosting_type': 'gbdt', 'class_weight': None...
# 216  {'boosting_type': 'gbdt', 'class_weight': None...
# 240  {'boosting_type': 'gbdt', 'class_weight': None...
# 264  {'boosting_type': 'gbdt', 'class_weight': None...
# 288  {'boosting_type': 'gbdt', 'class_weight': None...
# 312  {'boosting_type': 'gbdt', 'class_weight': None...
# 336  {'boosting_type': 'gbdt', 'class_weight': None...
# 360  {'boosting_type': 'gbdt', 'class_weight': None...
# 384  {'boosting_type': 'gbdt', 'class_weight': None...
# 408  {'boosting_type': 'gbdt', 'class_weight': None...
# 432  {'boosting_type': 'gbdt', 'class_weight': None...
#
#                   Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0    Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 24   Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 48   Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 72   Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 96   Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 120  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 144  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 168  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 192  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 216  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 240  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 264  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 288  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 312  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 336  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 360  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 384  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 408  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
# 432  Folktables_GA_2018_Income             200  OK 2024-01-06 18:59:47.583
#
#                              Session_Uuid Experiment_Iteration  \
# 0    ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 24   ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 48   ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 72   ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 96   ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 120  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 144  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 168  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 192  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 216  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 240  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 264  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 288  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 312  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 336  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 360  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 384  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 408  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
# 432  ac796b56-9c83-474a-8e7a-2d95ee5efa7e           Exp_iter_1
#
#      Dataset_Split_Seed  ...  SEX&RAC1P_priv_correct SEX&RAC1P_priv_incorrect  \
# 0                   100  ...                1.000000                 0.000000
# 24                  100  ...                0.566542                 0.837331
# 48                  100  ...                0.011439                 0.017813
# 72                  100  ...                1.000000                 0.000000
# 96                  100  ...                0.000000                 1.000000
# 120                 100  ...                0.000000                 1.000000
# 144                 100  ...                0.058280                 0.092569
# 168                 100  ...                0.042738                 0.142651
# 192                 100  ...                0.939656                 0.795566
# 216                 100  ...                0.662274                 0.551802
# 240                 100  ...                0.577981                 0.855144
# 264                 100  ...                1.000000                 0.000000
# 288                 100  ...                1.000000                 0.618812
# 312                 100  ...             2441.000000               654.000000
# 336                 100  ...                0.303974                 0.382263
# 360                 100  ...                0.180192                 0.678641
# 384                 100  ...                0.043965                 0.068539
# 408                 100  ...                1.000000                 0.000000
# 432                 100  ...                1.000000                 0.000000
#
#          SEX_dis  SEX_dis_correct  SEX_dis_incorrect     SEX_priv  \
# 0       0.818942         1.000000           0.000000     0.772890
# 24      0.595062         0.542451           0.833026     0.634515
# 48      0.012704         0.011250           0.019283     0.012508
# 72      0.657534         1.000000           0.000000     0.703605
# 96      0.373494         0.000000           1.000000     0.343711
# 120     0.107170         0.000000           1.000000     0.145833
# 144     0.063619         0.056295           0.096745     0.065426
# 168     0.059137         0.039250           0.149085     0.064624
# 192     0.914925         0.944306           0.782031     0.909105
# 216     0.689252         0.723640           0.533712     0.616530
# 240     0.607766         0.553700           0.852309     0.647023
# 264     0.691796         1.000000           0.000000     0.758273
# 288     0.905622         1.000000           0.747312     0.865504
# 312  1795.000000      1470.000000         325.000000  1955.000000
# 336     0.251253         0.212245           0.427692     0.355499
# 360     0.262893         0.170753           0.679647     0.297552
# 384     0.047749         0.042528           0.071365     0.049091
# 408     0.892830         1.000000           0.000000     0.854167
# 432     0.626506         1.000000           0.000000     0.656289
#
#      SEX_priv_correct  SEX_priv_incorrect      overall  Test_Set_Index
# 0            1.000000            0.000000     0.794933               0
# 24           0.575794            0.834352     0.615630               0
# 48           0.011259            0.016758     0.012602               0
# 72           1.000000            0.000000     0.685738               0
# 96           0.000000            1.000000     0.355111               0
# 120          0.000000            1.000000     0.125357               0
# 144          0.058417            0.089277     0.064561               0
# 168          0.045284            0.130444     0.061998               0
# 192          0.936248            0.816734     0.911891               0
# 216          0.634641            0.554897     0.651340               0
# 240          0.587053            0.851111     0.628232               0
# 264          1.000000            0.000000     0.732112               0
# 288          1.000000            0.608696     0.880861               0
# 312       1511.000000          444.000000  3750.000000               0
# 336          0.348776            0.378378     0.305600               0
# 360          0.184170            0.683406     0.280962               0
# 384          0.044042            0.066275     0.048449               0
# 408          1.000000            0.000000     0.874643               0
# 432          1.000000            0.000000     0.644889               0
#
# [19 rows x 33 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           # ylim=(0.75, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           metric_names=['Std', 'Aleatoric_Uncertainty', 'Epistemic_Uncertainty'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Difference'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Aleatoric_Uncertainty_Parity',
                                                         'Overall_Uncertainty_Parity'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Statistical_Parity_Difference'],
                                           vals_to_replace=vals_to_replace)
