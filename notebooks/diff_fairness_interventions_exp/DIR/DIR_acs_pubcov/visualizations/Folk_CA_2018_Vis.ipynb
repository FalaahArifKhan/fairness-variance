# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance/notebooks/diff_fairness_interventions_exp

# %% [markdown]
# # Visualizations

# %%
from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.visualizations import preprocess_metrics, create_group_base_and_fair_models_box_plot, \
    create_scatter_plot, create_group_models_box_plot_per_test_set, create_bar_plot_for_model_selection
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'one_repair_lvl_many_models_pubcov_CA'
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
SENSITIVE_ATTR_FOR_INTERVENTION = 'SEX&RAC1P'
EXPERIMENT_SESSION_UUID = 'c42fae24-694f-408e-98df-ce099940a961'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['LGBMClassifier', 'LogisticRegression', 'RandomForestClassifier', 'MLPClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (912, 35)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]][
    models_metrics_dct[list(models_metrics_dct.keys())[0]]['Experiment_Iteration'] == 'Exp_iter_1'
].head(20)
# Out:
#                     Metric  Bootstrap_Model_Seed      Model_Name  \
# 0                 Accuracy                   101  LGBMClassifier
# 1                 Accuracy                   101  LGBMClassifier
# 2                 Accuracy                   101  LGBMClassifier
# 3                 Accuracy                   101  LGBMClassifier
# 4                 Accuracy                   101  LGBMClassifier
# 5                 Accuracy                   101  LGBMClassifier
# 6                 Accuracy                   101  LGBMClassifier
# 7                 Accuracy                   101  LGBMClassifier
# 192  Aleatoric_Uncertainty                   101  LGBMClassifier
# 193  Aleatoric_Uncertainty                   101  LGBMClassifier
# 194  Aleatoric_Uncertainty                   101  LGBMClassifier
# 195  Aleatoric_Uncertainty                   101  LGBMClassifier
# 196  Aleatoric_Uncertainty                   101  LGBMClassifier
# 197  Aleatoric_Uncertainty                   101  LGBMClassifier
# 198  Aleatoric_Uncertainty                   101  LGBMClassifier
# 199  Aleatoric_Uncertainty                   101  LGBMClassifier
# 384                     F1                   101  LGBMClassifier
# 385                     F1                   101  LGBMClassifier
# 386                     F1                   101  LGBMClassifier
# 387                     F1                   101  LGBMClassifier
#
#                                           Model_Params Run_Number  \
# 0    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 1    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 2    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 3    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 4    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 5    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 6    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 7    {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 192  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 193  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 194  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 195  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 196  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 197  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 198  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 199  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 384  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 385  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 386  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
# 387  {'boosting_type': 'gbdt', 'class_weight': None...      Run_1
#
#                            Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
# 0    Folktables_CA_2018_Public_Coverage             200               0  OK
# 1    Folktables_CA_2018_Public_Coverage             200               1  OK
# 2    Folktables_CA_2018_Public_Coverage             200               2  OK
# 3    Folktables_CA_2018_Public_Coverage             200               3  OK
# 4    Folktables_CA_2018_Public_Coverage             200               0  OK
# 5    Folktables_CA_2018_Public_Coverage             200               1  OK
# 6    Folktables_CA_2018_Public_Coverage             200               2  OK
# 7    Folktables_CA_2018_Public_Coverage             200               3  OK
# 192  Folktables_CA_2018_Public_Coverage             200               0  OK
# 193  Folktables_CA_2018_Public_Coverage             200               1  OK
# 194  Folktables_CA_2018_Public_Coverage             200               2  OK
# 195  Folktables_CA_2018_Public_Coverage             200               3  OK
# 196  Folktables_CA_2018_Public_Coverage             200               0  OK
# 197  Folktables_CA_2018_Public_Coverage             200               1  OK
# 198  Folktables_CA_2018_Public_Coverage             200               2  OK
# 199  Folktables_CA_2018_Public_Coverage             200               3  OK
# 384  Folktables_CA_2018_Public_Coverage             200               0  OK
# 385  Folktables_CA_2018_Public_Coverage             200               1  OK
# 386  Folktables_CA_2018_Public_Coverage             200               2  OK
# 387  Folktables_CA_2018_Public_Coverage             200               3  OK
#
#     Record_Create_Date_Time  ... SEX&RAC1P_priv SEX&RAC1P_priv_correct  \
# 0   2023-08-01 23:13:20.469  ...       0.690741               1.000000
# 1   2023-08-01 23:13:20.481  ...       0.710185               1.000000
# 2   2023-08-01 23:13:20.493  ...       0.761111               1.000000
# 3   2023-08-01 23:13:20.505  ...       0.762963               1.000000
# 4   2023-08-01 23:06:10.855  ...       0.700000               1.000000
# 5   2023-08-01 23:06:10.870  ...       0.715741               1.000000
# 6   2023-08-01 23:06:10.882  ...       0.760185               1.000000
# 7   2023-08-01 23:06:10.895  ...       0.778704               1.000000
# 192 2023-08-01 23:13:20.469  ...       0.797102               0.768632
# 193 2023-08-01 23:13:20.481  ...       0.788736               0.755179
# 194 2023-08-01 23:13:20.493  ...       0.793868               0.768551
# 195 2023-08-01 23:13:20.505  ...       0.788429               0.759209
# 196 2023-08-01 23:06:10.855  ...       0.800347               0.774437
# 197 2023-08-01 23:06:10.870  ...       0.792020               0.761005
# 198 2023-08-01 23:06:10.882  ...       0.797869               0.772987
# 199 2023-08-01 23:06:10.895  ...       0.786636               0.759258
# 384 2023-08-01 23:13:20.469  ...       0.524217               1.000000
# 385 2023-08-01 23:13:20.481  ...       0.522137               1.000000
# 386 2023-08-01 23:13:20.493  ...       0.501931               1.000000
# 387 2023-08-01 23:13:20.505  ...       0.507692               1.000000
#
#      SEX&RAC1P_priv_incorrect   SEX_dis SEX_dis_correct  SEX_dis_incorrect  \
# 0                    0.000000  0.713777        1.000000           0.000000
# 1                    0.000000  0.695962        1.000000           0.000000
# 2                    0.000000  0.769596        1.000000           0.000000
# 3                    0.000000  0.749406        1.000000           0.000000
# 4                    0.000000  0.717340        1.000000           0.000000
# 5                    0.000000  0.703088        1.000000           0.000000
# 6                    0.000000  0.762470        1.000000           0.000000
# 7                    0.000000  0.770784        1.000000           0.000000
# 192                  0.860692  0.793320        0.762531           0.870101
# 193                  0.870968  0.797543        0.768255           0.864585
# 194                  0.874530  0.795078        0.769714           0.879802
# 195                  0.882480  0.786670        0.755992           0.878412
# 196                  0.860806  0.795699        0.765774           0.871643
# 197                  0.870111  0.800278        0.773125           0.864576
# 198                  0.876743  0.799625        0.772318           0.887279
# 199                  0.882974  0.783749        0.757291           0.872717
# 384                  0.000000  0.524655        1.000000           0.000000
# 385                  0.000000  0.498039        1.000000           0.000000
# 386                  0.000000  0.500000        1.000000           0.000000
# 387                  0.000000  0.463104        1.000000           0.000000
#
#      SEX_priv  SEX_priv_correct  SEX_priv_incorrect   overall
# 0    0.686930          1.000000            0.000000  0.702000
# 1    0.694529          1.000000            0.000000  0.695333
# 2    0.768997          1.000000            0.000000  0.769333
# 3    0.764438          1.000000            0.000000  0.756000
# 4    0.694529          1.000000            0.000000  0.707333
# 5    0.699088          1.000000            0.000000  0.701333
# 6    0.767477          1.000000            0.000000  0.764667
# 7    0.775076          1.000000            0.000000  0.772667
# 192  0.806560          0.781968            0.860520  0.799128
# 193  0.791810          0.754602            0.876410  0.795028
# 194  0.795926          0.771543            0.877096  0.795450
# 195  0.799942          0.773810            0.884744  0.792492
# 196  0.809462          0.787396            0.859632  0.801736
# 197  0.794840          0.760393            0.874866  0.797892
# 198  0.800243          0.776305            0.879256  0.799896
# 199  0.797622          0.771435            0.887863  0.789835
# 384  0.536036          1.000000            0.000000  0.529968
# 385  0.501241          1.000000            0.000000  0.499452
# 386  0.500000          1.000000            0.000000  0.500000
# 387  0.504792          1.000000            0.000000  0.481586
#
# [20 rows x 35 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct_for_mult_test_sets()

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.0][3].head(20)
# Out:
#                      Metric  Bootstrap_Model_Seed              Model_Name  \
# 27                 Accuracy                   101  RandomForestClassifier
# 219   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 411                      F1                   101  RandomForestClassifier
# 603                     FNR                   101  RandomForestClassifier
# 795                     FPR                   101  RandomForestClassifier
# 987                     IQR                   101  RandomForestClassifier
# 1179                 Jitter                   101  RandomForestClassifier
# 1371        Label_Stability                   101  RandomForestClassifier
# 1563                   Mean                   101  RandomForestClassifier
# 1755    Overall_Uncertainty                   101  RandomForestClassifier
# 1947                    PPV                   101  RandomForestClassifier
# 2139    Per_Sample_Accuracy                   101  RandomForestClassifier
# 2331          Positive-Rate                   101  RandomForestClassifier
# 2523            Sample_Size                   101  RandomForestClassifier
# 2715         Selection-Rate                   101  RandomForestClassifier
# 2907       Statistical_Bias                   101  RandomForestClassifier
# 3099                    Std                   101  RandomForestClassifier
# 3291                    TNR                   101  RandomForestClassifier
# 3483                    TPR                   101  RandomForestClassifier
#
#                                            Model_Params Run_Number  \
# 27    {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 219   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 411   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 603   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 795   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 987   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1179  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1371  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1563  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1755  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1947  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2139  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2331  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2523  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2715  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2907  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3099  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3291  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3483  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                             Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
# 27    Folktables_CA_2018_Public_Coverage             200               3  OK
# 219   Folktables_CA_2018_Public_Coverage             200               3  OK
# 411   Folktables_CA_2018_Public_Coverage             200               3  OK
# 603   Folktables_CA_2018_Public_Coverage             200               3  OK
# 795   Folktables_CA_2018_Public_Coverage             200               3  OK
# 987   Folktables_CA_2018_Public_Coverage             200               3  OK
# 1179  Folktables_CA_2018_Public_Coverage             200               3  OK
# 1371  Folktables_CA_2018_Public_Coverage             200               3  OK
# 1563  Folktables_CA_2018_Public_Coverage             200               3  OK
# 1755  Folktables_CA_2018_Public_Coverage             200               3  OK
# 1947  Folktables_CA_2018_Public_Coverage             200               3  OK
# 2139  Folktables_CA_2018_Public_Coverage             200               3  OK
# 2331  Folktables_CA_2018_Public_Coverage             200               3  OK
# 2523  Folktables_CA_2018_Public_Coverage             200               3  OK
# 2715  Folktables_CA_2018_Public_Coverage             200               3  OK
# 2907  Folktables_CA_2018_Public_Coverage             200               3  OK
# 3099  Folktables_CA_2018_Public_Coverage             200               3  OK
# 3291  Folktables_CA_2018_Public_Coverage             200               3  OK
# 3483  Folktables_CA_2018_Public_Coverage             200               3  OK
#
#      Record_Create_Date_Time  ... SEX&RAC1P_priv SEX&RAC1P_priv_correct  \
# 27   2023-08-01 23:06:10.999  ...       0.792593               1.000000
# 219  2023-08-01 23:06:10.999  ...       0.806481               0.783489
# 411  2023-08-01 23:06:10.999  ...       0.527426               1.000000
# 603  2023-08-01 23:06:10.999  ...       0.404762               0.000000
# 795  2023-08-01 23:06:10.999  ...       0.159770               0.000000
# 987  2023-08-01 23:06:10.999  ...       0.092896               0.089836
# 1179 2023-08-01 23:06:10.999  ...       0.118618               0.091575
# 1371 2023-08-01 23:06:10.999  ...       0.832370               0.873727
# 1563 2023-08-01 23:06:10.999  ...       0.620273               0.655028
# 1755 2023-08-01 23:06:10.999  ...       0.824248               0.800794
# 1947 2023-08-01 23:06:10.999  ...       0.473485               1.000000
# 2139 2023-08-01 23:06:10.999  ...       0.776380               0.936770
# 2331 2023-08-01 23:06:10.999  ...       1.257143               1.000000
# 2523 2023-08-01 23:06:10.999  ...    1080.000000             856.000000
# 2715 2023-08-01 23:06:10.999  ...       0.244444               0.146028
# 2907 2023-08-01 23:06:10.999  ...       0.351786               0.278952
# 3099 2023-08-01 23:06:10.999  ...       0.067979               0.065897
# 3291 2023-08-01 23:06:10.999  ...       0.840230               1.000000
# 3483 2023-08-01 23:06:10.999  ...       0.595238               1.000000
#
#       SEX&RAC1P_priv_incorrect     SEX_dis SEX_dis_correct  SEX_dis_incorrect  \
# 27                    0.000000    0.769596        1.000000           0.000000
# 219                   0.894345    0.802919        0.778123           0.885743
# 411                   0.000000    0.469945        1.000000           0.000000
# 603                   1.000000    0.441558        0.000000           1.000000
# 795                   1.000000    0.183140        0.000000           1.000000
# 987                   0.104587    0.092736        0.089339           0.104081
# 1179                  0.221960    0.121268        0.094682           0.210070
# 1371                  0.674330    0.826936        0.868981           0.686495
# 1563                  0.487457    0.626737        0.663070           0.505376
# 1755                  0.913876    0.820707        0.795373           0.905329
# 1947                  0.000000    0.405660        1.000000           0.000000
# 2139                  0.163460    0.755344        0.934367           0.157371
# 2331                  1.635294    1.376623        1.000000           1.852941
# 2523                224.000000  842.000000      648.000000         194.000000
# 2715                  0.620536    0.251781        0.132716           0.649485
# 2907                  0.630115    0.359638        0.276758           0.636476
# 3099                  0.075933    0.067733        0.065398           0.075534
# 3291                  0.000000    0.816860        1.000000           0.000000
# 3483                  0.000000    0.558442        1.000000           0.000000
#
#         SEX_priv  SEX_priv_correct  SEX_priv_incorrect      overall
# 27      0.802432          1.000000            0.000000     0.784000
# 219     0.814297          0.794008            0.896705     0.807911
# 411     0.535714          1.000000            0.000000     0.498452
# 603     0.427481          0.000000            1.000000     0.435088
# 795     0.140417          0.000000            1.000000     0.164609
# 987     0.094011          0.091600            0.103805     0.093295
# 1179    0.117543          0.092705            0.218425     0.119634
# 1371    0.835729          0.871932            0.688692     0.830793
# 1563    0.620743          0.653165            0.489062     0.624108
# 1755    0.832220          0.811653            0.915755     0.825757
# 1947    0.503356          1.000000            0.000000     0.445983
# 2139    0.781831          0.935966            0.155808     0.766963
# 2331    1.137405          1.000000            1.321429     1.266667
# 2523  658.000000        528.000000          130.000000  1500.000000
# 2715    0.226444          0.142045            0.569231     0.240667
# 2907    0.352888          0.284816            0.629364     0.356677
# 3099    0.068767          0.067161            0.075289     0.068187
# 3291    0.859583          1.000000            0.000000     0.835391
# 3483    0.572519          1.000000            0.000000     0.564912
#
# [19 rows x 35 columns]

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics_for_mult_test_sets(exp_subgroup_metrics_dct)

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.0][3].head(20)
# Out:
#                            Metric       SEX     RAC1P  SEX&RAC1P  \
# 0                 Accuracy_Parity -0.032835 -0.015308  -0.030688
# 1    Aleatoric_Uncertainty_Parity -0.011378  0.022509   0.005105
# 2     Aleatoric_Uncertainty_Ratio  0.986027  1.028230   1.006330
# 3              Equalized_Odds_FNR  0.014078  0.105211   0.115238
# 4              Equalized_Odds_FPR  0.042722 -0.002147   0.017041
# 5                      IQR_Parity -0.001275  0.002659   0.001428
# 6                   Jitter_Parity  0.003725  0.010885   0.003627
# 7           Label_Stability_Ratio  0.989478  0.983414   0.993233
# 8      Label_Stability_Difference -0.008794 -0.013888  -0.005632
# 9      Overall_Uncertainty_Parity -0.011513  0.022905   0.005390
# 10      Overall_Uncertainty_Ratio  0.986166  1.028105   1.006539
# 11               Disparate_Impact  1.210320  0.949101   1.028788
# 12  Statistical_Parity_Difference  0.025338 -0.025880  -0.013492
# 13                     Std_Parity -0.001034  0.001960   0.000743
# 14                      Std_Ratio  0.984968  1.029145   1.010931
# 15             Equalized_Odds_TNR -0.042722  0.002147  -0.017041
# 16             Equalized_Odds_TPR -0.014078 -0.105211  -0.115238
#
#                 Model_Name Experiment_Iteration  Intervention_Param  \
# 0   RandomForestClassifier           Exp_iter_1                 0.0
# 1   RandomForestClassifier           Exp_iter_1                 0.0
# 2   RandomForestClassifier           Exp_iter_1                 0.0
# 3   RandomForestClassifier           Exp_iter_1                 0.0
# 4   RandomForestClassifier           Exp_iter_1                 0.0
# 5   RandomForestClassifier           Exp_iter_1                 0.0
# 6   RandomForestClassifier           Exp_iter_1                 0.0
# 7   RandomForestClassifier           Exp_iter_1                 0.0
# 8   RandomForestClassifier           Exp_iter_1                 0.0
# 9   RandomForestClassifier           Exp_iter_1                 0.0
# 10  RandomForestClassifier           Exp_iter_1                 0.0
# 11  RandomForestClassifier           Exp_iter_1                 0.0
# 12  RandomForestClassifier           Exp_iter_1                 0.0
# 13  RandomForestClassifier           Exp_iter_1                 0.0
# 14  RandomForestClassifier           Exp_iter_1                 0.0
# 15  RandomForestClassifier           Exp_iter_1                 0.0
# 16  RandomForestClassifier           Exp_iter_1                 0.0
#
#     Test_Set_Index
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# 5                3
# 6                3
# 7                3
# 8                3
# 9                3
# 10               3
# 11               3
# 12               3
# 13               3
# 14               3
# 15               3
# 16               3

# %% [markdown]
# ## Figure 1. Subgroup boxplots.

# %%
melted_all_subgroup_metrics_per_model_dct, melted_all_group_metrics_per_model_dct = \
    preprocess_metrics(exp_subgroup_metrics_dct, exp_group_metrics_dct)

# %%
vals_to_replace = {
    'Model_Name': {
        'LGBMClassifier': 'LGBM',
        'LogisticRegression': 'LR',
        'RandomForestClassifier': 'RF',
        'MLPClassifier': 'MLP'
    }
}

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           ylim=(0.45, 1.0),
                                           metric_names=['F1', 'Accuracy', 'Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_subgroup_metrics_per_model_dct,
                                           ylim=(0.7, 0.95),
                                           metric_names=['Label_Stability'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 2. Create group boxplots.

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Label_Stability_Ratio'],
                                           vals_to_replace=vals_to_replace)

# %%
create_group_base_and_fair_models_box_plot(melted_all_group_metrics_per_model_dct,
                                           group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                           metric_names=['Equalized_Odds_FPR', 'Equalized_Odds_FNR'],
                                           vals_to_replace=vals_to_replace)

# %% [markdown]
# ## Figure 5. Out-of-domain boxplots.

# %%
new_vals_to_replace = vals_to_replace
new_vals_to_replace['Test_Set_Index'] = {
    0: 'CA 2018',
    1: 'CA 2017',
    2: 'TX 2018',
    3: 'TX 2017',
}

# %%
create_group_models_box_plot_per_test_set(melted_all_subgroup_metrics_per_model_dct, metric_name='F1',
                                          vals_to_replace=new_vals_to_replace)

# %%
create_group_models_box_plot_per_test_set(melted_all_subgroup_metrics_per_model_dct, metric_name='Aleatoric_Uncertainty',
                                          vals_to_replace=new_vals_to_replace)

# %%
create_group_models_box_plot_per_test_set(melted_all_group_metrics_per_model_dct, metric_name='Equalized_Odds_FNR', group='SEX',
                                          vals_to_replace=new_vals_to_replace)

# %% [markdown]
# ## Figure 3. Scatter plots.

# %%
create_scatter_plot(melted_all_group_metrics_per_model_dct,
                    group='SEX',
                    fairness_metric_name='Equalized_Odds_FPR',
                    stability_metric_name='Label_Stability_Ratio')
# Out:
# alt.Chart(...)

# %%
create_scatter_plot(melted_all_group_metrics_per_model_dct,
                    group='SEX&RAC1P',
                    fairness_metric_name='Equalized_Odds_FPR',
                    stability_metric_name='Label_Stability_Ratio')
# Out:
# alt.Chart(...)

# %%
create_scatter_plot(melted_all_group_metrics_per_model_dct,
                    group='RAC1P',
                    fairness_metric_name='Equalized_Odds_FNR',
                    stability_metric_name='Label_Stability_Ratio')
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Figure 6. Responsible model selection

# %%
metrics_value_range_dct = {
    'Accuracy': [0.705, 0.73], # C1
    'Equalized_Odds_FPR': [-0.01, 0.01], # C2
    'Label_Stability': [0.85, 1.0], # C3
    'Label_Stability_Ratio': [0.97, 1.2], # C4
    'Accuracy&Equalized_Odds_FPR': None, # C1 + C2
    'Accuracy&Label_Stability': None, # C1 + C3
    'Accuracy&Label_Stability_Ratio': None, # C1 + C4
    'Accuracy&Equalized_Odds_FPR&Label_Stability&Label_Stability_Ratio': None, # C1 + C2 + C3 + C4
}
create_bar_plot_for_model_selection(melted_all_subgroup_metrics_per_model_dct,
                                    melted_all_group_metrics_per_model_dct,
                                    metrics_value_range_dct,
                                    group='SEX&RAC1P')
# Out:
# alt.Chart(...)
