# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
EXPERIMENT_NAME = 'stress_testing_nulls'
DB_COLLECTION_NAME = f'{EXPERIMENT_NAME}_results'
DATASET_NAME = 'Folktables_GA_2018'
EXPERIMENT_SESSION_UUID = '2f6541f0-2a77-446a-a5be-92d7b4187052'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'AGEP', 'SEX&RAC1P&AGEP']
PREPROCESSING_TECHNIQUES = ['cat: mode, num: median', 'cat: mode_trimmed_0.3, num: median']

# %%
# MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression', 'RandomForestClassifier',
#                'XGBClassifier', 'KNeighborsClassifier', 'MLPClassifier']
MODEL_NAMES = ['DecisionTreeClassifier', 'LogisticRegression']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (448, 27)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#       Metric  Bootstrap_Model_Seed              Model_Name  \
# 0   Accuracy                   101  DecisionTreeClassifier
# 1   Accuracy                   101  DecisionTreeClassifier
# 2   Accuracy                   101  DecisionTreeClassifier
# 3   Accuracy                   101  DecisionTreeClassifier
# 4   Accuracy                   101  DecisionTreeClassifier
# 5   Accuracy                   101  DecisionTreeClassifier
# 6   Accuracy                   101  DecisionTreeClassifier
# 7   Accuracy                   101  DecisionTreeClassifier
# 8   Accuracy                   101  DecisionTreeClassifier
# 9   Accuracy                   101  DecisionTreeClassifier
# 10  Accuracy                   101  DecisionTreeClassifier
# 11  Accuracy                   101  DecisionTreeClassifier
# 12  Accuracy                   101  DecisionTreeClassifier
# 13  Accuracy                   101  DecisionTreeClassifier
# 28  Accuracy                   102  DecisionTreeClassifier
# 29  Accuracy                   102  DecisionTreeClassifier
# 30  Accuracy                   102  DecisionTreeClassifier
# 31  Accuracy                   102  DecisionTreeClassifier
# 32  Accuracy                   102  DecisionTreeClassifier
# 33  Accuracy                   102  DecisionTreeClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 1   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 2   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 3   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 4   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 5   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 6   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 7   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 8   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 9   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 10  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 11  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 12  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 13  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 28  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 29  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 30  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 31  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 32  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 33  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
#
#           Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
#
# 2   0.722462  0.799510   0.7602
# 3   0.722462  0.799510   0.7602
# 4   0.721286  0.798285   0.7590
# 5   0.721678  0.798285   0.7592
# 6   0.720502  0.797060   0.7580
# 7   0.721286  0.797060   0.7584
# 8   0.720502  0.795018   0.7570
# 9   0.720894  0.794610   0.7570
# 10  0.718542  0.788893   0.7530
# 11  0.719718  0.788485   0.7534
# 12  0.717366  0.791343   0.7536
# 13  0.718150  0.790935   0.7538
# 28  0.751862  0.772152   0.7618
# 29  0.751862  0.772152   0.7618
# 30  0.751470  0.772969   0.7620
# 31  0.751470  0.772969   0.7620
# 32  0.751862  0.771335   0.7614
# 33  0.751862  0.771335   0.7614
#
# [20 rows x 27 columns]

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_subgroup_metrics_dct['DecisionTreeClassifier']['cat: mode_trimmed_0.3, num: median']['Exp_iter_1'][0.0].head(100)
# Out:
#                   Metric  Bootstrap_Model_Seed              Model_Name  \
# 1               Accuracy                   101  DecisionTreeClassifier
# 29              Accuracy                   102  DecisionTreeClassifier
# 57               Entropy                   101  DecisionTreeClassifier
# 85               Entropy                   102  DecisionTreeClassifier
# 113                   F1                   101  DecisionTreeClassifier
# 141                   F1                   102  DecisionTreeClassifier
# 169                  FNR                   101  DecisionTreeClassifier
# 197                  FNR                   102  DecisionTreeClassifier
# 225                  FPR                   101  DecisionTreeClassifier
# 253                  FPR                   102  DecisionTreeClassifier
# 281                  IQR                   101  DecisionTreeClassifier
# 309                  IQR                   102  DecisionTreeClassifier
# 337               Jitter                   101  DecisionTreeClassifier
# 365               Jitter                   102  DecisionTreeClassifier
# 393      Label_Stability                   101  DecisionTreeClassifier
# 421      Label_Stability                   102  DecisionTreeClassifier
# 449                 Mean                   101  DecisionTreeClassifier
# 477                 Mean                   102  DecisionTreeClassifier
# 505                  PPV                   101  DecisionTreeClassifier
# 533                  PPV                   102  DecisionTreeClassifier
# 561  Per_Sample_Accuracy                   101  DecisionTreeClassifier
# 589  Per_Sample_Accuracy                   102  DecisionTreeClassifier
# 617        Positive-Rate                   101  DecisionTreeClassifier
# 645        Positive-Rate                   102  DecisionTreeClassifier
# 673       Selection-Rate                   101  DecisionTreeClassifier
# 701       Selection-Rate                   102  DecisionTreeClassifier
# 729                  Std                   101  DecisionTreeClassifier
# 757                  Std                   102  DecisionTreeClassifier
# 785                  TNR                   101  DecisionTreeClassifier
# 813                  TNR                   102  DecisionTreeClassifier
# 841                  TPR                   101  DecisionTreeClassifier
# 869                  TPR                   102  DecisionTreeClassifier
#
#                                           Model_Params Run_Number  \
# 1    {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 29   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 57   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 85   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 113  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 141  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 169  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 197  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 225  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 253  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 281  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 309  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 337  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 365  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 393  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 421  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 449  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 477  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 505  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 533  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 561  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 589  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 617  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 645  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 673  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 701  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 729  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 757  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 785  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 813  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 841  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 869  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 645  1.162791  1.028966  1.093065
# 673  0.667973  0.639853  0.654200
# 701  0.607605  0.609228  0.608400
# 729  0.080997  0.101104  0.090845
# 757  0.079676  0.101344  0.090289
# 785  0.557471  0.694695  0.619305
# 813  0.651067  0.699700  0.672982
# 841  0.873968  0.870345  0.872080
# 869  0.843961  0.822069  0.832555
#
# [32 rows x 27 columns]

# %%
exp_subgroup_metrics_dct['DecisionTreeClassifier']['cat: mode, num: median']['Exp_iter_1'][0.0].head(100)
# Out:
#                   Metric  Bootstrap_Model_Seed              Model_Name  \
# 0               Accuracy                   101  DecisionTreeClassifier
# 28              Accuracy                   102  DecisionTreeClassifier
# 56               Entropy                   101  DecisionTreeClassifier
# 84               Entropy                   102  DecisionTreeClassifier
# 112                   F1                   101  DecisionTreeClassifier
# 140                   F1                   102  DecisionTreeClassifier
# 168                  FNR                   101  DecisionTreeClassifier
# 196                  FNR                   102  DecisionTreeClassifier
# 224                  FPR                   101  DecisionTreeClassifier
# 252                  FPR                   102  DecisionTreeClassifier
# 280                  IQR                   101  DecisionTreeClassifier
# 308                  IQR                   102  DecisionTreeClassifier
# 336               Jitter                   101  DecisionTreeClassifier
# 364               Jitter                   102  DecisionTreeClassifier
# 392      Label_Stability                   101  DecisionTreeClassifier
# 420      Label_Stability                   102  DecisionTreeClassifier
# 448                 Mean                   101  DecisionTreeClassifier
# 476                 Mean                   102  DecisionTreeClassifier
# 504                  PPV                   101  DecisionTreeClassifier
# 532                  PPV                   102  DecisionTreeClassifier
# 560  Per_Sample_Accuracy                   101  DecisionTreeClassifier
# 588  Per_Sample_Accuracy                   102  DecisionTreeClassifier
# 616        Positive-Rate                   101  DecisionTreeClassifier
# 644        Positive-Rate                   102  DecisionTreeClassifier
# 672       Selection-Rate                   101  DecisionTreeClassifier
# 700       Selection-Rate                   102  DecisionTreeClassifier
# 728                  Std                   101  DecisionTreeClassifier
# 756                  Std                   102  DecisionTreeClassifier
# 784                  TNR                   101  DecisionTreeClassifier
# 812                  TNR                   102  DecisionTreeClassifier
# 840                  TPR                   101  DecisionTreeClassifier
# 868                  TPR                   102  DecisionTreeClassifier
#
#                                           Model_Params Run_Number  \
# 0    {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 28   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 56   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 84   {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 112  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 140  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 168  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 196  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 224  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 252  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 280  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 308  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 336  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 364  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 392  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 420  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 448  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 476  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 504  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 532  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 560  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 588  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 616  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 644  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 672  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 700  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 728  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 756  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 784  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 812  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
# 840  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_1
# 868  {'ccp_alpha': 0.0, 'class_weight': None, 'crit...      Run_2
#
#            Dataset_Name  Num_Estimators  Test_Set_Index Tag  \
# 0    Folktables_GA_2018              10               0  OK
# 28   Folktables_GA_2018              10               0  OK
# 56   Folktables_GA_2018              10               0  OK
# 84   Folktables_GA_2018              10               0  OK
# 112  Folktables_GA_2018              10               0  OK
# 140  Folktables_GA_2018              10               0  OK
# 168  Folktables_GA_2018              10               0  OK
# 196  Folktables_GA_2018              10               0  OK
# 224  Folktables_GA_2018              10               0  OK
# 252  Folktables_GA_2018              10               0  OK
# 280  Folktables_GA_2018              10               0  OK
# %%
exp_avg_group_metrics_dct['DecisionTreeClassifier']['cat: mode_trimmed_0.3, num: median']['Exp_iter_1'][0.5].head(100)
# Out:
#                           Metric       SEX     RAC1P      AGEP  \
# 0             Equalized_Odds_TPR -0.000369  0.016804 -0.093370
# 1             Equalized_Odds_FPR  0.074364  0.071170 -0.331503
# 2               Disparate_Impact  1.130670  1.087759  1.032421
# 3  Statistical_Parity_Difference  0.143962  0.099857  0.037039
# 4                Accuracy_Parity -0.050123 -0.027723 -0.046342
# 5          Label_Stability_Ratio  1.006000  0.998782  0.912650
# 6                     IQR_Parity -0.046145  0.013958 -0.003705
# 7                     Std_Parity -0.023275  0.003294  0.013631
# 8                      Std_Ratio  0.777445  1.035958  1.167434
# 9                  Jitter_Parity  0.002526 -0.003197  0.063083
#
#    SEX&RAC1P&AGEP              Model_Name
# 0       -0.099768  DecisionTreeClassifier
# 1        0.016984  DecisionTreeClassifier
# 2        1.248786  DecisionTreeClassifier
# 3        0.251989  DecisionTreeClassifier
# 4       -0.190694  DecisionTreeClassifier
# 5        0.903506  DecisionTreeClassifier
# 6       -0.027341  DecisionTreeClassifier
# 7       -0.002723  DecisionTreeClassifier
# 8        0.966744  DecisionTreeClassifier
# 9        0.075048  DecisionTreeClassifier

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_avg_runs_group_metrics_dct=exp_avg_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_exp_avg_runs_subgroup_metrics_dct[MODEL_NAMES[0]][PREPROCESSING_TECHNIQUES[0]]['Exp_iter_1'][0.5]
# Out:
#              Metric              Model_Name  Num_Estimators  Test_Set_Index  \
# 0          Accuracy  DecisionTreeClassifier            10.0             6.0
# 1           Entropy  DecisionTreeClassifier            10.0             6.0
# 2                F1  DecisionTreeClassifier            10.0             6.0
# 3               FNR  DecisionTreeClassifier            10.0             6.0
# 4               FPR  DecisionTreeClassifier            10.0             6.0
# ..              ...                     ...             ...             ...
# 139   Positive-Rate  DecisionTreeClassifier            10.0             6.0
# 140  Selection-Rate  DecisionTreeClassifier            10.0             6.0
# 141             Std  DecisionTreeClassifier            10.0             6.0
# 142             TNR  DecisionTreeClassifier            10.0             6.0
# 143             TPR  DecisionTreeClassifier            10.0             6.0
#
#      Dataset_Split_Seed  Model_Init_Seed  Subgroup  Metric_Value
# 0                 100.0            100.0  AGEP_dis      0.749216
# 1                 100.0            100.0  AGEP_dis      0.170802
# 2                 100.0            100.0  AGEP_dis      0.775558
# 3                 100.0            100.0  AGEP_dis      0.154498
# 4                 100.0            100.0  AGEP_dis      0.351980
# ..                  ...              ...       ...           ...
# 139               100.0            100.0   overall      1.171577
# 140               100.0            100.0   overall      0.652100
# 141               100.0            100.0   overall      0.093175
# 142               100.0            100.0   overall      0.618629
# 143               100.0            100.0   overall      0.867769
#
# [144 rows x 8 columns]

# %%
visualizer.melted_exp_avg_runs_group_metrics_dct[MODEL_NAMES[0]][PREPROCESSING_TECHNIQUES[0]]['Exp_iter_1'][0.3].head(1000)
# Out:
#                            Metric              Model_Name           Group  \
# 0              Equalized_Odds_TPR  DecisionTreeClassifier             SEX
# 1              Equalized_Odds_FPR  DecisionTreeClassifier             SEX
# 2                Disparate_Impact  DecisionTreeClassifier             SEX
# 3   Statistical_Parity_Difference  DecisionTreeClassifier             SEX
# 4                 Accuracy_Parity  DecisionTreeClassifier             SEX
# 5           Label_Stability_Ratio  DecisionTreeClassifier             SEX
# 6                      IQR_Parity  DecisionTreeClassifier             SEX
# 7                      Std_Parity  DecisionTreeClassifier             SEX
# 8                       Std_Ratio  DecisionTreeClassifier             SEX
# 9                   Jitter_Parity  DecisionTreeClassifier             SEX
# 10             Equalized_Odds_TPR  DecisionTreeClassifier           RAC1P
# 11             Equalized_Odds_FPR  DecisionTreeClassifier           RAC1P
# 12               Disparate_Impact  DecisionTreeClassifier           RAC1P
# 13  Statistical_Parity_Difference  DecisionTreeClassifier           RAC1P
# 14                Accuracy_Parity  DecisionTreeClassifier           RAC1P
# 15          Label_Stability_Ratio  DecisionTreeClassifier           RAC1P
# 16                     IQR_Parity  DecisionTreeClassifier           RAC1P
# 17                     Std_Parity  DecisionTreeClassifier           RAC1P
# 18                      Std_Ratio  DecisionTreeClassifier           RAC1P
# 19                  Jitter_Parity  DecisionTreeClassifier           RAC1P
# 20             Equalized_Odds_TPR  DecisionTreeClassifier            AGEP
# 21             Equalized_Odds_FPR  DecisionTreeClassifier            AGEP
# 22               Disparate_Impact  DecisionTreeClassifier            AGEP
# 23  Statistical_Parity_Difference  DecisionTreeClassifier            AGEP
# 24                Accuracy_Parity  DecisionTreeClassifier            AGEP
# 25          Label_Stability_Ratio  DecisionTreeClassifier            AGEP
# 26                     IQR_Parity  DecisionTreeClassifier            AGEP
# 27                     Std_Parity  DecisionTreeClassifier            AGEP
# 28                      Std_Ratio  DecisionTreeClassifier            AGEP
# 29                  Jitter_Parity  DecisionTreeClassifier            AGEP
# 30             Equalized_Odds_TPR  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 31             Equalized_Odds_FPR  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 32               Disparate_Impact  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 33  Statistical_Parity_Difference  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 34                Accuracy_Parity  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 35          Label_Stability_Ratio  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 36                     IQR_Parity  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 37                     Std_Parity  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 38                      Std_Ratio  DecisionTreeClassifier  SEX&RAC1P&AGEP
# 39                  Jitter_Parity  DecisionTreeClassifier  SEX&RAC1P&AGEP
#
#     Metric_Value
# 0       0.007331
# 1       0.085662
# 2       1.146296
# 3       0.156587
# 4      -0.048792
# 5       1.017890
# 6      -0.041964
# 7      -0.021036
# 8       0.793905
# 9      -0.005942
# 10      0.015489
# 11      0.056638
# 12      1.076523
# 13      0.085495
# 14     -0.021332
# 15      0.998886
# 16      0.014001
# 17      0.003210
# 18      1.035567
# 19     -0.002518
# 20     -0.095062
# 21     -0.331559
# 22      1.021018
# 23      0.023693
# 24     -0.040066
# 25      0.918117
# 26     -0.001951
# 27      0.012777
# 28      1.158239
# 29      0.058464
# 30     -0.093730
# 31      0.013587
# 32      1.244401
# 33      0.241254
# 34     -0.171148
# 35      0.917281
# 36     -0.020269
# 37     -0.001716
# 38      0.978551
# 39      0.062279

# %% [markdown]
# ### Subgroup metrics per dataset, experiment iteration, and model

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='variance')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_plot(model_name=MODEL_NAMES[1],
                                                target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                subgroup_metrics_type='error')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Group metrics per dataset and model

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='variance')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_plot(model_name=MODEL_NAMES[0],
                                             target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                             group_metrics_type='fairness')
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset and multiple models

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='Jitter',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[1],
                                                          model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_plot(subgroup_metric='F1',
                                                          target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                          model_names=MODEL_NAMES)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific group metric per dataset, experiment iteration, and multiple models

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric='Label_Stability_Ratio',
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES[:2])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_groups_grid_pct_lines_per_model_plot(group_metric='Disparate_Impact',
                                                       target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                       model_names=MODEL_NAMES[:2])
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Specific subgroup metric per dataset, one model, and multiple preprocessing techniques

# %%
visualizer.create_subgroups_grid_pct_lines_per_model_and_preprocessing_plot(subgroup_metric='Jitter', model_name=MODEL_NAMES[0])
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Box plots for subgroup metrics per model and experiment iteration

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=0.5,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_exp_iters(target_percentage=0.5,
                                                                   target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                   subgroup_metrics_type='error')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[0],
                                                                     subgroup_metrics_type='variance')

# %%
visualizer.create_subgroup_metrics_box_plot_for_multiple_percentages(target_preprocessing_technique=PREPROCESSING_TECHNIQUES[1],
                                                                     subgroup_metrics_type='error')
