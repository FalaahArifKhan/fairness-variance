# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_GA_2018_Income'
EXPERIMENT_SESSION_UUID = '26beff01-939d-4d98-be67-65b150b352b2'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (95, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3                Accuracy                   101  RandomForestClassifier
# 4                Accuracy                   101  RandomForestClassifier
# 5   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 6   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 7   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 8   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 9   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 10                     F1                   101  RandomForestClassifier
# 11                     F1                   101  RandomForestClassifier
# 12                     F1                   101  RandomForestClassifier
# 13                     F1                   101  RandomForestClassifier
# 14                     F1                   101  RandomForestClassifier
# 15                    FNR                   101  RandomForestClassifier
# 16                    FNR                   101  RandomForestClassifier
# 17                    FNR                   101  RandomForestClassifier
# 18                    FNR                   101  RandomForestClassifier
# 19                    FNR                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 12  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                           Dataset_Name  Num_Estimators Tag  \
# 0   Folktables_CA_2018_Public_Coverage              20  OK
# 1   Folktables_CA_2018_Public_Coverage              20  OK
# 2   Folktables_CA_2018_Public_Coverage              20  OK
# 3   Folktables_CA_2018_Public_Coverage              20  OK
# 4   Folktables_CA_2018_Public_Coverage              20  OK
# 5   Folktables_CA_2018_Public_Coverage              20  OK
# 6   Folktables_CA_2018_Public_Coverage              20  OK
# 7   Folktables_CA_2018_Public_Coverage              20  OK
# 8   Folktables_CA_2018_Public_Coverage              20  OK
# 9   Folktables_CA_2018_Public_Coverage              20  OK
# 10  Folktables_CA_2018_Public_Coverage              20  OK
# 11  Folktables_CA_2018_Public_Coverage              20  OK
# 12  Folktables_CA_2018_Public_Coverage              20  OK
# 13  Folktables_CA_2018_Public_Coverage              20  OK
# 14  Folktables_CA_2018_Public_Coverage              20  OK
# 15  Folktables_CA_2018_Public_Coverage              20  OK
# 16  Folktables_CA_2018_Public_Coverage              20  OK
# 17  Folktables_CA_2018_Public_Coverage              20  OK
# 18  Folktables_CA_2018_Public_Coverage              20  OK
# 19  Folktables_CA_2018_Public_Coverage              20  OK
#
#    Record_Create_Date_Time                          Session_Uuid  ...  \
# 0  2023-07-31 16:43:49.255  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 1  2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 2  2023-07-31 16:46:39.530  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 3  2023-07-31 16:53:34.924  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 4  2023-07-31 16:39:25.680  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 5  2023-07-31 16:43:49.255  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 6  2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 7  2023-07-31 16:46:39.530  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 8  2023-07-31 16:53:34.924  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 9  2023-07-31 16:39:25.680  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 10 2023-07-31 16:43:49.255  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 11 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 12 2023-07-31 16:46:39.530  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 13 2023-07-31 16:53:34.924  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 14 2023-07-31 16:39:25.680  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 15 2023-07-31 16:43:49.255  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 16 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 17 2023-07-31 16:46:39.530  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 18 2023-07-31 16:53:34.924  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 19 2023-07-31 16:39:25.680  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
#
#    SEX&RAC1P_priv  SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect   SEX_dis  \
# 0        0.676852                1.000000                  0.000000  0.706651
# 1        0.689815                1.000000                  0.000000  0.723278
# 2        0.686111                1.000000                  0.000000  0.707838
# 3        0.692593                1.000000                  0.000000  0.714964
# 4        0.677778                1.000000                  0.000000  0.694774
# 5        0.815409                0.786821                  0.875288  0.812771
# 6        0.812695                0.788201                  0.867166  0.810753
# 7        0.814467                0.788466                  0.871300  0.810590
# 8        0.817632                0.794172                  0.870488  0.815127
# 9        0.686626                0.661899                  0.738637  0.685542
# 10       0.482963                1.000000                  0.000000  0.496945
# 11       0.503704                1.000000                  0.000000  0.531187
# 12       0.503660                1.000000                  0.000000  0.515748
# 13       0.517442                1.000000                  0.000000  0.525692
# 14       0.532258                1.000000                  0.000000  0.536937
# 15       0.616471                0.000000                  1.000000  0.602606
# 16       0.600000                0.000000                  1.000000  0.570033
# 17       0.595294                0.000000                  1.000000  0.573290
# 18       0.581176                0.000000                  1.000000  0.566775
# 19       0.534118                0.000000                  1.000000  0.514658
#
#     SEX_dis_correct  SEX_dis_incorrect  SEX_priv  SEX_priv_correct  \
# 0          1.000000           0.000000  0.668693          1.000000
# 1          1.000000           0.000000  0.676292          1.000000
# 2          1.000000           0.000000  0.677812          1.000000
# 3          1.000000           0.000000  0.685410          1.000000
# 4          1.000000           0.000000  0.673252          1.000000
# 5          0.783464           0.883368  0.823026          0.797408
# 6          0.786524           0.874082  0.819694          0.796047
# 7          0.781061           0.882131  0.821741          0.798757
# 8          0.788718           0.881370  0.823532          0.802933
# 9          0.650639           0.764991  0.695712          0.676361
# 10         1.000000           0.000000  0.488263          1.000000
# 11         1.000000           0.000000  0.501171          1.000000
# 12         1.000000           0.000000  0.500000          1.000000
# 13         1.000000           0.000000  0.521940          1.000000
# 14         1.000000           0.000000  0.531590          1.000000
# 15         0.000000           1.000000  0.617647          0.000000
# 16         0.000000           1.000000  0.606618          0.000000
# 17         0.000000           1.000000  0.610294          0.000000
# 18         0.000000           1.000000  0.584559          0.000000
# 19         0.000000           1.000000  0.551471          0.000000
#
#     SEX_priv_incorrect   overall
# 0             0.000000  0.690000
# 1             0.000000  0.702667
# 2             0.000000  0.694667
# 3             0.000000  0.702000
# 4             0.000000  0.685333
# 5             0.874732  0.817269
# 6             0.869096  0.814675
# 7             0.870093  0.815481
# 8             0.868413  0.818814
# 9             0.735585  0.690003
# 10            0.000000  0.492912
# 11            0.000000  0.517316
# 12            0.000000  0.508584
# 13            0.000000  0.523962
# 14            0.000000  0.534517
# 15            1.000000  0.609672
# 16            1.000000  0.587219
# 17            1.000000  0.590674
# 18            1.000000  0.575130
# 19            1.000000  0.531952
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
#                                                                              67
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...
# Run_Number                                                                Run_1
# Dataset_Name                                 Folktables_CA_2018_Public_Coverage
# Num_Estimators                                                               20
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-07-31 16:46:39.530000
# Session_Uuid                               58ecf391-a5ca-4ff9-a1d5-d7cdc804a115
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                               [0.0, 0.1, 0.3, 0.5]
# Intervention_Param                                                          0.1
# RAC1P_dis                                                                 705.0
# RAC1P_dis_correct                                                         485.0
# RAC1P_dis_incorrect                                                       220.0
# RAC1P_priv                                                                795.0
# RAC1P_priv_correct                                                        557.0
# RAC1P_priv_incorrect                                                      238.0
# SEX&RAC1P_dis                                                             420.0
# SEX&RAC1P_dis_correct                                                     301.0
# SEX&RAC1P_dis_incorrect                                                   119.0
# SEX&RAC1P_priv                                                           1080.0
# SEX&RAC1P_priv_correct                                                    741.0
# SEX&RAC1P_priv_incorrect                                                  339.0
# SEX_dis                                                                   842.0
# SEX_dis_correct                                                           596.0
# SEX_dis_incorrect                                                         246.0
# SEX_priv                                                                  658.0
# SEX_priv_correct                                                          446.0
# SEX_priv_incorrect                                                        212.0
# overall                                                                  1500.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.3].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 1                Accuracy                   101  RandomForestClassifier
# 6   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 11                     F1                   101  RandomForestClassifier
# 16                    FNR                   101  RandomForestClassifier
# 21                    FPR                   101  RandomForestClassifier
# 26                    IQR                   101  RandomForestClassifier
# 31                 Jitter                   101  RandomForestClassifier
# 36        Label_Stability                   101  RandomForestClassifier
# 41                   Mean                   101  RandomForestClassifier
# 46    Overall_Uncertainty                   101  RandomForestClassifier
# 51                    PPV                   101  RandomForestClassifier
# 56    Per_Sample_Accuracy                   101  RandomForestClassifier
# 61          Positive-Rate                   101  RandomForestClassifier
# 66            Sample_Size                   101  RandomForestClassifier
# 71         Selection-Rate                   101  RandomForestClassifier
# 76       Statistical_Bias                   101  RandomForestClassifier
# 81                    Std                   101  RandomForestClassifier
# 86                    TNR                   101  RandomForestClassifier
# 91                    TPR                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 1   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 21  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 26  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 31  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 36  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 41  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 46  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 51  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 56  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 61  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 66  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 71  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 76  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 81  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 86  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 91  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                           Dataset_Name  Num_Estimators Tag  \
# 1   Folktables_CA_2018_Public_Coverage              20  OK
# 6   Folktables_CA_2018_Public_Coverage              20  OK
# 11  Folktables_CA_2018_Public_Coverage              20  OK
# 16  Folktables_CA_2018_Public_Coverage              20  OK
# 21  Folktables_CA_2018_Public_Coverage              20  OK
# 26  Folktables_CA_2018_Public_Coverage              20  OK
# 31  Folktables_CA_2018_Public_Coverage              20  OK
# 36  Folktables_CA_2018_Public_Coverage              20  OK
# 41  Folktables_CA_2018_Public_Coverage              20  OK
# 46  Folktables_CA_2018_Public_Coverage              20  OK
# 51  Folktables_CA_2018_Public_Coverage              20  OK
# 56  Folktables_CA_2018_Public_Coverage              20  OK
# 61  Folktables_CA_2018_Public_Coverage              20  OK
# 66  Folktables_CA_2018_Public_Coverage              20  OK
# 71  Folktables_CA_2018_Public_Coverage              20  OK
# 76  Folktables_CA_2018_Public_Coverage              20  OK
# 81  Folktables_CA_2018_Public_Coverage              20  OK
# 86  Folktables_CA_2018_Public_Coverage              20  OK
# 91  Folktables_CA_2018_Public_Coverage              20  OK
#
#    Record_Create_Date_Time                          Session_Uuid  ...  \
# 1  2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 6  2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 11 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 16 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 21 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 26 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 31 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 36 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 41 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 46 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 51 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 56 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 61 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 66 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 71 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 76 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 81 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 86 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
# 91 2023-07-31 16:49:19.722  58ecf391-a5ca-4ff9-a1d5-d7cdc804a115  ...
#
#    SEX&RAC1P_priv  SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect  \
# 1        0.689815                1.000000                  0.000000
# 6        0.812695                0.788201                  0.867166
# 11       0.503704                1.000000                  0.000000
# 16       0.600000                0.000000                  1.000000
# 21       0.122137                0.000000                  1.000000
# 26       0.090492                0.086186                  0.100070
# 31       0.119771                0.098467                  0.167148
# 36       0.837130                0.866577                  0.771642
# 41       0.628825                0.638822                  0.606595
# 46       0.830677                0.805289                  0.887138
# 51       0.680000                1.000000                  0.000000
# 56       0.679306                0.933020                  0.115075
# 61       0.588235                1.000000                  0.313725
# 66    1080.000000              745.000000                335.000000
# 71       0.231481                0.228188                  0.238806
# 76       0.399965                0.282748                  0.660640
# 81       0.069584                0.066509                  0.076422
# 86       0.877863                1.000000                  0.000000
# 91       0.400000                1.000000                  0.000000
#
#        SEX_dis  SEX_dis_correct  SEX_dis_incorrect    SEX_priv  \
# 1     0.723278         1.000000           0.000000    0.676292
# 6     0.810753         0.786524           0.874082    0.819694
# 11    0.531187         1.000000           0.000000    0.501171
# 16    0.570033         0.000000           1.000000    0.606618
# 21    0.108411         0.000000           1.000000    0.124352
# 26    0.091128         0.087918           0.099519    0.091156
# 31    0.125872         0.106369           0.176847    0.116165
# 36    0.823872         0.850903           0.753219    0.843921
# 41    0.633362         0.643269           0.607467    0.625034
# 46    0.829231         0.804565           0.893703    0.837632
# 51    0.694737         1.000000           0.000000    0.690323
# 56    0.702910         0.923810           0.125536    0.668921
# 61    0.618893         1.000000           0.331429    0.569853
# 66  842.000000       609.000000         233.000000  658.000000
# 71    0.225653         0.216749           0.248927    0.235562
# 76    0.385874         0.283058           0.654606    0.407265
# 81    0.070434         0.068227           0.076202    0.069769
# 86    0.891589         1.000000           0.000000    0.875648
# 91    0.429967         1.000000           0.000000    0.393382
#
#     SEX_priv_correct  SEX_priv_incorrect      overall
# 1           1.000000            0.000000     0.702667
# 6           0.796047            0.869096     0.814675
# 11          1.000000            0.000000     0.517316
# 16          0.000000            1.000000     0.587219
# 21          0.000000            1.000000     0.115092
# 26          0.087454            0.098890     0.091140
# 31          0.094477            0.161478     0.121614
# 36          0.873708            0.781690     0.832667
# 41          0.632842            0.608722     0.629709
# 46          0.813215            0.888645     0.832916
# 51          1.000000            0.000000     0.692754
# 56          0.936629            0.109624     0.688000
# 61          1.000000            0.290909     0.595855
# 66        445.000000          213.000000  1500.000000
# 71          0.240449            0.225352     0.230000
# 76          0.285662            0.661319     0.395257
# 81          0.066933            0.075694     0.070142
# 86          1.000000            0.000000     0.884908
# 91          1.000000            0.000000     0.412781
#
# [19 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.9].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.9].head()
#
# KeyError: 0.9

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11             Equalized_Odds_TPR  RandomForestClassifier
# 12             Equalized_Odds_FPR  RandomForestClassifier
# 13             Equalized_Odds_FNR  RandomForestClassifier
# 14               Disparate_Impact  RandomForestClassifier
# 15  Statistical_Parity_Difference  RandomForestClassifier
# 16                Accuracy_Parity  RandomForestClassifier
# 17          Label_Stability_Ratio  RandomForestClassifier
# 18                     IQR_Parity  RandomForestClassifier
# 19                     Std_Parity  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 0.0    SEX      0.025927
# 1            Exp_iter_1                 0.0    SEX      0.001504
# 2            Exp_iter_1                 0.0    SEX     -0.025927
# 3            Exp_iter_1                 0.0    SEX      1.122432
# 4            Exp_iter_1                 0.0    SEX      0.076745
# 5            Exp_iter_1                 0.0    SEX      0.029740
# 6            Exp_iter_1                 0.0    SEX      1.000393
# 7            Exp_iter_1                 0.0    SEX     -0.001669
# 8            Exp_iter_1                 0.0    SEX     -0.001300
# 9            Exp_iter_1                 0.0    SEX      0.986448
# 10           Exp_iter_1                 0.0    SEX     -0.000984
# 11           Exp_iter_1                 0.0  RAC1P     -0.029898
# 12           Exp_iter_1                 0.0  RAC1P     -0.021915
# 13           Exp_iter_1                 0.0  RAC1P      0.029898
# 14           Exp_iter_1                 0.0  RAC1P      0.911344
# 15           Exp_iter_1                 0.0  RAC1P     -0.061742
# 16           Exp_iter_1                 0.0  RAC1P      0.003198
# 17           Exp_iter_1                 0.0  RAC1P      0.997386
# 18           Exp_iter_1                 0.0  RAC1P      0.006457
# 19           Exp_iter_1                 0.0  RAC1P      0.004039

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='RAC1P',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='RAC1P',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio',
                                                              'Jitter_Parity', 'Disparate_Impact'])
# Out:
# alt.VConcatChart(...)
