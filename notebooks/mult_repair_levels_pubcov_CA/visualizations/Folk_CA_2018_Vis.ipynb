# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /home/dh3553/projects/fairness-variance

# %% [markdown]
# # Visualizations

# %%
import os
import pandas as pd

from virny.utils.custom_initializers import create_models_metrics_dct_from_database_df

from source.utils.db_functions import read_model_metric_dfs_from_db
from source.custom_classes.experiments_composer import ExperimentsComposer
from source.custom_classes.experiments_visualizer import ExperimentsVisualizer

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'exp_mult_repair_levels'
DATASET_NAME = 'Folktables_CA_2018_Public_Coverage'
EXPERIMENT_SESSION_UUID = '116104d6-7d63-4564-ae57-82b19b260fa5'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
MODEL_NAMES = ['RandomForestClassifier']

# %%
from source.utils.db_functions import connect_to_mongodb

client, collection_obj, db_writer_func = connect_to_mongodb(DB_COLLECTION_NAME)

# %% [markdown]
# ## Group Metrics Composition

# %%
model_metric_dfs = read_model_metric_dfs_from_db(collection_obj, EXPERIMENT_SESSION_UUID)
models_metrics_dct = create_models_metrics_dct_from_database_df(model_metric_dfs)
client.close()

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].shape
# Out:
# (209, 34)

# %%
models_metrics_dct[list(models_metrics_dct.keys())[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1                Accuracy                   101  RandomForestClassifier
# 2                Accuracy                   101  RandomForestClassifier
# 3                Accuracy                   101  RandomForestClassifier
# 4                Accuracy                   101  RandomForestClassifier
# 5                Accuracy                   101  RandomForestClassifier
# 6                Accuracy                   101  RandomForestClassifier
# 7                Accuracy                   101  RandomForestClassifier
# 8                Accuracy                   101  RandomForestClassifier
# 9                Accuracy                   101  RandomForestClassifier
# 10               Accuracy                   101  RandomForestClassifier
# 11  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 12  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 13  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 14  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 15  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 16  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 17  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 18  Aleatoric_Uncertainty                   101  RandomForestClassifier
# 19  Aleatoric_Uncertainty                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 2   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 3   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 4   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 5   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 6   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 7   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 8   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 9   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 10  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 13  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 14  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 15  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 16  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 17  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 19  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                           Dataset_Name  Num_Estimators Tag  \
# 0   Folktables_CA_2018_Public_Coverage             200  OK
# 1   Folktables_CA_2018_Public_Coverage             200  OK
# 2   Folktables_CA_2018_Public_Coverage             200  OK
# 3   Folktables_CA_2018_Public_Coverage             200  OK
# 4   Folktables_CA_2018_Public_Coverage             200  OK
# 5   Folktables_CA_2018_Public_Coverage             200  OK
# 6   Folktables_CA_2018_Public_Coverage             200  OK
# 7   Folktables_CA_2018_Public_Coverage             200  OK
# 8   Folktables_CA_2018_Public_Coverage             200  OK
# 9   Folktables_CA_2018_Public_Coverage             200  OK
# 10  Folktables_CA_2018_Public_Coverage             200  OK
# 11  Folktables_CA_2018_Public_Coverage             200  OK
# 12  Folktables_CA_2018_Public_Coverage             200  OK
# 13  Folktables_CA_2018_Public_Coverage             200  OK
# 14  Folktables_CA_2018_Public_Coverage             200  OK
# 15  Folktables_CA_2018_Public_Coverage             200  OK
# 16  Folktables_CA_2018_Public_Coverage             200  OK
# 17  Folktables_CA_2018_Public_Coverage             200  OK
# 18  Folktables_CA_2018_Public_Coverage             200  OK
# 19  Folktables_CA_2018_Public_Coverage             200  OK
#
#    Record_Create_Date_Time                          Session_Uuid  ...  \
# 0  2023-07-31 17:51:11.475  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 1  2023-07-31 17:47:41.514  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 2  2023-07-31 17:36:23.683  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 3  2023-07-31 17:49:59.848  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 4  2023-07-31 17:52:17.276  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 5  2023-07-31 17:50:48.209  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 6  2023-07-31 17:35:50.720  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 7  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 8  2023-07-31 17:37:22.142  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 9  2023-07-31 17:39:01.386  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 10 2023-07-31 17:37:35.900  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 11 2023-07-31 17:51:11.475  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 12 2023-07-31 17:47:41.514  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 13 2023-07-31 17:36:23.683  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 14 2023-07-31 17:49:59.848  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 15 2023-07-31 17:52:17.276  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 16 2023-07-31 17:50:48.209  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 17 2023-07-31 17:35:50.720  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 18 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 19 2023-07-31 17:37:22.142  116104d6-7d63-4564-ae57-82b19b260fa5  ...
#
#    SEX&RAC1P_priv  SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect   SEX_dis  \
# 0        0.688889                1.000000                  0.000000  0.714964
# 1        0.687037                1.000000                  0.000000  0.716152
# 2        0.688889                1.000000                  0.000000  0.712589
# 3        0.693519                1.000000                  0.000000  0.716152
# 4        0.689815                1.000000                  0.000000  0.710214
# 5        0.688889                1.000000                  0.000000  0.714964
# 6        0.681481                1.000000                  0.000000  0.710214
# 7        0.687037                1.000000                  0.000000  0.712589
# 8        0.691667                1.000000                  0.000000  0.719715
# 9        0.687963                1.000000                  0.000000  0.712589
# 10       0.693519                1.000000                  0.000000  0.716152
# 11       0.806107                0.781005                  0.861690  0.802995
# 12       0.798911                0.773066                  0.855650  0.796373
# 13       0.793844                0.768333                  0.850333  0.790136
# 14       0.796505                0.772592                  0.850618  0.793579
# 15       0.798656                0.773722                  0.854105  0.795793
# 16       0.799706                0.774716                  0.855041  0.796753
# 17       0.813962                0.786303                  0.873139  0.812119
# 18       0.814988                0.789418                  0.871120  0.813040
# 19       0.788715                0.764966                  0.841991  0.785985
#
#     SEX_dis_correct  SEX_dis_incorrect  SEX_priv  SEX_priv_correct  \
# 0          1.000000           0.000000  0.677812          1.000000
# 1          1.000000           0.000000  0.671733          1.000000
# 2          1.000000           0.000000  0.680851          1.000000
# 3          1.000000           0.000000  0.685410          1.000000
# 4          1.000000           0.000000  0.682371          1.000000
# 5          1.000000           0.000000  0.682371          1.000000
# 6          1.000000           0.000000  0.668693          1.000000
# 7          1.000000           0.000000  0.674772          1.000000
# 8          1.000000           0.000000  0.680851          1.000000
# 9          1.000000           0.000000  0.682371          1.000000
# 10         1.000000           0.000000  0.688450          1.000000
# 11         0.774609           0.874199  0.814323          0.791237
# 12         0.768942           0.865582  0.806301          0.781454
# 13         0.760953           0.862492  0.802854          0.780671
# 14         0.765932           0.863331  0.804687          0.783733
# 15         0.765309           0.870501  0.808358          0.786742
# 16         0.767946           0.869012  0.809030          0.787374
# 17         0.782903           0.883721  0.820445          0.794439
# 18         0.785674           0.880890  0.821177          0.797114
# 19         0.759576           0.853796  0.796459          0.774956
#
#     SEX_priv_incorrect   overall
# 0             0.000000  0.698667
# 1             0.000000  0.696667
# 2             0.000000  0.698667
# 3             0.000000  0.702667
# 4             0.000000  0.698000
# 5             0.000000  0.700667
# 6             0.000000  0.692000
# 7             0.000000  0.696000
# 8             0.000000  0.702667
# 9             0.000000  0.699333
# 10            0.000000  0.704000
# 11            0.862891  0.807964
# 12            0.857145  0.800728
# 13            0.850178  0.795715
# 14            0.850341  0.798452
# 15            0.854796  0.801305
# 16            0.855554  0.802139
# 17            0.872934  0.815771
# 18            0.871104  0.816610
# 19            0.842334  0.790580
#
# [20 rows x 34 columns]

# %%
df = models_metrics_dct[list(models_metrics_dct.keys())[0]]
df[(df.Metric == 'Sample_Size') & (df.Experiment_Iteration == 'Exp_iter_1') & (df.Intervention_Param == 0.1)].T
# Out:
#                                                                             144
# Metric                                                              Sample_Size
# Bootstrap_Model_Seed                                                        101
# Model_Name                                               RandomForestClassifier
# Model_Params                  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...
# Run_Number                                                                Run_1
# Dataset_Name                                 Folktables_CA_2018_Public_Coverage
# Num_Estimators                                                              200
# Tag                                                                          OK
# Record_Create_Date_Time                              2023-07-31 17:47:41.514000
# Session_Uuid                               116104d6-7d63-4564-ae57-82b19b260fa5
# Experiment_Iteration                                                 Exp_iter_1
# Dataset_Split_Seed                                                          100
# Model_Init_Seed                                                             100
# Fair_Intervention_Params_Lst                                         [0.0, 0.1]
# Intervention_Param                                                          0.1
# RAC1P_dis                                                                 705.0
# RAC1P_dis_correct                                                         488.0
# RAC1P_dis_incorrect                                                       217.0
# RAC1P_priv                                                                795.0
# RAC1P_priv_correct                                                        557.0
# RAC1P_priv_incorrect                                                      238.0
# SEX&RAC1P_dis                                                             420.0
# SEX&RAC1P_dis_correct                                                     303.0
# SEX&RAC1P_dis_incorrect                                                   117.0
# SEX&RAC1P_priv                                                           1080.0
# SEX&RAC1P_priv_correct                                                    742.0
# SEX&RAC1P_priv_incorrect                                                  338.0
# SEX_dis                                                                   842.0
# SEX_dis_correct                                                           603.0
# SEX_dis_incorrect                                                         239.0
# SEX_priv                                                                  658.0
# SEX_priv_correct                                                          442.0
# SEX_priv_incorrect                                                        216.0
# overall                                                                  1500.0

# %%
exp_composer = ExperimentsComposer(models_metrics_dct, SENSITIVE_ATTRS)
exp_subgroup_metrics_dct = exp_composer.create_exp_subgroup_metrics_dct()

# %%
exp_group_metrics_dct = exp_composer.compose_group_metrics(exp_subgroup_metrics_dct)

# %%
exp_subgroup_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.3].head(20)
# Out:
#                     Metric  Bootstrap_Model_Seed              Model_Name  \
# 7                 Accuracy                   101  RandomForestClassifier
# 18   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 29                      F1                   101  RandomForestClassifier
# 40                     FNR                   101  RandomForestClassifier
# 51                     FPR                   101  RandomForestClassifier
# 62                     IQR                   101  RandomForestClassifier
# 73                  Jitter                   101  RandomForestClassifier
# 84         Label_Stability                   101  RandomForestClassifier
# 95                    Mean                   101  RandomForestClassifier
# 106    Overall_Uncertainty                   101  RandomForestClassifier
# 117                    PPV                   101  RandomForestClassifier
# 128    Per_Sample_Accuracy                   101  RandomForestClassifier
# 139          Positive-Rate                   101  RandomForestClassifier
# 150            Sample_Size                   101  RandomForestClassifier
# 161         Selection-Rate                   101  RandomForestClassifier
# 172       Statistical_Bias                   101  RandomForestClassifier
# 183                    Std                   101  RandomForestClassifier
# 194                    TNR                   101  RandomForestClassifier
# 205                    TPR                   101  RandomForestClassifier
#
#                                           Model_Params Run_Number  \
# 7    {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 18   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 29   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 40   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 51   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 62   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 73   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 84   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 95   {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 106  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 117  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 128  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 139  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 150  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 161  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 172  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 183  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 194  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
# 205  {'bootstrap': True, 'ccp_alpha': 0.0, 'class_w...      Run_1
#
#                            Dataset_Name  Num_Estimators Tag  \
# 7    Folktables_CA_2018_Public_Coverage             200  OK
# 18   Folktables_CA_2018_Public_Coverage             200  OK
# 29   Folktables_CA_2018_Public_Coverage             200  OK
# 40   Folktables_CA_2018_Public_Coverage             200  OK
# 51   Folktables_CA_2018_Public_Coverage             200  OK
# 62   Folktables_CA_2018_Public_Coverage             200  OK
# 73   Folktables_CA_2018_Public_Coverage             200  OK
# 84   Folktables_CA_2018_Public_Coverage             200  OK
# 95   Folktables_CA_2018_Public_Coverage             200  OK
# 106  Folktables_CA_2018_Public_Coverage             200  OK
# 117  Folktables_CA_2018_Public_Coverage             200  OK
# 128  Folktables_CA_2018_Public_Coverage             200  OK
# 139  Folktables_CA_2018_Public_Coverage             200  OK
# 150  Folktables_CA_2018_Public_Coverage             200  OK
# 161  Folktables_CA_2018_Public_Coverage             200  OK
# 172  Folktables_CA_2018_Public_Coverage             200  OK
# 183  Folktables_CA_2018_Public_Coverage             200  OK
# 194  Folktables_CA_2018_Public_Coverage             200  OK
# 205  Folktables_CA_2018_Public_Coverage             200  OK
#
#     Record_Create_Date_Time                          Session_Uuid  ...  \
# 7   2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 18  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 29  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 40  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 51  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 62  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 73  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 84  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 95  2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 106 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 117 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 128 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 139 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 150 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 161 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 172 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 183 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 194 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
# 205 2023-07-31 17:46:16.228  116104d6-7d63-4564-ae57-82b19b260fa5  ...
#
#     SEX&RAC1P_priv  SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect  \
# 7         0.687037                1.000000                  0.000000
# 18        0.814988                0.789418                  0.871120
# 29        0.501475                1.000000                  0.000000
# 40        0.600000                0.000000                  1.000000
# 51        0.126718                0.000000                  1.000000
# 62        0.093061                0.089504                  0.100869
# 73        0.113877                0.093029                  0.159646
# 84        0.841269                0.872534                  0.772633
# 95        0.629154                0.639413                  0.606633
# 106       0.832566                0.806461                  0.889874
# 117       0.671937                1.000000                  0.000000
# 128       0.678847                0.936119                  0.114068
# 139       0.595294                1.000000                  0.325490
# 150    1080.000000              742.000000                338.000000
# 161       0.234259                0.229111                  0.245562
# 172       0.400519                0.283209                  0.658046
# 183       0.068074                0.065696                  0.073296
# 194       0.873282                1.000000                  0.000000
# 205       0.400000                1.000000                  0.000000
#
#         SEX_dis  SEX_dis_correct  SEX_dis_incorrect    SEX_priv  \
# 7      0.712589         1.000000           0.000000    0.674772
# 18     0.813040         0.785674           0.880890    0.821177
# 29     0.510121         1.000000           0.000000    0.497653
# 40     0.589577         0.000000           1.000000    0.610294
# 51     0.114019         0.000000           1.000000    0.124352
# 62     0.093703         0.089918           0.103088    0.093851
# 73     0.121095         0.096489           0.182104    0.108669
# 84     0.827423         0.865950           0.731901    0.851079
# 95     0.633881         0.646083           0.603628    0.626185
# 106    0.830986         0.803192           0.899896    0.838880
# 117    0.673797         1.000000           0.000000    0.688312
# 128    0.703296         0.932742           0.134421    0.668777
# 139    0.609121         1.000000           0.337017    0.566176
# 150  842.000000       600.000000         242.000000  658.000000
# 161    0.222090         0.210000           0.252066    0.234043
# 172    0.386043         0.280743           0.647117    0.407734
# 183    0.068650         0.066334           0.074393    0.068556
# 194    0.885981         1.000000           0.000000    0.875648
# 205    0.410423         1.000000           0.000000    0.389706
#
#      SEX_priv_correct  SEX_priv_incorrect      overall
# 7            1.000000            0.000000     0.696000
# 18           0.797114            0.871104     0.816610
# 29           1.000000            0.000000     0.504348
# 40           0.000000            1.000000     0.599309
# 51           0.000000            1.000000     0.118350
# 62           0.090961            0.099846     0.093768
# 73           0.088488            0.150539     0.115644
# 84           0.880676            0.789673     0.837800
# 95           0.633571            0.610860     0.630505
# 106          0.814410            0.889649     0.834449
# 117          1.000000            0.000000     0.680352
# 128          0.940270            0.105491     0.688153
# 139          1.000000            0.289157     0.588946
# 150        444.000000          214.000000  1500.000000
# 161          0.238739            0.224299     0.227333
# 172          0.285958            0.660390     0.395558
# 183          0.066504            0.072813     0.068609
# 194          1.000000            0.000000     0.881650
# 205          1.000000            0.000000     0.400691
#
# [19 rows x 34 columns]

# %%
exp_group_metrics_dct['RandomForestClassifier']['Exp_iter_1'][0.9].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR  0.034070 -0.044951   0.019817
# 1             Equalized_Odds_FPR  0.010653 -0.008294  -0.016398
# 2             Equalized_Odds_FNR -0.034070  0.044951  -0.019817
# 3               Disparate_Impact  1.157771  0.917968   1.027349
# 4  Statistical_Parity_Difference  0.094546 -0.055398   0.017632
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.9
# 1  RandomForestClassifier           Exp_iter_1                 0.9
# 2  RandomForestClassifier           Exp_iter_1                 0.9
# 3  RandomForestClassifier           Exp_iter_1                 0.9
# 4  RandomForestClassifier           Exp_iter_1                 0.9

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = ExperimentsVisualizer(exp_subgroup_metrics_dct=exp_subgroup_metrics_dct,
                                   exp_group_metrics_dct=exp_group_metrics_dct,
                                   dataset_name=DATASET_NAME,
                                   model_names=MODEL_NAMES,
                                   sensitive_attrs=SENSITIVE_ATTRS)

# %%
visualizer.melted_all_group_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                            Metric              Model_Name  \
# 0              Equalized_Odds_TPR  RandomForestClassifier
# 1              Equalized_Odds_FPR  RandomForestClassifier
# 2              Equalized_Odds_FNR  RandomForestClassifier
# 3                Disparate_Impact  RandomForestClassifier
# 4   Statistical_Parity_Difference  RandomForestClassifier
# 5                 Accuracy_Parity  RandomForestClassifier
# 6           Label_Stability_Ratio  RandomForestClassifier
# 7                      IQR_Parity  RandomForestClassifier
# 8                      Std_Parity  RandomForestClassifier
# 9                       Std_Ratio  RandomForestClassifier
# 10                  Jitter_Parity  RandomForestClassifier
# 11             Equalized_Odds_TPR  RandomForestClassifier
# 12             Equalized_Odds_FPR  RandomForestClassifier
# 13             Equalized_Odds_FNR  RandomForestClassifier
# 14               Disparate_Impact  RandomForestClassifier
# 15  Statistical_Parity_Difference  RandomForestClassifier
# 16                Accuracy_Parity  RandomForestClassifier
# 17          Label_Stability_Ratio  RandomForestClassifier
# 18                     IQR_Parity  RandomForestClassifier
# 19                     Std_Parity  RandomForestClassifier
#
#    Experiment_Iteration  Intervention_Param  Group  Metric_Value
# 0            Exp_iter_1                 0.7    SEX      0.039004
# 1            Exp_iter_1                 0.7    SEX      0.000160
# 2            Exp_iter_1                 0.7    SEX     -0.039004
# 3            Exp_iter_1                 0.7    SEX      1.138333
# 4            Exp_iter_1                 0.7    SEX      0.080355
# 5            Exp_iter_1                 0.7    SEX      0.037153
# 6            Exp_iter_1                 0.7    SEX      0.983267
# 7            Exp_iter_1                 0.7    SEX      0.000266
# 8            Exp_iter_1                 0.7    SEX      0.000420
# 9            Exp_iter_1                 0.7    SEX      1.005721
# 10           Exp_iter_1                 0.7    SEX      0.007052
# 11           Exp_iter_1                 0.7  RAC1P     -0.043034
# 12           Exp_iter_1                 0.7  RAC1P     -0.018012
# 13           Exp_iter_1                 0.7  RAC1P      0.043034
# 14           Exp_iter_1                 0.7  RAC1P      0.894596
# 15           Exp_iter_1                 0.7  RAC1P     -0.069128
# 16           Exp_iter_1                 0.7  RAC1P     -0.004175
# 17           Exp_iter_1                 0.7  RAC1P      0.986856
# 18           Exp_iter_1                 0.7  RAC1P      0.006104
# 19           Exp_iter_1                 0.7  RAC1P      0.004179

# %% [markdown]
# ### Line band plots for subgroup metrics

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Accuracy', 'F1', 'FNR', 'Jitter', 'Label_Stability', 'FPR'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'])
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_correct')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_subgroup_metrics_line_band_plot(model_name=MODEL_NAMES[0],
                                                  subgroup_metrics=['Aleatoric_Uncertainty', 'Overall_Uncertainty'],
                                                  subgroup='RAC1P_dis_incorrect')
# Out:
# alt.VConcatChart(...)

# %%
visualizer.create_line_bands_per_group_metric_plot(model_name=MODEL_NAMES[0],
                                                   group_metric='Overall_Uncertainty',
                                                   group='RAC1P',
                                                   metric_type='subgroup')
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Line band plots for group metrics

# %%
visualizer.create_group_metrics_line_band_plot(group='RAC1P',
                                               model_name=MODEL_NAMES[0],
                                               group_metrics=['Equalized_Odds_FPR', 'Equalized_Odds_FNR', 'Label_Stability_Ratio',
                                                              'Jitter_Parity', 'Disparate_Impact'])
# Out:
# alt.VConcatChart(...)
