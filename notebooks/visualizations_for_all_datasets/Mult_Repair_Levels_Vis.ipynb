# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code

# %% [markdown]
# # Visualizations

# %%
from source.custom_classes.datasets_experiments_visualizer import DatasetsExperimentsVisualizer
from source.utils.data_vis_utils import create_ext_subgroup_and_group_metrics_dicts_for_datasets

# %% [markdown]
# ## Initialize Configs

# %%
DATASET_NAMES = ['Folktables_GA_2018_Income', 'Law_School', 'Folktables_CA_2018_Public_Coverage', 'Ricci']
MODEL_NAMES = ['RandomForestClassifier']
DATASETS_DB_CONFIG = {
    'Folktables_GA_2018_Income': {
        'db_collection_name': 'exp_mult_repair_levels',
        'experiment_session_uuid': '26beff01-939d-4d98-be67-65b150b352b2',
        'sensitive_attrs': ['SEX', 'RAC1P', 'SEX&RAC1P'],
    },
    'Law_School': {
        'db_collection_name': 'exp_mult_repair_levels',
        'experiment_session_uuid': '9430484b-bec6-42a0-ac65-11c53446a61f',
        'sensitive_attrs': ['male', 'race', 'male&race'],
    },
    'Folktables_CA_2018_Public_Coverage': {
        'db_collection_name': 'exp_mult_repair_levels',
        'experiment_session_uuid': '116104d6-7d63-4564-ae57-82b19b260fa5',
        'sensitive_attrs': ['SEX', 'RAC1P', 'SEX&RAC1P'],
    },
    'Ricci': {
        'db_collection_name': 'exp_mult_repair_levels',
        'experiment_session_uuid': '6d916473-4d0f-4247-9638-b4f140ec4b28',
        'sensitive_attrs': ['Race'],
    },
}
DATASETS_SENSITIVE_ATTRS = {
    'Folktables_GA_2018_Income': ['SEX', 'RAC1P', 'SEX&RAC1P'],
    'Law_School': ['male', 'race', 'male&race'],
    'Folktables_CA_2018_Public_Coverage': ['SEX', 'RAC1P', 'SEX&RAC1P'],
    'Ricci': ['Race'],
}

# %% [markdown]
# ## Group Metrics Composition

# %%
datasets_exp_metrics_dct = create_ext_subgroup_and_group_metrics_dicts_for_datasets(DATASETS_DB_CONFIG, DATASET_NAMES)

# %%
datasets_exp_metrics_dct[DATASET_NAMES[0]]['subgroup_metrics']['RandomForestClassifier']['Exp_iter_1'][0.3].head(20)
# Out:
#                      Metric  Bootstrap_Model_Seed              Model_Name  \
# 2                  Accuracy                   101  RandomForestClassifier
# 68    Aleatoric_Uncertainty                   101  RandomForestClassifier
# 134                      F1                   101  RandomForestClassifier
# 200                     FNR                   101  RandomForestClassifier
# 266                     FPR                   101  RandomForestClassifier
# 332                     IQR                   101  RandomForestClassifier
# 398                  Jitter                   101  RandomForestClassifier
# 464         Label_Stability                   101  RandomForestClassifier
# 530                    Mean                   101  RandomForestClassifier
# 596     Overall_Uncertainty                   101  RandomForestClassifier
# 662                     PPV                   101  RandomForestClassifier
# 728     Per_Sample_Accuracy                   101  RandomForestClassifier
# 794           Positive-Rate                   101  RandomForestClassifier
# 860             Sample_Size                   101  RandomForestClassifier
# 926          Selection-Rate                   101  RandomForestClassifier
# 992                     Std                   101  RandomForestClassifier
# 1058                    TNR                   101  RandomForestClassifier
# 1124                    TPR                   101  RandomForestClassifier
#
#                                            Model_Params Run_Number  \
# 2     {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 68    {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 134   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 200   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 266   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 332   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 398   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 464   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 530   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 596   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 662   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 728   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 794   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 860   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 926   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 992   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1058  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1124  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
#
#                    Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 2     Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 68    Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 134   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 200   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 266   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 332   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 398   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 464   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 530   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 596   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 662   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 728   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 794   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 860   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 926   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 992   Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 1058  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
# 1124  Folktables_GA_2018_Income             200  OK 2023-07-23 04:44:13.113
#
#                               Session_Uuid  ... SEX&RAC1P_priv  \
# 2     26beff01-939d-4d98-be67-65b150b352b2  ...       0.812399
# 68    26beff01-939d-4d98-be67-65b150b352b2  ...       0.632524
# 134   26beff01-939d-4d98-be67-65b150b352b2  ...       0.722288
# 200   26beff01-939d-4d98-be67-65b150b352b2  ...       0.345572
# 266   26beff01-939d-4d98-be67-65b150b352b2  ...       0.093710
# 332   26beff01-939d-4d98-be67-65b150b352b2  ...       0.081742
# 398   26beff01-939d-4d98-be67-65b150b352b2  ...       0.072563
# 464   26beff01-939d-4d98-be67-65b150b352b2  ...       0.898382
# 530   26beff01-939d-4d98-be67-65b150b352b2  ...       0.647063
# 596   26beff01-939d-4d98-be67-65b150b352b2  ...       0.650657
# 662   26beff01-939d-4d98-be67-65b150b352b2  ...       0.805851
# 728   26beff01-939d-4d98-be67-65b150b352b2  ...       0.804771
# 794   26beff01-939d-4d98-be67-65b150b352b2  ...       0.812095
# 860   26beff01-939d-4d98-be67-65b150b352b2  ...    1242.000000
# 926   26beff01-939d-4d98-be67-65b150b352b2  ...       0.302738
# 992   26beff01-939d-4d98-be67-65b150b352b2  ...       0.058517
# 1058  26beff01-939d-4d98-be67-65b150b352b2  ...       0.906290
# 1124  26beff01-939d-4d98-be67-65b150b352b2  ...       0.654428
#
#       SEX&RAC1P_priv_correct  SEX&RAC1P_priv_incorrect     SEX_dis  \
# 2                   1.000000                  0.000000    0.840278
# 68                  0.583198                  0.846131    0.611247
# 134                 1.000000                  0.000000    0.696570
# 200                 0.000000                  1.000000    0.356098
# 266                 0.000000                  1.000000    0.081553
# 332                 0.074670                  0.112367    0.080130
# 398                 0.052503                  0.159431    0.071075
# 464                 0.927820                  0.770901    0.896931
# 530                 0.664443                  0.571801    0.698450
# 596                 0.599997                  0.870037    0.629214
# 662                 1.000000                  0.000000    0.758621
# 728                 0.963791                  0.116137    0.830021
# 794                 1.000000                  0.456250    0.848780
# 860              1009.000000                233.000000  720.000000
# 926                 0.300297                  0.313305    0.241667
# 992                 0.053603                  0.079801    0.056951
# 1058                1.000000                  0.000000    0.918447
# 1124                1.000000                  0.000000    0.643902
#
#       SEX_dis_correct  SEX_dis_incorrect    SEX_priv  SEX_priv_correct  \
# 2            1.000000           0.000000    0.797436          1.000000
# 68           0.570675           0.824690    0.634553          0.580480
# 134          1.000000           0.000000    0.724739          1.000000
# 200          0.000000           1.000000    0.350000          0.000000
# 266          0.000000           1.000000    0.100000          0.000000
# 332          0.073578           0.114598    0.081635          0.074689
# 398          0.051777           0.172597    0.072975          0.053895
# 464          0.926281           0.742522    0.899090          0.926206
# 530          0.724855           0.559538    0.629470          0.641977
# 596          0.587301           0.849717    0.652630          0.597396
# 662          1.000000           0.000000    0.818898          1.000000
# 728          0.962793           0.131522    0.789147          0.963103
# 794          1.000000           0.575342    0.793750          1.000000
# 860        605.000000         115.000000  780.000000        622.000000
# 926          0.218182           0.365217    0.325641          0.334405
# 992          0.052547           0.080119    0.058488          0.053488
# 1058         1.000000           0.000000    0.900000          1.000000
# 1124         1.000000           0.000000    0.650000          1.000000
#
#       SEX_priv_incorrect      overall
# 2               0.000000     0.818000
# 68              0.847421     0.623366
# 134             0.000000     0.713536
# 200             1.000000     0.352381
# 266             1.000000     0.090256
# 332             0.108983     0.080913
# 398             0.148088     0.072063
# 464             0.792342     0.898053
# 530             0.580233     0.662580
# 596             0.870067     0.641390
# 662             0.000000     0.794393
# 728             0.104335     0.808767
# 794             0.410714     0.815238
# 860           158.000000  1500.000000
# 926             0.291139     0.285333
# 992             0.078175     0.057750
# 1058            0.000000     0.909744
# 1124            0.000000     0.647619
#
# [18 rows x 34 columns]

# %%
datasets_exp_metrics_dct[DATASET_NAMES[0]]['group_metrics']['RandomForestClassifier']['Exp_iter_1'][0.9].head()
# Out:
#                           Metric       SEX     RAC1P  SEX&RAC1P  \
# 0             Equalized_Odds_TPR -0.016387  0.077789   0.007141
# 1             Equalized_Odds_FPR -0.011228  0.004746   0.000760
# 2             Equalized_Odds_FNR  0.016387 -0.077789  -0.007141
# 3               Disparate_Impact  1.067680  1.262328   1.177947
# 4  Statistical_Parity_Difference  0.048857  0.182431   0.129137
#
#                Model_Name Experiment_Iteration  Intervention_Param
# 0  RandomForestClassifier           Exp_iter_1                 0.9
# 1  RandomForestClassifier           Exp_iter_1                 0.9
# 2  RandomForestClassifier           Exp_iter_1                 0.9
# 3  RandomForestClassifier           Exp_iter_1                 0.9
# 4  RandomForestClassifier           Exp_iter_1                 0.9

# %% [markdown]
# ## Metrics Visualization and Reporting

# %%
visualizer = DatasetsExperimentsVisualizer(datasets_exp_metrics_dct=datasets_exp_metrics_dct,
                                           dataset_names=DATASET_NAMES,
                                           model_names=MODEL_NAMES,
                                           datasets_sensitive_attrs=DATASETS_SENSITIVE_ATTRS)

# %%
visualizer.melted_all_datasets_subgroup_metrics_per_model_dct[MODEL_NAMES[0]].head(20)
# Out:
#                    Metric  Bootstrap_Model_Seed              Model_Name  \
# 0                Accuracy                   101  RandomForestClassifier
# 1   Aleatoric_Uncertainty                   101  RandomForestClassifier
# 2                      F1                   101  RandomForestClassifier
# 3                     FNR                   101  RandomForestClassifier
# 4                     FPR                   101  RandomForestClassifier
# 5                     IQR                   101  RandomForestClassifier
# 6                  Jitter                   101  RandomForestClassifier
# 7         Label_Stability                   101  RandomForestClassifier
# 8                    Mean                   101  RandomForestClassifier
# 9     Overall_Uncertainty                   101  RandomForestClassifier
# 10                    PPV                   101  RandomForestClassifier
# 11    Per_Sample_Accuracy                   101  RandomForestClassifier
# 12          Positive-Rate                   101  RandomForestClassifier
# 13            Sample_Size                   101  RandomForestClassifier
# 14         Selection-Rate                   101  RandomForestClassifier
# 15                    Std                   101  RandomForestClassifier
# 16                    TNR                   101  RandomForestClassifier
# 17                    TPR                   101  RandomForestClassifier
# 18               Accuracy                   101  RandomForestClassifier
# 19  Aleatoric_Uncertainty                   101  RandomForestClassifier
#
#                                          Model_Params Run_Number  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 4   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 5   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 6   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 7   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 8   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 9   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 10  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 15  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 16  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 17  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 18  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
# 19  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...      Run_1
#
#                  Dataset_Name  Num_Estimators Tag Record_Create_Date_Time  \
# 0   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 1   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 2   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 3   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 4   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 5   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 6   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 7   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 8   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 9   Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 10  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 11  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 12  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 13  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 14  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 15  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 16  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 17  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 18  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
# 19  Folktables_GA_2018_Income             200  OK 2023-07-23 03:44:07.959
#
#                             Session_Uuid Experiment_Iteration  \
# 0   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 1   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 2   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 3   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 4   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 5   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 6   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 7   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 8   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 9   26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 10  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 11  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 12  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 13  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 14  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 15  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 16  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 17  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 18  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
# 19  26beff01-939d-4d98-be67-65b150b352b2           Exp_iter_1
#
#     Dataset_Split_Seed  Model_Init_Seed Fair_Intervention_Params_Lst  \
# 0                  100              100         [0.0, 0.1, 0.2, 0.3]
# 1                  100              100         [0.0, 0.1, 0.2, 0.3]
# 2                  100              100         [0.0, 0.1, 0.2, 0.3]
# 3                  100              100         [0.0, 0.1, 0.2, 0.3]
# 4                  100              100         [0.0, 0.1, 0.2, 0.3]
# 5                  100              100         [0.0, 0.1, 0.2, 0.3]
# 6                  100              100         [0.0, 0.1, 0.2, 0.3]
# 7                  100              100         [0.0, 0.1, 0.2, 0.3]
# 8                  100              100         [0.0, 0.1, 0.2, 0.3]
# 9                  100              100         [0.0, 0.1, 0.2, 0.3]
# 10                 100              100         [0.0, 0.1, 0.2, 0.3]
# 11                 100              100         [0.0, 0.1, 0.2, 0.3]
# 12                 100              100         [0.0, 0.1, 0.2, 0.3]
# 13                 100              100         [0.0, 0.1, 0.2, 0.3]
# 14                 100              100         [0.0, 0.1, 0.2, 0.3]
# 15                 100              100         [0.0, 0.1, 0.2, 0.3]
# 16                 100              100         [0.0, 0.1, 0.2, 0.3]
# 17                 100              100         [0.0, 0.1, 0.2, 0.3]
# 18                 100              100         [0.0, 0.1, 0.2, 0.3]
# 19                 100              100         [0.0, 0.1, 0.2, 0.3]
#
#     Intervention_Param           Subgroup  Metric_Value
# 0                  0.2          RAC1P_dis      0.846311
# 1                  0.2          RAC1P_dis      0.584862
# 2                  0.2          RAC1P_dis      0.693878
# 3                  0.2          RAC1P_dis      0.351145
# 4                  0.2          RAC1P_dis      0.081232
# 5                  0.2          RAC1P_dis      0.072855
# 6                  0.2          RAC1P_dis      0.057996
# 7                  0.2          RAC1P_dis      0.919303
# 8                  0.2          RAC1P_dis      0.705945
# 9                  0.2          RAC1P_dis      0.600592
# 10                 0.2          RAC1P_dis      0.745614
# 11                 0.2          RAC1P_dis      0.838340
# 12                 0.2          RAC1P_dis      0.870229
# 13                 0.2          RAC1P_dis    488.000000
# 14                 0.2          RAC1P_dis      0.233607
# 15                 0.2          RAC1P_dis      0.051327
# 16                 0.2          RAC1P_dis      0.918768
# 17                 0.2          RAC1P_dis      0.648855
# 18                 0.2  RAC1P_dis_correct      1.000000
# 19                 0.2  RAC1P_dis_correct      0.543753

# %% [markdown]
# ### Group Specific Metrics

# %%
visualizer.create_group_metric_line_bands_per_dataset_plot(model_name=MODEL_NAMES[0],
                                                           metric_type='subgroup',
                                                           metric_name='Accuracy',
                                                           dataset_groups_dct={
                                                               'Folktables_GA_2018_Income': 'overall',
                                                               'Law_School': 'overall',
                                                               'Folktables_CA_2018_Public_Coverage': 'overall',
                                                               'Ricci': 'overall',
                                                           })
# Out:
# alt.LayerChart(...)

# %%
visualizer.create_group_metric_line_bands_per_dataset_plot(model_name=MODEL_NAMES[0],
                                                           metric_type='subgroup',
                                                           metric_name='Label_Stability',
                                                           dataset_groups_dct={
                                                               'Folktables_GA_2018_Income': 'overall',
                                                               'Law_School': 'overall',
                                                               'Folktables_CA_2018_Public_Coverage': 'overall',
                                                               'Ricci': 'overall',
                                                           })
# Out:
# alt.LayerChart(...)

# %%
visualizer.create_group_metric_line_bands_per_dataset_plot(model_name=MODEL_NAMES[0],
                                                           metric_type='subgroup',
                                                           metric_name='Overall_Uncertainty',
                                                           dataset_groups_dct={
                                                               'Folktables_GA_2018_Income': 'RAC1P_dis_correct',
                                                               'Law_School': 'race_dis_correct',
                                                               'Folktables_CA_2018_Public_Coverage': 'RAC1P_dis_correct',
                                                               'Ricci': 'Race_dis_correct',
                                                           })
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
visualizer.create_group_metric_line_bands_per_dataset_plot(model_name=MODEL_NAMES[0],
                                                           metric_type='group',
                                                           metric_name='Equalized_Odds_FPR',
                                                           dataset_groups_dct={
                                                               'Folktables_GA_2018_Income': 'RAC1P',
                                                               'Law_School': 'race',
                                                               'Folktables_CA_2018_Public_Coverage': 'RAC1P',
                                                               'Ricci': 'Race',
                                                           })
# Out:
# alt.LayerChart(...)

# %%
visualizer.create_group_metric_line_bands_per_dataset_plot(model_name=MODEL_NAMES[0],
                                                           metric_type='group',
                                                           metric_name='Std_Parity',
                                                           dataset_groups_dct={
                                                               'Folktables_GA_2018_Income': 'RAC1P',
                                                               'Law_School': 'race',
                                                               'Folktables_CA_2018_Public_Coverage': 'RAC1P',
                                                               'Ricci': 'Race',
                                                           })
# Out:
# alt.LayerChart(...)
