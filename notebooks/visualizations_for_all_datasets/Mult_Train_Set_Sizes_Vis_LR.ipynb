# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from source.uncertainty_visualizations import (create_exp_metrics_dicts_for_mult_train_set_sizes,
                                               create_group_metric_line_bands_per_dataset_plot)
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'

# %% [markdown]
# ## Initialize Configs

# %%
MODEL_NAMES = ['LogisticRegression']
EXPERIMENT_NAMES = ['rich_experiment', 'poor_experiment']
DB_COLLECTION_NAME = 'out_of_domain_uncertainty'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
SENSITIVE_ATTR_FOR_DISPARITY_METRICS = 'SEX&RAC1P'
DATASETS_DB_CONFIG = {
    'rich_experiment': {
        2_000: 'd2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024',
        5_000: '0d076c58-648a-4259-963a-97fb6ad00917',
        10_000: 'ef323312-150b-4ae3-a96d-a3314ae6525f',
        30_000: '42b1bd0f-6dbe-479d-906f-902f13ce7049',
        50_000: 'c4fbebec-73df-440a-8cb1-6887b4329a73',
        70_000: '20a516c0-8105-40e7-aae1-7ee97a2dea68',
        90_000: '6349084e-1fca-4441-9901-bd4c4d360e14',
    },
    'poor_experiment': {
        2_000: 'a5c86454-358c-4d32-95f8-fa5e1f8033af',
        5_000: '42346f8e-d48e-43c0-b410-6a70903c4480',
        10_000: '6052b92f-f6ef-4711-a04c-eb9dd49e06bb',
        30_000: '223090a3-0104-489f-8050-92a22bfbd1f6',
        50_000: 'b8ad0a86-280d-46fb-8746-d55be289381c',
        70_000: '97512376-2490-421c-a1ca-bbdeb46c82b9',
        90_000: 'cc201523-93eb-4e2e-84f9-eec31ffe0d0a',
    },
}

# %% [markdown]
# ## Group Metrics Composition

# %%
metrics_per_exp_dct = create_exp_metrics_dicts_for_mult_train_set_sizes(DATASETS_DB_CONFIG, EXPERIMENT_NAMES,
                                                                        DB_COLLECTION_NAME, SENSITIVE_ATTRS)
# Out:
# Extracted metrics for rich_experiment and 2000 train set size
# Extracted metrics for rich_experiment and 5000 train set size
# Extracted metrics for rich_experiment and 10000 train set size
# Extracted metrics for rich_experiment and 30000 train set size
# Extracted metrics for rich_experiment and 50000 train set size
# Extracted metrics for rich_experiment and 70000 train set size
# Extracted metrics for rich_experiment and 90000 train set size
#
# Extracted metrics for poor_experiment and 2000 train set size
# Extracted metrics for poor_experiment and 5000 train set size
# Extracted metrics for poor_experiment and 10000 train set size
# Extracted metrics for poor_experiment and 30000 train set size
# Extracted metrics for poor_experiment and 50000 train set size
# Extracted metrics for poor_experiment and 70000 train set size
# Extracted metrics for poor_experiment and 90000 train set size

# %%
metrics_per_exp_dct[EXPERIMENT_NAMES[0]]['subgroup_metrics'].head(20)
# Out:
#                    Metric          Model_Name  \
# 0                Accuracy  LogisticRegression
# 1   Aleatoric_Uncertainty  LogisticRegression
# 2                      F1  LogisticRegression
# 3                     FNR  LogisticRegression
# 4                     FPR  LogisticRegression
# 5                     IQR  LogisticRegression
# 6                  Jitter  LogisticRegression
# 7         Label_Stability  LogisticRegression
# 8                    Mean  LogisticRegression
# 9     Overall_Uncertainty  LogisticRegression
# 10                    PPV  LogisticRegression
# 11    Per_Sample_Accuracy  LogisticRegression
# 12          Positive-Rate  LogisticRegression
# 13         Selection-Rate  LogisticRegression
# 14       Statistical_Bias  LogisticRegression
# 15                    Std  LogisticRegression
# 16                    TNR  LogisticRegression
# 17                    TPR  LogisticRegression
# 18               Accuracy  LogisticRegression
# 19  Aleatoric_Uncertainty  LogisticRegression
#
#                                          Model_Params            Dataset_Name  \
# 0   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 1   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 2   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 3   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 4   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 5   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 6   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 7   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 8   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 9   {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 10  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 11  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 12  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 13  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 14  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 15  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 16  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 17  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 18  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
# 19  {'C': 1, 'class_weight': None, 'dual': False, ...  Folktables_2018_Income
#
#     Num_Estimators  Test_Set_Index Tag Record_Create_Date_Time  \
# 0              200               0  OK 2023-11-13 23:37:33.230
# 1              200               0  OK 2023-11-13 23:37:33.230
# 2              200               0  OK 2023-11-13 23:37:33.230
# 3              200               0  OK 2023-11-13 23:37:33.230
# 4              200               0  OK 2023-11-13 23:37:33.230
# 5              200               0  OK 2023-11-13 23:37:33.230
# 6              200               0  OK 2023-11-13 23:37:33.230
# 7              200               0  OK 2023-11-13 23:37:33.230
# 8              200               0  OK 2023-11-13 23:37:33.230
# 9              200               0  OK 2023-11-13 23:37:33.230
# 10             200               0  OK 2023-11-13 23:37:33.230
# 11             200               0  OK 2023-11-13 23:37:33.230
# 12             200               0  OK 2023-11-13 23:37:33.230
# 13             200               0  OK 2023-11-13 23:37:33.230
# 14             200               0  OK 2023-11-13 23:37:33.230
# 15             200               0  OK 2023-11-13 23:37:33.230
# 16             200               0  OK 2023-11-13 23:37:33.230
# 17             200               0  OK 2023-11-13 23:37:33.230
# 18             200               0  OK 2023-11-13 23:37:33.230
# 19             200               0  OK 2023-11-13 23:37:33.230
#
#                             Session_Uuid Experiment_Iteration  \
# 0   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 1   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 2   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 3   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 4   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 5   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 6   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 7   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 8   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 9   d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 10  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 11  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 12  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 13  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 14  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 15  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 16  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 17  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 18  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
# 19  d2d0e1d6-cb8a-4f6a-8adf-7d6bc25a7024           Exp_iter_1
#
#     Dataset_Split_Seed  Model_Init_Seed Fair_Intervention_Params_Lst  \
# 0                  100              100                        [0.7]
# 1                  100              100                        [0.7]
# 2                  100              100                        [0.7]
# 3                  100              100                        [0.7]
# 4                  100              100                        [0.7]
# 5                  100              100                        [0.7]
# 6                  100              100                        [0.7]
# 7                  100              100                        [0.7]
# 8                  100              100                        [0.7]
# 9                  100              100                        [0.7]
# 10                 100              100                        [0.7]
# 11                 100              100                        [0.7]
# 12                 100              100                        [0.7]
# 13                 100              100                        [0.7]
# 14                 100              100                        [0.7]
# 15                 100              100                        [0.7]
# 16                 100              100                        [0.7]
# 17                 100              100                        [0.7]
# 18                 100              100                        [0.7]
# 19                 100              100                        [0.7]
#
#     Intervention_Param           Subgroup  Metric_Value  Train_Set_Size
# 0                  0.7          RAC1P_dis      0.802219            2000
# 1                  0.7          RAC1P_dis      0.604532            2000
# 2                  0.7          RAC1P_dis      0.753457            2000
# 3                  0.7          RAC1P_dis      0.202020            2000
# 4                  0.7          RAC1P_dis      0.195197            2000
# 5                  0.7          RAC1P_dis      0.099109            2000
# 6                  0.7          RAC1P_dis      0.093583            2000
# 7                  0.7          RAC1P_dis      0.868673            2000
# 8                  0.7          RAC1P_dis      0.570943            2000
# 9                  0.7          RAC1P_dis      0.633260            2000
# 10                 0.7          RAC1P_dis      0.713640            2000
# 11                 0.7          RAC1P_dis      0.788441            2000
# 12                 0.7          RAC1P_dis      1.118182            2000
# 13                 0.7          RAC1P_dis      0.423489            2000
# 14                 0.7          RAC1P_dis      0.284812            2000
# 15                 0.7          RAC1P_dis      0.073408            2000
# 16                 0.7          RAC1P_dis      0.804803            2000
# 17                 0.7          RAC1P_dis      0.797980            2000
# 18                 0.7  RAC1P_dis_correct      1.000000            2000
# 19                 0.7  RAC1P_dis_correct      0.560909            2000

# %%
metrics_per_exp_dct[EXPERIMENT_NAMES[0]]['group_metrics'].head()
# Out:
#                          Metric          Model_Name Experiment_Iteration  \
# 0               Accuracy_Parity  LogisticRegression           Exp_iter_1
# 1  Aleatoric_Uncertainty_Parity  LogisticRegression           Exp_iter_1
# 2   Aleatoric_Uncertainty_Ratio  LogisticRegression           Exp_iter_1
# 3            Equalized_Odds_FNR  LogisticRegression           Exp_iter_1
# 4            Equalized_Odds_FPR  LogisticRegression           Exp_iter_1
#
#    Intervention_Param  Test_Set_Index Group  Metric_Value  Train_Set_Size
# 0                 0.7               0   SEX     -0.007952            2000
# 1                 0.7               0   SEX      0.020299            2000
# 2                 0.7               0   SEX      1.033078            2000
# 3                 0.7               0   SEX     -0.011183            2000
# 4                 0.7               0   SEX      0.011724            2000

# %% [markdown]
# ## Metrics Visualization and Reporting

# %% [markdown]
# ### Group Metrics

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Accuracy',
                                                group_name='overall',
                                                ylim=[0.7, 0.83],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
# create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
#                                                 experiment_names=EXPERIMENT_NAMES,
#                                                 model_name=MODEL_NAMES[0],
#                                                 metric_type='subgroup',
#                                                 metric_name='F1',
#                                                 group_name='overall',
#                                                 ylim=[0.48, 0.82],
#                                                 with_band=True)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Std',
                                                group_name='overall',
                                                ylim=[0.02, 0.09],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Label_Stability',
                                                group_name='overall',
                                                ylim=[0.82, 0.97],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Aleatoric_Uncertainty',
                                                group_name='overall',
                                                ylim=[0.56, 0.70],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
# create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
#                                                 experiment_names=EXPERIMENT_NAMES,
#                                                 model_name=MODEL_NAMES[0],
#                                                 metric_type='subgroup',
#                                                 metric_name='Overall_Uncertainty',
#                                                 group_name='overall',
#                                                 ylim=[0.58, 0.70],
#                                                 with_band=True)

# %%
# create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
#                                                 experiment_names=EXPERIMENT_NAMES,
#                                                 model_name=MODEL_NAMES[0],
#                                                 metric_type='subgroup',
#                                                 metric_name='Epistemic_Uncertainty',
#                                                 group_name='overall',
#                                                 ylim=[0.0, 0.035],
#                                                 with_band=True)

# %%
# create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
#                                                 experiment_names=EXPERIMENT_NAMES,
#                                                 model_name=MODEL_NAMES[0],
#                                                 metric_type='subgroup',
#                                                 metric_name='Other_Uncertainty',
#                                                 group_name='overall',
#                                                 with_band=True)

# %% [markdown]
# ### Disparity Metrics

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Equalized_Odds_FNR',
                                                group_name=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                ylim=[-0.06, 0.14],
                                                with_band=False)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Equalized_Odds_FPR',
                                                group_name=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                ylim=[-0.1, 0.02],
                                                with_band=False)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Label_Stability_Difference',
                                                group_name=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                ylim=[-0.005, 0.06],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
# create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
#                                                 experiment_names=EXPERIMENT_NAMES,
#                                                 model_name=MODEL_NAMES[0],
#                                                 metric_type='group',
#                                                 metric_name='Label_Stability_Ratio',
#                                                 group_name=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
#                                                 ylim=[0.98, 1.08],
#                                                 with_band=False)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Aleatoric_Uncertainty_Parity',
                                                group_name=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                ylim=[-0.14, -0.015],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Std_Parity',
                                                group_name=SENSITIVE_ATTR_FOR_DISPARITY_METRICS,
                                                ylim=[-0.015, 0.003],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)
