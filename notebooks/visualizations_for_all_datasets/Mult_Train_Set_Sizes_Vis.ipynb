# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code

# %% [markdown]
# # Visualizations

# %%
from source.uncertainty_visualizations import (create_exp_metrics_dicts_for_mult_train_set_sizes,
                                               create_group_metric_line_bands_per_dataset_plot)
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'
# WARNING:root:No module named 'tensorflow': AdversarialDebiasing will be unavailable. To install, run:
# pip install 'aif360[AdversarialDebiasing]'

# %% [markdown]
# ## Initialize Configs

# %%
MODEL_NAMES = ['RandomForestClassifier']
EXPERIMENT_NAMES = ['rich_experiment', 'poor_experiment']
DB_COLLECTION_NAME = 'out_of_domain_uncertainty'
SENSITIVE_ATTRS = ['SEX', 'RAC1P', 'SEX&RAC1P']
DATASETS_DB_CONFIG = {
    'rich_experiment': {
        10_000: '99df3a37-a84e-4824-bbe7-cc25fc0e4bd5',
        30_000: '980128a7-9cdb-486e-bf95-e2b9a391271c',
        50_000: '39efed81-cbcb-48cd-b630-11b65f876e59',
        70_000: 'cb7a0ccf-15e3-45c1-980a-71866f4038c7',
        90_000: '9af761cf-de63-4868-b8c1-75c7ee25103b',
    },
    'poor_experiment': {
        10_000: 'fa8d64fb-e05a-4ac3-aa28-f1c2bd01d261',
        30_000: 'aab78d05-9b80-4bb7-a30d-f0a8efec6a48',
        50_000: '24b32f8d-94f4-43da-8e78-5607101fbfae',
        70_000: '32f0c940-8892-4b94-8af3-7dbe2e795257',
        90_000: 'b74b8eef-38ac-4bb5-a970-96e8798f3122',
    },
}

# %% [markdown]
# ## Group Metrics Composition

# %%
metrics_per_exp_dct = create_exp_metrics_dicts_for_mult_train_set_sizes(DATASETS_DB_CONFIG, EXPERIMENT_NAMES,
                                                                        DB_COLLECTION_NAME, SENSITIVE_ATTRS)
# Out:
# Extracted metrics for rich_experiment and 10000 train set size
# Extracted metrics for rich_experiment and 30000 train set size
# Extracted metrics for rich_experiment and 50000 train set size
# Extracted metrics for rich_experiment and 70000 train set size
# Extracted metrics for rich_experiment and 90000 train set size
#
# Extracted metrics for poor_experiment and 10000 train set size
# Extracted metrics for poor_experiment and 30000 train set size
# Extracted metrics for poor_experiment and 50000 train set size
# Extracted metrics for poor_experiment and 70000 train set size
# Extracted metrics for poor_experiment and 90000 train set size

# %%
metrics_per_exp_dct[EXPERIMENT_NAMES[0]]['subgroup_metrics'].head(20)
# Out:
#                    Metric              Model_Name  \
# 0                Accuracy  RandomForestClassifier
# 1   Aleatoric_Uncertainty  RandomForestClassifier
# 2                      F1  RandomForestClassifier
# 3                     FNR  RandomForestClassifier
# 4                     FPR  RandomForestClassifier
# 5                     IQR  RandomForestClassifier
# 6                  Jitter  RandomForestClassifier
# 7         Label_Stability  RandomForestClassifier
# 8                    Mean  RandomForestClassifier
# 9     Overall_Uncertainty  RandomForestClassifier
# 10                    PPV  RandomForestClassifier
# 11    Per_Sample_Accuracy  RandomForestClassifier
# 12          Positive-Rate  RandomForestClassifier
# 13            Sample_Size  RandomForestClassifier
# 14         Selection-Rate  RandomForestClassifier
# 15       Statistical_Bias  RandomForestClassifier
# 16                    Std  RandomForestClassifier
# 17                    TNR  RandomForestClassifier
# 18                    TPR  RandomForestClassifier
# 19               Accuracy  RandomForestClassifier
#
#                                          Model_Params            Dataset_Name  \
# 0   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 1   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 2   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 3   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 4   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 5   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 6   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 7   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 8   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 9   {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 10  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 11  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 12  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 13  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 14  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 15  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 16  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 17  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 18  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
# 19  {'bootstrap': False, 'ccp_alpha': 0.0, 'class_...  Folktables_2018_Income
#
#     Num_Estimators  Test_Set_Index Tag Record_Create_Date_Time  \
# 0              200               0  OK 2023-10-22 23:30:28.593
# 1              200               0  OK 2023-10-22 23:30:28.593
# 2              200               0  OK 2023-10-22 23:30:28.593
# 3              200               0  OK 2023-10-22 23:30:28.593
# 4              200               0  OK 2023-10-22 23:30:28.593
# 5              200               0  OK 2023-10-22 23:30:28.593
# 6              200               0  OK 2023-10-22 23:30:28.593
# 7              200               0  OK 2023-10-22 23:30:28.593
# 8              200               0  OK 2023-10-22 23:30:28.593
# 9              200               0  OK 2023-10-22 23:30:28.593
# 10             200               0  OK 2023-10-22 23:30:28.593
# 11             200               0  OK 2023-10-22 23:30:28.593
# 12             200               0  OK 2023-10-22 23:30:28.593
# 13             200               0  OK 2023-10-22 23:30:28.593
# 14             200               0  OK 2023-10-22 23:30:28.593
# 15             200               0  OK 2023-10-22 23:30:28.593
# 16             200               0  OK 2023-10-22 23:30:28.593
# 17             200               0  OK 2023-10-22 23:30:28.593
# 18             200               0  OK 2023-10-22 23:30:28.593
# 19             200               0  OK 2023-10-22 23:30:28.593
#
#                             Session_Uuid Experiment_Iteration  \
# 0   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 1   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 2   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 3   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 4   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 5   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 6   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 7   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 8   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 9   99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 10  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 11  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 12  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 13  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 14  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 15  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 16  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 17  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 18  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
# 19  99df3a37-a84e-4824-bbe7-cc25fc0e4bd5           Exp_iter_1
#
#     Dataset_Split_Seed  Model_Init_Seed Fair_Intervention_Params_Lst  \
# 0                  100              100                        [0.0]
# 1                  100              100                        [0.0]
# 2                  100              100                        [0.0]
# 3                  100              100                        [0.0]
# 4                  100              100                        [0.0]
# 5                  100              100                        [0.0]
# 6                  100              100                        [0.0]
# 7                  100              100                        [0.0]
# 8                  100              100                        [0.0]
# 9                  100              100                        [0.0]
# 10                 100              100                        [0.0]
# 11                 100              100                        [0.0]
# 12                 100              100                        [0.0]
# 13                 100              100                        [0.0]
# 14                 100              100                        [0.0]
# 15                 100              100                        [0.0]
# 16                 100              100                        [0.0]
# 17                 100              100                        [0.0]
# 18                 100              100                        [0.0]
# 19                 100              100                        [0.0]
#
#     Intervention_Param           Subgroup  Metric_Value  Train_Set_Size
# 0                  0.0          RAC1P_dis      0.812548           10000
# 1                  0.0          RAC1P_dis      0.712247           10000
# 2                  0.0          RAC1P_dis      0.759568           10000
# 3                  0.0          RAC1P_dis      0.218182           10000
# 4                  0.0          RAC1P_dis      0.168719           10000
# 5                  0.0          RAC1P_dis      0.054644           10000
# 6                  0.0          RAC1P_dis      0.064760           10000
# 7                  0.0          RAC1P_dis      0.909185           10000
# 8                  0.0          RAC1P_dis      0.565983           10000
# 9                  0.0          RAC1P_dis      0.719916           10000
# 10                 0.0          RAC1P_dis      0.738550           10000
# 11                 0.0          RAC1P_dis      0.804616           10000
# 12                 0.0          RAC1P_dis      1.058586           10000
# 13                 0.0          RAC1P_dis   2614.000000           10000
# 14                 0.0          RAC1P_dis      0.400918           10000
# 15                 0.0          RAC1P_dis      0.304891           10000
# 16                 0.0          RAC1P_dis      0.040793           10000
# 17                 0.0          RAC1P_dis      0.831281           10000
# 18                 0.0          RAC1P_dis      0.781818           10000
# 19                 0.0  RAC1P_dis_correct      1.000000           10000

# %%
metrics_per_exp_dct[EXPERIMENT_NAMES[0]]['group_metrics'].head()
# Out:
#                          Metric              Model_Name Experiment_Iteration  \
# 0               Accuracy_Parity  RandomForestClassifier           Exp_iter_1
# 1  Aleatoric_Uncertainty_Parity  RandomForestClassifier           Exp_iter_1
# 2   Aleatoric_Uncertainty_Ratio  RandomForestClassifier           Exp_iter_1
# 3            Equalized_Odds_FNR  RandomForestClassifier           Exp_iter_1
# 4            Equalized_Odds_FPR  RandomForestClassifier           Exp_iter_1
#
#    Intervention_Param  Test_Set_Index Group  Metric_Value  Train_Set_Size
# 0                 0.0               0   SEX     -0.005675           10000
# 1                 0.0               0   SEX      0.012097           10000
# 2                 0.0               0   SEX      1.016541           10000
# 3                 0.0               0   SEX      0.020243           10000
# 4                 0.0               0   SEX     -0.003483           10000

# %%
df = metrics_per_exp_dct[EXPERIMENT_NAMES[0]]['group_metrics']
df[(df.Metric == 'Equalized_Odds_FPR') & (df.Experiment_Iteration == 'Exp_iter_1') & 
   (df.Group == 'RAC1P') & (df.Train_Set_Size == 70_000)]
# Out:
#                 Metric              Model_Name Experiment_Iteration  \
# 20  Equalized_Odds_FPR  RandomForestClassifier           Exp_iter_1
# 20  Equalized_Odds_FPR  RandomForestClassifier           Exp_iter_1
# 20  Equalized_Odds_FPR  RandomForestClassifier           Exp_iter_1
# 20  Equalized_Odds_FPR  RandomForestClassifier           Exp_iter_1
#
#     Intervention_Param  Test_Set_Index  Group  Metric_Value  Train_Set_Size
# 20                 0.0               0  RAC1P     -0.039228           70000
# 20                 0.0               1  RAC1P     -0.080411           70000
# 20                 0.7               0  RAC1P     -0.031342           70000
# 20                 0.7               1  RAC1P     -0.033085           70000

# %% [markdown]
# ## Metrics Visualization and Reporting

# %% [markdown]
# ### Group Metrics

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Accuracy',
                                                group_name='overall',
                                                ylim=[0.7, 0.83],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='F1',
                                                group_name='overall',
                                                ylim=[0.55, 0.82],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Std',
                                                group_name='overall',
                                                ylim=[0.03, 0.08],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Label_Stability',
                                                group_name='overall',
                                                ylim=[0.86, 0.93],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Aleatoric_Uncertainty',
                                                group_name='overall',
                                                ylim=[0.56, 0.78],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Overall_Uncertainty',
                                                group_name='overall',
                                                ylim=[0.58, 0.78],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='subgroup',
                                                metric_name='Epistemic_Uncertainty',
                                                group_name='overall',
                                                ylim=[0.0, 0.03],
                                                with_band=True)
# Out:
# alt.VConcatChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Equalized_Odds_FNR',
                                                group_name='RAC1P',
                                                ylim=[-0.06, 0.14],
                                                with_band=False)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Equalized_Odds_FPR',
                                                group_name='RAC1P',
                                                ylim=[-0.1, 0.04],
                                                with_band=False)
# Out:
# alt.VConcatChart(...)

# %%
create_group_metric_line_bands_per_dataset_plot(metrics_per_exp_dct=metrics_per_exp_dct,
                                                experiment_names=EXPERIMENT_NAMES,
                                                model_name=MODEL_NAMES[0],
                                                metric_type='group',
                                                metric_name='Label_Stability_Ratio',
                                                group_name='RAC1P',
                                                ylim=[1.0, 1.06],
                                                with_band=False)
# Out:
# alt.VConcatChart(...)
