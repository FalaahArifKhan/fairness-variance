# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import os
import warnings
warnings.filterwarnings('ignore')
os.environ["PYTHONWARNINGS"] = "ignore"

# %%
cur_folder_name = os.getcwd().split('/')[-1]
if cur_folder_name != "fairness-variance":
    os.chdir("../..")

print('Current location: ', os.getcwd())
# Out:
# Current location:  /Users/denys_herasymuk/UCU/4course_2term/Bachelor_Thesis/Code/fairness-variance

# %% [markdown]
# # Visualizations

# %%
from source.utils.data_vis_utils import read_metrics_for_diff_bootstrap_sizes
from source.uncertainty_visualizations import create_plot_for_diff_bootstrap_sizes, create_plot_for_diff_bootstrap_sizes_and_exp_run
# Out:
# WARNING:root:No module named 'tempeh': LawSchoolGPADataset will be unavailable. To install, run:
# pip install 'aif360[LawSchoolGPA]'

# %% [markdown]
# ## Initialize Configs

# %%
DB_COLLECTION_NAME = 'one_repair_lvl_many_models'
DATASETS_DB_CONFIG = {
    'Folktables_CA_2018_Income': {
        10: '0f6a39fe-817f-42a6-99d0-a0801d2722bf',
        50: 'f12c5c59-e58a-4f5a-bc5b-e33f81189fd7',
        101: 'd9a91e93-d876-40fe-98be-41ec023e789f',
        150: 'c4ce3ca1-31dc-4742-9386-91112ff5ed69',
        200: 'f7c0575e-6607-4d44-a07c-0facc7afa75a',
    },
    # 'Student_Performance_Por': {
    #     10: '1f187cae-4dd4-46f8-8521-6ed5f4bd2554',
    #     50: '7b140c4d-9ce8-48c5-bded-d6e6590fe372',
    #     101: 'd34eea29-48d7-436b-872e-7777d8e40c1a',
    #     150: '9bccff31-d5ee-4958-bcd6-9cc7bb335e18',
    #     200: 'fe74b015-8074-41b0-92cd-44eefacebc04',
    # },
}
DATASET_NAMES = list(DATASETS_DB_CONFIG.keys())
MODEL_NAMES = ['RandomForestClassifier']
SENSITIVE_ATTR_FOR_INTERVENTION = 'SEX&RAC1P'
DATASETS_SENSITIVE_ATTRS = {
    'Folktables_CA_2018_Income': ['SEX', 'RAC1P', 'SEX&RAC1P'],
    'Student_Performance_Por': ['sex'],
}

# %% [markdown]
# ## Group Metrics Composition

# %%
all_subgroup_metrics_df, all_group_metrics_df = (
    read_metrics_for_diff_bootstrap_sizes(datasets_db_config=DATASETS_DB_CONFIG,
                                          datasets_sensitive_attrs_dct=DATASETS_SENSITIVE_ATTRS,
                                          db_collection_name=DB_COLLECTION_NAME))
# Out:
# Extracted metrics for Folktables_CA_2018_Income dataset and 10 bootstrap size
# Extracted metrics for Folktables_CA_2018_Income dataset and 50 bootstrap size
# Extracted metrics for Folktables_CA_2018_Income dataset and 101 bootstrap size
# Extracted metrics for Folktables_CA_2018_Income dataset and 150 bootstrap size
# Extracted metrics for Folktables_CA_2018_Income dataset and 200 bootstrap size

# %%
all_subgroup_metrics_df.head(20)
# Out:
#                    Metric              Model_Name               Dataset_Name  \
# 0         Mean_Prediction  RandomForestClassifier  Folktables_CA_2018_Income
# 1        Statistical_Bias  RandomForestClassifier  Folktables_CA_2018_Income
# 2     Overall_Uncertainty  RandomForestClassifier  Folktables_CA_2018_Income
# 3                     Std  RandomForestClassifier  Folktables_CA_2018_Income
# 4                     IQR  RandomForestClassifier  Folktables_CA_2018_Income
# 5   Aleatoric_Uncertainty  RandomForestClassifier  Folktables_CA_2018_Income
# 6   Epistemic_Uncertainty  RandomForestClassifier  Folktables_CA_2018_Income
# 7         Label_Stability  RandomForestClassifier  Folktables_CA_2018_Income
# 8                  Jitter  RandomForestClassifier  Folktables_CA_2018_Income
# 9                     TPR  RandomForestClassifier  Folktables_CA_2018_Income
# 10                    TNR  RandomForestClassifier  Folktables_CA_2018_Income
# 11                    PPV  RandomForestClassifier  Folktables_CA_2018_Income
# 12                    FNR  RandomForestClassifier  Folktables_CA_2018_Income
# 13                    FPR  RandomForestClassifier  Folktables_CA_2018_Income
# 14               Accuracy  RandomForestClassifier  Folktables_CA_2018_Income
# 15                     F1  RandomForestClassifier  Folktables_CA_2018_Income
# 16         Selection-Rate  RandomForestClassifier  Folktables_CA_2018_Income
# 17          Positive-Rate  RandomForestClassifier  Folktables_CA_2018_Income
# 18            Sample_Size  RandomForestClassifier  Folktables_CA_2018_Income
# 19        Mean_Prediction  RandomForestClassifier  Folktables_CA_2018_Income
#
#     Num_Estimators Record_Create_Date_Time  \
# 0               10 2024-02-24 22:03:06.218
# 1               10 2024-02-24 22:03:06.218
# 2               10 2024-02-24 22:03:06.218
# 3               10 2024-02-24 22:03:06.218
# 4               10 2024-02-24 22:03:06.218
# 5               10 2024-02-24 22:03:06.218
# 6               10 2024-02-24 22:03:06.218
# 7               10 2024-02-24 22:03:06.218
# 8               10 2024-02-24 22:03:06.218
# 9               10 2024-02-24 22:03:06.218
# 10              10 2024-02-24 22:03:06.218
# 11              10 2024-02-24 22:03:06.218
# 12              10 2024-02-24 22:03:06.218
# 13              10 2024-02-24 22:03:06.218
# 14              10 2024-02-24 22:03:06.218
# 15              10 2024-02-24 22:03:06.218
# 16              10 2024-02-24 22:03:06.218
# 17              10 2024-02-24 22:03:06.218
# 18              10 2024-02-24 22:03:06.218
# 19              10 2024-02-24 22:03:06.218
#
#                             Session_Uuid Experiment_Iteration  \
# 0   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 1   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 2   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 3   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 4   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 5   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 6   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 7   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 8   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 9   0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 10  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 11  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 12  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 13  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 14  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 15  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 16  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 17  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 18  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
# 19  0f6a39fe-817f-42a6-99d0-a0801d2722bf           Exp_iter_1
#
#     Dataset_Split_Seed Fair_Intervention_Params_Lst  Intervention_Param  \
# 0                  100                        [0.0]                 0.0
# 1                  100                        [0.0]                 0.0
# 2                  100                        [0.0]                 0.0
# 3                  100                        [0.0]                 0.0
# 4                  100                        [0.0]                 0.0
# 5                  100                        [0.0]                 0.0
# 6                  100                        [0.0]                 0.0
# 7                  100                        [0.0]                 0.0
# 8                  100                        [0.0]                 0.0
# 9                  100                        [0.0]                 0.0
# 10                 100                        [0.0]                 0.0
# 11                 100                        [0.0]                 0.0
# 12                 100                        [0.0]                 0.0
# 13                 100                        [0.0]                 0.0
# 14                 100                        [0.0]                 0.0
# 15                 100                        [0.0]                 0.0
# 16                 100                        [0.0]                 0.0
# 17                 100                        [0.0]                 0.0
# 18                 100                        [0.0]                 0.0
# 19                 100                        [0.0]                 0.0
#
#        Run_Start_Date_Time          Subgroup  Metric_Value
# 0  2024-02-24 22:01:10.017          SEX_priv      0.581662
# 1  2024-02-24 22:01:10.017          SEX_priv      0.300106
# 2  2024-02-24 22:01:10.017          SEX_priv      0.681381
# 3  2024-02-24 22:01:10.017          SEX_priv      0.041506
# 4  2024-02-24 22:01:10.017          SEX_priv      0.051069
# 5  2024-02-24 22:01:10.017          SEX_priv      0.673135
# 6  2024-02-24 22:01:10.017          SEX_priv      0.008246
# 7  2024-02-24 22:01:10.017          SEX_priv      0.926123
# 8  2024-02-24 22:01:10.017          SEX_priv      0.056392
# 9  2024-02-24 22:01:10.017          SEX_priv      0.714670
# 10 2024-02-24 22:01:10.017          SEX_priv      0.849642
# 11 2024-02-24 22:01:10.017          SEX_priv      0.808219
# 12 2024-02-24 22:01:10.017          SEX_priv      0.285330
# 13 2024-02-24 22:01:10.017          SEX_priv      0.150358
# 14 2024-02-24 22:01:10.017          SEX_priv      0.786211
# 15 2024-02-24 22:01:10.017          SEX_priv      0.758571
# 16 2024-02-24 22:01:10.017          SEX_priv      0.415560
# 17 2024-02-24 22:01:10.017          SEX_priv      0.884253
# 18 2024-02-24 22:01:10.017          SEX_priv   1581.000000
# 19 2024-02-24 22:01:10.017  SEX_priv_correct      0.586465

# %%
all_group_metrics_df.head(20)
# Out:
#                               Metric              Model_Name  \
# 0                Accuracy_Difference  RandomForestClassifier
# 1   Aleatoric_Uncertainty_Difference  RandomForestClassifier
# 2        Aleatoric_Uncertainty_Ratio  RandomForestClassifier
# 3   Epistemic_Uncertainty_Difference  RandomForestClassifier
# 4        Epistemic_Uncertainty_Ratio  RandomForestClassifier
# 5                 Equalized_Odds_FNR  RandomForestClassifier
# 6                 Equalized_Odds_FPR  RandomForestClassifier
# 7                     IQR_Difference  RandomForestClassifier
# 8                  Jitter_Difference  RandomForestClassifier
# 9              Label_Stability_Ratio  RandomForestClassifier
# 10        Label_Stability_Difference  RandomForestClassifier
# 11    Overall_Uncertainty_Difference  RandomForestClassifier
# 12         Overall_Uncertainty_Ratio  RandomForestClassifier
# 13                  Disparate_Impact  RandomForestClassifier
# 14     Statistical_Parity_Difference  RandomForestClassifier
# 15                    Std_Difference  RandomForestClassifier
# 16                         Std_Ratio  RandomForestClassifier
# 17                Equalized_Odds_TNR  RandomForestClassifier
# 18                Equalized_Odds_TPR  RandomForestClassifier
# 19               Accuracy_Difference  RandomForestClassifier
#
#                  Dataset_Name  Num_Estimators     Run_Start_Date_Time  \
# 0   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 1   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 2   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 3   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 4   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 5   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 6   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 7   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 8   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 9   Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 10  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 11  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 12  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 13  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 14  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 15  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 16  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 17  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 18  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
# 19  Folktables_CA_2018_Income              10 2024-02-24 22:01:10.017
#
#    Record_Create_Date_Time Experiment_Iteration  Group  Metric_Value
# 0  2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.026333
# 1  2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.020758
# 2  2024-02-24 22:03:06.218           Exp_iter_1    SEX      1.030838
# 3  2024-02-24 22:03:06.218           Exp_iter_1    SEX     -0.000116
# 4  2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.985978
# 5  2024-02-24 22:03:06.218           Exp_iter_1    SEX     -0.027962
# 6  2024-02-24 22:03:06.218           Exp_iter_1    SEX     -0.002006
# 7  2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.000592
# 8  2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.006704
# 9  2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.991045
# 10 2024-02-24 22:03:06.218           Exp_iter_1    SEX     -0.008293
# 11 2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.020643
# 12 2024-02-24 22:03:06.218           Exp_iter_1    SEX      1.030296
# 13 2024-02-24 22:03:06.218           Exp_iter_1    SEX      1.139785
# 14 2024-02-24 22:03:06.218           Exp_iter_1    SEX     -0.054038
# 15 2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.000399
# 16 2024-02-24 22:03:06.218           Exp_iter_1    SEX      1.009623
# 17 2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.002006
# 18 2024-02-24 22:03:06.218           Exp_iter_1    SEX      0.027962
# 19 2024-02-24 22:03:06.218           Exp_iter_1  RAC1P      0.003015

# %% [markdown]
# ## Metrics Visualization and Reporting

# %% [markdown]
# ### Group Metrics

# %%
create_plot_for_diff_bootstrap_sizes(all_subgroup_metrics_df,
                                     dataset_name=DATASET_NAMES[0],
                                     metric_name='Accuracy',
                                     model_name=MODEL_NAMES[0],
                                     with_band=True)
# Out:
# alt.LayerChart(...)

# %%
create_plot_for_diff_bootstrap_sizes(all_subgroup_metrics_df,
                                     dataset_name=DATASET_NAMES[0],
                                     metric_name='F1',
                                     model_name=MODEL_NAMES[0],
                                     with_band=True)
# Out:
# alt.LayerChart(...)

# %%
create_plot_for_diff_bootstrap_sizes(all_subgroup_metrics_df,
                                     dataset_name=DATASET_NAMES[0],
                                     metric_name='Label_Stability',
                                     model_name=MODEL_NAMES[0],
                                     with_band=True)
# Out:
# alt.LayerChart(...)

# %%
create_plot_for_diff_bootstrap_sizes(all_subgroup_metrics_df,
                                     dataset_name=DATASET_NAMES[0],
                                     metric_name='Aleatoric_Uncertainty',
                                     model_name=MODEL_NAMES[0],
                                     with_band=True)
# Out:
# alt.LayerChart(...)

# %%
create_plot_for_diff_bootstrap_sizes(all_subgroup_metrics_df,
                                     dataset_name=DATASET_NAMES[0],
                                     metric_name='Std',
                                     model_name=MODEL_NAMES[0],
                                     with_band=True)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Disparity Metrics

# %%
create_plot_for_diff_bootstrap_sizes(all_group_metrics_df,
                                     dataset_name=DATASET_NAMES[0],
                                     metric_name='Label_Stability_Difference',
                                     group=SENSITIVE_ATTR_FOR_INTERVENTION,
                                     model_name=MODEL_NAMES[0],
                                     with_band=True)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Group metrics per experiment run

# %%
create_plot_for_diff_bootstrap_sizes_and_exp_run(all_subgroup_metrics_df,
                                                 dataset_name=DATASET_NAMES[0],
                                                 metric_name='Label_Stability',
                                                 model_name=MODEL_NAMES[0])
# Out:
# alt.Chart(...)

# %%
create_plot_for_diff_bootstrap_sizes_and_exp_run(all_subgroup_metrics_df,
                                                 dataset_name=DATASET_NAMES[0],
                                                 metric_name='Aleatoric_Uncertainty',
                                                 model_name=MODEL_NAMES[0])
# Out:
# alt.Chart(...)

# %%
create_plot_for_diff_bootstrap_sizes_and_exp_run(all_subgroup_metrics_df,
                                                 dataset_name=DATASET_NAMES[0],
                                                 metric_name='Std',
                                                 model_name=MODEL_NAMES[0])
# Out:
# alt.Chart(...)
